# %%
# following code taken from Foursquare API lab and adapted to Billings Montana info
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     geopy-1.19.0               |             py_0          53 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.19.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.3.9-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001 conda-forge
#     openssl:         1.0.2r-h7b6447c_0             --> 1.0.2r-h14c3975_0   conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# geopy-1.19.0         | 53 KB     | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         560 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA' # your Foursquare ID
CLIENT_SECRET = 'U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA
# CLIENT_SECRET:U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY

# %%
address = '1603 Grand Ave, Billings, MT'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 45.784127338925 -108.557717907471

# %%
search_query = 'Coffee Shop'
categoryId = '4bf58dd8d48988d1e0931735' # Coffee Shop
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Coffee Shop .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=45.784127338925,-108.557717907471&v=20180604&query=Coffee Shop&radius=50000&limit=500'

# %%
# get requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce44f66dd57970e2322a5ab'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '58a9ad9c2948b344b7704b88',
#     'location': {'address': '415 N 29th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3638,
#      'formattedAddress': ['415 N 29th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.784958,
#        'lng': -108.51086}],
#      'lat': 45.784958,
#      'lng': -108.51086,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Stirrup Coffee Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '503520a9e4b0272a4de301ff',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3833,
#      'formattedAddress': ['Billings, MT 59101', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78065490722656,
#        'lng': -108.50859069824219}],
#      'lat': 45.78065490722656,
#      'lng': -108.50859069824219,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Himmelberger Brewing Company Coffee Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f322ada19836c91c7bccd42',
#     'location': {'address': '1635 Old Hardin Rd',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 9064,
#      'formattedAddress': ['1635 Old Hardin Rd',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.800339,
#        'lng': -108.443274}],
#      'lat': 45.800339,
#      'lng': -108.443274,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Lighthouse Coffee Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b85967df964a520156731e3',
#     'location': {'address': '1640 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': 'at 17th St',
#      'distance': 66,
#      'formattedAddress': ['1640 Grand Ave (at 17th St)',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78383755536309,
#        'lng': -108.55847330489213}],
#      'lat': 45.78383755536309,
#      'lng': -108.55847330489213,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'City Brew Coffee',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f3261a519836c91c7d23d55',
#     'location': {'address': '1603 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 102,
#      'formattedAddress': ['1603 Grand Ave', 'Billings, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.784216,
#        'lng': -108.559038}],
#      'lat': 45.784216,
#      'lng': -108.559038,
#      'state': 'MT'},
#     'name': 'Musgraves Gourmet Coffee',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d115951735',
#       'name': 'Bike Shop',
#       'pluralName': 'Bike Shops',
#       'primary': True,
#       'shortName': 'Bike Shop'}],
#     'hasPerk': False,
#     'id': '575c3930498eabc9389298fe',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 299,
#      'formattedAddress': ['Billings, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.783222,
#        'lng': -108.55409}],
#      'lat': 45.783222,
#      'lng': -108.55409,
#      'state': 'MT'},
#     'name': "Colin's Bike Shop",
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4dd187f6d22d67839c47c29d',
#     'location': {'address': '320 S 24th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2689,
#      'formattedAddress': ['320 S 24th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.76542140371609,
#        'lng': -108.57964918614968}],
#      'lat': 45.76542140371609,
#      'lng': -108.57964918614968,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'The Coffee Mill',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4f3224fb19836c91c7ba835f',
#     'location': {'address': '300 S 24th St W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2598,
#      'formattedAddress': ['300 S 24th St W', 'Billings, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.76468,
#        'lng': -108.57624}],
#      'lat': 45.76468,
#      'lng': -108.57624,
#      'state': 'MT'},
#     'name': 'Coffee Mill Espresso and More',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '595a90cb1de76542ca46d019',
#     'location': {'address': '1528 24th St W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1508,
#      'formattedAddress': ['1528 24th St W',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.786178,
#        'lng': -108.576922}],
#      'lat': 45.786178,
#      'lng': -108.576922,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Black Dog Coffee House',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f3222b719836c91c7b99b82',
#     'location': {'address': '1939 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 581,
#      'formattedAddress': ['1939 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78413,
#        'lng': -108.56521}],
#      'lat': 45.78413,
#      'lng': -108.56521,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Big Sky Coffee Roasters',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b3651a4f964a520c73225e3',
#     'location': {'address': '819 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1604,
#      'formattedAddress': ['819 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78435172937381,
#        'lng': -108.53705234643124}],
#      'lat': 45.78435172937381,
#      'lng': -108.53705234643124,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Off the Leaf Coffee Bar',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d115951735',
#       'name': 'Bike Shop',
#       'pluralName': 'Bike Shops',
#       'primary': True,
#       'shortName': 'Bike Shop'}],
#     'hasPerk': False,
#     'id': '50b1475be4b0d4508c001a87',
#     'location': {'address': '1934 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 644,
#      'formattedAddress': ['1934 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.784011,
#        'lng': -108.566014}],
#      'lat': 45.784011,
#      'lng': -108.566014,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'The Bike Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d115951735',
#       'name': 'Bike Shop',
#       'pluralName': 'Bike Shops',
#       'primary': True,
#       'shortName': 'Bike Shop'}],
#     'hasPerk': False,
#     'id': '4c606cfb924b76b0d7cef0b9',
#     'location': {'address': '1910 Broadwater Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 984,
#      'formattedAddress': ['1910 Broadwater Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7767647,
#        'lng': -108.56475136666667}],
#      'lat': 45.7767647,
#      'lng': -108.56475136666667,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'The Spoke Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '4c193528fe5a76b0cb3c0315',
#     'location': {'address': '11 St W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': 'Grand Ave',
#      'distance': 1089,
#      'formattedAddress': ['11 St W (Grand Ave)',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78388872119463,
#        'lng': -108.54368465683791}],
#      'lat': 45.78388872119463,
#      'lng': -108.54368465683791,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Billings Barber Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '58796acde0adac0ce98fe4a8',
#     'location': {'address': '2828 2nd Avenue North',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 4687,
#      'formattedAddress': ['2828 2nd Avenue North',
#       'Billings, MT',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7772941142321,
#        'lng': -108.498141970485}],
#      'lat': 45.7772941142321,
#      'lng': -108.498141970485,
#      'state': 'MT'},
#     'name': 'Coffee Tavern',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4cd0780d6449a0938ccbcacf',
#     'location': {'address': '1028 Broadwater Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 7210,
#      'formattedAddress': ['1028 Broadwater Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.810156606377184,
#        'lng': -108.47265081216734}],
#      'lat': 45.810156606377184,
#      'lng': -108.47265081216734,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Coffee Mill Coffee & More',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '57369584498ea44d0c2d3cbb',
#     'location': {'address': '2501 Montana Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 998,
#      'formattedAddress': ['2501 Montana Ave',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.777025,
#        'lng': -108.565579}],
#      'lat': 45.777025,
#      'lng': -108.565579,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'MaAV Coffee House',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4f326c2919836c91c7d64d21',
#     'location': {'address': '100 24th St W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2076,
#      'formattedAddress': ['100 24th St W',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.77107032636983,
#        'lng': -108.57681334018707}],
#      'lat': 45.77107032636983,
#      'lng': -108.57681334018707,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'City Brew Coffee',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4bd98ef80115c9b6e6af7780',
#     'location': {'address': '2425 King Ave W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': 'S 24th St',
#      'distance': 3503,
#      'formattedAddress': ['2425 King Ave W (S 24th St)',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7557254409678,
#        'lng': -108.57716943161564}],
#      'lat': 45.7557254409678,
#      'lng': -108.57716943161564,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'City Brew Coffee',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f325c8319836c91c7d03ba3',
#     'location': {'address': '1831 Poly Dr',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1299,
#      'formattedAddress': ['1831 Poly Dr',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.79512,
#        'lng': -108.563348}],
#      'lat': 45.79512,
#      'lng': -108.563348,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Musgraves Gourmet Coffee',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b859620f964a520026731e3',
#     'location': {'address': '1131 N 27th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3482,
#      'formattedAddress': ['1131 N 27th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.79374465252583,
#        'lng': -108.51502969289317}],
#      'lat': 45.79374465252583,
#      'lng': -108.51502969289317,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'City Brew Coffee',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d123951735',
#       'name': 'Smoke Shop',
#       'pluralName': 'Smoke Shops',
#       'primary': True,
#       'shortName': 'Smoke Shop'}],
#     'hasPerk': False,
#     'id': '4dc71880b0fb5556cd1a1c57',
#     'location': {'address': '111 S 24th St W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2335,
#      'formattedAddress': ['111 S 24th St W',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.76737029006368,
#        'lng': -108.57582265024995}],
#      'lat': 45.76737029006368,
#      'lng': -108.57582265024995,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': "Smitty's Smoke Shop",
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '5aa0056ecf72a0487e755f34',
#     'location': {'address': '1233 N 30th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3163,
#      'formattedAddress': ['1233 N 30th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.793141,
#        'lng': -108.519071}],
#      'lat': 45.793141,
#      'lng': -108.519071,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Casablanca Coffee 2',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'id': '52f2ab2ebcbc57f1066b8b45',
#       'name': 'Organic Grocery',
#       'pluralName': 'Organic Groceries',
#       'primary': True,
#       'shortName': 'Organic Grocery'}],
#     'hasPerk': False,
#     'id': '4fe8e2d5e4b0d5efa51c7eb5',
#     'location': {'address': '304 S 24th St W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2445,
#      'formattedAddress': ['304 S 24th St W',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.76655150240635,
#        'lng': -108.57660700732642}],
#      'lat': 45.76655150240635,
#      'lng': -108.57660700732642,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Natural Grocers',
#     'referralId': 'v-1558466407',
#     'venuePage': {'id': '361446993'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d122951735',
#       'name': 'Electronics Store',
#       'pluralName': 'Electronics Stores',
#       'primary': True,
#       'shortName': 'Electronics'}],
#     'hasPerk': False,
#     'id': '4baf9fd0f964a52015113ce3',
#     'location': {'address': '2450 King Ave W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': 'S 24th St W',
#      'distance': 3706,
#      'formattedAddress': ['2450 King Ave W (S 24th St W)',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7540786,
#        'lng': -108.5782676}],
#      'lat': 45.7540786,
#      'lng': -108.5782676,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Best Buy',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '58559bae109dfe314276b1ed',
#     'location': {'address': '1335 Golden Valley Cir',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3110,
#      'formattedAddress': ['1335 Golden Valley Cir',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.783803,
#        'lng': -108.597782}],
#      'lat': 45.783803,
#      'lng': -108.597782,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'City Brew',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4f3260e519836c91c7d1f17e',
#     'location': {'address': '2900 12th Ave N',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3212,
#      'formattedAddress': ['2900 12th Ave N',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.792977,
#        'lng': -108.518325}],
#      'lat': 45.792977,
#      'lng': -108.518325,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Casablanca Coffee Kiosk',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hobbyshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fb941735',
#       'name': 'Hobby Shop',
#       'pluralName': 'Hobby Shops',
#       'primary': True,
#       'shortName': 'Hobbies'}],
#     'hasPerk': False,
#     'id': '5079b7c8e4b034705318b09b',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2165,
#      'formattedAddress': ['Billings, MT 59102', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.76811346599074,
#        'lng': -108.57356295403201}],
#      'lat': 45.76811346599074,
#      'lng': -108.57356295403201,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': "Pat's Hotrod Shop",
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'primary': True,
#       'shortName': 'Automotive'}],
#     'hasPerk': False,
#     'id': '5552aec3498e51c5935022e4',
#     'location': {'address': '1845 Lampman Dr',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2732,
#      'formattedAddress': ['1845 Lampman Dr',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.75999,
#        'lng': -108.564108}],
#      'lat': 45.75999,
#      'lng': -108.564108,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Hanks Body Shop Inc',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4be359d4cbdbef3b0a9360d8',
#     'location': {'address': '124 N 28th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3963,
#      'formattedAddress': ['124 N 28th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78282279068451,
#        'lng': -108.50669622143464}],
#      'lat': 45.78282279068451,
#      'lng': -108.50669622143464,
#      'neighborhood': 'Downtown',
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Rock Creek Coffee Roasters',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f2941735',
#       'name': 'Sporting Goods Shop',
#       'pluralName': 'Sporting Goods Shops',
#       'primary': True,
#       'shortName': 'Sporting Goods'}],
#     'hasPerk': False,
#     'id': '4fdf4722e4b03622b26e4ad3',
#     'location': {'address': '485 S 24th St W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2924,
#      'formattedAddress': ['485 S 24th St W',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.76095400137561,
#        'lng': -108.57546080532668}],
#      'lat': 45.76095400137561,
#      'lng': -108.57546080532668,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Bighorn Fly & Tackle Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b9d4282f964a520df9d36e3',
#     'location': {'address': '27 N 27th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': '1st Ave N',
#      'distance': 4135,
#      'formattedAddress': ['27 N 27th St (1st Ave N)',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.782867,
#        'lng': -108.504476}],
#      'lat': 45.782867,
#      'lng': -108.504476,
#      'neighborhood': 'Downtown',
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Starbucks',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4c7bd1d897028cfa43f1e1fe',
#     'location': {'address': '2120 3rd Ave N',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3217,
#      'formattedAddress': ['2120 3rd Ave N',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.75612831666667,
#        'lng': -108.5680212}],
#      'lat': 45.75612831666667,
#      'lng': -108.5680212,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Mountain Mudd Espresso',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '5b4640ecb8fd9d002c8b673e',
#     'location': {'address': '1211 N 27th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3533,
#      'formattedAddress': ['1211 N 27th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.79406135396124,
#        'lng': -108.51448631299718}],
#      'lat': 45.79406135396124,
#      'lng': -108.51448631299718,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'City Brew Coffee North',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '50d057dce4b08cc4922cb03c',
#     'location': {'address': 'Logan Terminal A',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2705,
#      'formattedAddress': ['Logan Terminal A',
#       'Billings, MT 59105',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.80374675604687,
#        'lng': -108.53715198606456}],
#      'lat': 45.80374675604687,
#      'lng': -108.53715198606456,
#      'postalCode': '59105',
#      'state': 'MT'},
#     'name': 'the big cup of coffee',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '574a5612498e1c0c6fb946a1',
#     'location': {'address': '2501 Montana Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': 'N 25th St',
#      'distance': 4360,
#      'formattedAddress': ['2501 Montana Ave (N 25th St)',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78312692607741,
#        'lng': -108.50157109170749}],
#      'lat': 45.78312692607741,
#      'lng': -108.50157109170749,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'MoAV Coffee House',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#        'suffix': '.png'},
#       'id': '5454144b498ec1f095bff2f2',
#       'name': 'Construction & Landscaping',
#       'pluralName': 'Construction & Landscaping',
#       'primary': True,
#       'shortName': 'Construction'}],
#     'hasPerk': False,
#     'id': '5106de12e4b056a13ae698a2',
#     'location': {'address': '3325 1st Ave N',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3538,
#      'formattedAddress': ['3325 1st Ave N',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7789464,
#        'lng': -108.5127427}],
#      'lat': 45.7789464,
#      'lng': -108.5127427,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': "Becker's Glass Shop, Inc",
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4c715800df6b8cfad4bcba4d',
#     'location': {'address': '802 Shiloh Crossing Blvd',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': 'at King Ave W',
#      'distance': 5460,
#      'formattedAddress': ['802 Shiloh Crossing Blvd (at King Ave W)',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.75483760428098,
#        'lng': -108.61412895707149}],
#      'lat': 45.75483760428098,
#      'lng': -108.61412895707149,
#      'neighborhood': 'West End',
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'City Brew Coffee',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f6941735',
#       'name': 'Department Store',
#       'pluralName': 'Department Stores',
#       'primary': True,
#       'shortName': 'Department Store'}],
#     'hasPerk': False,
#     'id': '4b8c0593f964a5200eb932e3',
#     'location': {'address': '905 S 24th St W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': 'King Ave',
#      'distance': 3662,
#      'formattedAddress': ['905 S 24th St W (King Ave)',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.753489193379544,
#        'lng': -108.57492278958995}],
#      'lat': 45.753489193379544,
#      'lng': -108.57492278958995,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Shopko',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '56d772f4498ea2397473477c',
#     'location': {'address': '2712 2ND',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 4030,
#      'formattedAddress': ['2712 2ND', 'Billings, MT 59101', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.783109,
#        'lng': -108.505819}],
#      'lat': 45.783109,
#      'lng': -108.505819,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Ebon Coffee Collective',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/papergoods_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d121951735',
#       'name': 'Paper / Office Supplies Store',
#       'pluralName': 'Paper / Office Supplies Stores',
#       'primary': True,
#       'shortName': 'Office Supplies'}],
#     'hasPerk': False,
#     'id': '4b941d4cf964a520166934e3',
#     'location': {'address': '9 N 32nd St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3740,
#      'formattedAddress': ['9 N 32nd St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.77939435952856,
#        'lng': -108.51001257299198}],
#      'lat': 45.77939435952856,
#      'lng': -108.51001257299198,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Accent print shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'primary': True,
#       'shortName': 'Business Services'}],
#     'hasPerk': False,
#     'id': '5a09d6548e886a27c46bba17',
#     'location': {'address': '960 S 24th St W Ste C',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3692,
#      'formattedAddress': ['960 S 24th St W Ste C',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7535497,
#        'lng': -108.576135}],
#      'lat': 45.7535497,
#      'lng': -108.576135,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Ballistic Barber Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '52bde6a411d27ee2c3968811',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2716,
#      'formattedAddress': ['Billings, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78684113226233,
#        'lng': -108.59249048998326}],
#      'lat': 45.78684113226233,
#      'lng': -108.59249048998326,
#      'state': 'MT'},
#     'name': 'Golden Razor Salon and Barber Shoppe',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/papergoods_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d121951735',
#       'name': 'Paper / Office Supplies Store',
#       'pluralName': 'Paper / Office Supplies Stores',
#       'primary': True,
#       'shortName': 'Office Supplies'}],
#     'hasPerk': False,
#     'id': '51ed9a4c498ed28755796d81',
#     'location': {'address': '2822 3rd Ave N Ste B14',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3842,
#      'formattedAddress': ['2822 3rd Ave N Ste B14',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78329,
#        'lng': -108.50823}],
#      'lat': 45.78329,
#      'lng': -108.50823,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'The Rubber Stamp Shop',
#     'referralId': 'v-1558466407',
#     'venuePage': {'id': '496794857'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f322a0019836c91c7bc79c8',
#     'location': {'address': '115 N 29th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3938,
#      'formattedAddress': ['115 N 29th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.781642,
#        'lng': -108.50711}],
#      'lat': 45.781642,
#      'lng': -108.50711,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Yellowstone Sandwich Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f6941735',
#       'name': 'Department Store',
#       'pluralName': 'Department Stores',
#       'primary': True,
#       'shortName': 'Department Store'}],
#     'hasPerk': False,
#     'id': '4ee23e180e61689f53c1c392',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3001,
#      'formattedAddress': ['Billings, MT 59102', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.75983338231644,
#        'lng': -108.57448305185963}],
#      'lat': 45.75983338231644,
#      'lng': -108.57448305185963,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Shopco',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d101951735',
#       'name': 'Thrift / Vintage Store',
#       'pluralName': 'Thrift / Vintage Stores',
#       'primary': True,
#       'shortName': 'Thrift / Vintage'}],
#     'hasPerk': False,
#     'id': '533eed73498ef078be43a618',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': '27th W Street',
#      'distance': 4167,
#      'formattedAddress': ['27th W Street', 'Billings, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.788524461996786,
#        'lng': -108.5044071083359}],
#      'lat': 45.788524461996786,
#      'lng': -108.5044071083359,
#      'state': 'MT'},
#     'name': 'Thrift Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1b3941735',
#       'name': 'Medical School',
#       'pluralName': 'Medical Schools',
#       'primary': True,
#       'shortName': 'Medical School'}],
#     'hasPerk': False,
#     'id': '591d4439f427de196f13e5e3',
#     'location': {'address': '1335 Holiday Cir',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 4228,
#      'formattedAddress': ['1335 Holiday Cir',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7462893,
#        'lng': -108.5528737}],
#      'lat': 45.7462893,
#      'lng': -108.5528737,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Mega Bud Shop',
#     'referralId': 'v-1558466407',
#     'venuePage': {'id': '418514054'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'primary': True,
#       'shortName': 'Automotive'}],
#     'hasPerk': False,
#     'id': '51bf16c0e4b0b87136edfc74',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 4393,
#      'formattedAddress': ['Billings, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.788319,
#        'lng': -108.501438}],
#      'lat': 45.788319,
#      'lng': -108.501438,
#      'state': 'MT'},
#     'name': 'Brake Shop',
#     'referralId': 'v-1558466407'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '54541900498ea6ccd0202697',
#       'name': 'Health & Beauty Service',
#       'pluralName': 'Health & Beauty Services',
#       'primary': True,
#       'shortName': 'Health & Beauty'}],
#     'hasPerk': False,
#     'id': '5a54ee02b04056149962378f',
#     'location': {'address': 'Billings, Mt',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 4076,
#      'formattedAddress': ['Billings, Mt',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.747573998572236,
#        'lng': -108.55459562031389}],
#      'lat': 45.747573998572236,
#      'lng': -108.55459562031389,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Omega Chemicals Online Shop',
#     'referralId': 'v-1558466407'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Coffee Shop', 'primary': True,...    False
# 1  [{'shortName': 'Coffee Shop', 'primary': True,...    False
# 2  [{'shortName': 'Food', 'primary': True, 'icon'...    False
# 3  [{'shortName': 'Coffee Shop', 'primary': True,...    False
# 4  [{'shortName': 'Food', 'primary': True, 'icon'...    False
#
#                          id    location.address location.cc location.city  \
# 0  58a9ad9c2948b344b7704b88       415 N 29th St          US      Billings
# 1  503520a9e4b0272a4de301ff                 NaN          US      Billings
# 2  4f322ada19836c91c7bccd42  1635 Old Hardin Rd          US      Billings
# 3  4b85967df964a520156731e3      1640 Grand Ave          US      Billings
# 4  4f3261a519836c91c7d23d55      1603 Grand Ave          US      Billings
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN               3638
# 1    United States                  NaN               3833
# 2    United States                  NaN               9064
# 3    United States           at 17th St                 66
# 4    United States                  NaN                102
#
#                            location.formattedAddress  \
# 0  [415 N 29th St, Billings, MT 59101, United Sta...
# 1                [Billings, MT 59101, United States]
# 2  [1635 Old Hardin Rd, Billings, MT 59101, Unite...
# 3  [1640 Grand Ave (at 17th St), Billings, MT 591...
# 4      [1603 Grand Ave, Billings, MT, United States]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 45.784958, 'lng': -108.51086, 'label'...     45.784958
# 1  [{'lat': 45.78065490722656, 'lng': -108.508590...     45.780655
# 2  [{'lat': 45.800339, 'lng': -108.443274, 'label...     45.800339
# 3  [{'lat': 45.78383755536309, 'lng': -108.558473...     45.783838
# 4  [{'lat': 45.784216, 'lng': -108.559038, 'label...     45.784216
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0   -108.510860                   NaN               59101             MT
# 1   -108.508591                   NaN               59101             MT
# 2   -108.443274                   NaN               59101             MT
# 3   -108.558473                   NaN               59102             MT
# 4   -108.559038                   NaN                 NaN             MT
#
#                                        name    referralId venuePage.id
# 0                       Stirrup Coffee Shop  v-1558466407          NaN
# 1  Himmelberger Brewing Company Coffee Shop  v-1558466407          NaN
# 2                    Lighthouse Coffee Shop  v-1558466407          NaN
# 3                          City Brew Coffee  v-1558466407          NaN
# 4                  Musgraves Gourmet Coffee  v-1558466407          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                         name                     categories  \
# 0                        Stirrup Coffee Shop                    Coffee Shop
# 1   Himmelberger Brewing Company Coffee Shop                    Coffee Shop
# 2                     Lighthouse Coffee Shop                           Food
# 3                           City Brew Coffee                    Coffee Shop
# 4                   Musgraves Gourmet Coffee                           Food
# 5                          Colin's Bike Shop                      Bike Shop
# 6                            The Coffee Mill                    Coffee Shop
# 7              Coffee Mill Espresso and More                    Coffee Shop
# 8                     Black Dog Coffee House                    Coffee Shop
# 9                    Big Sky Coffee Roasters                           Food
# 10                   Off the Leaf Coffee Bar                    Coffee Shop
# 11                             The Bike Shop                      Bike Shop
# 12                            The Spoke Shop                      Bike Shop
# 13                      Billings Barber Shop             Salon / Barbershop
# 14                             Coffee Tavern                    Coffee Shop
# 15                 Coffee Mill Coffee & More                    Coffee Shop
# 16                         MaAV Coffee House                    Coffee Shop
# 17                          City Brew Coffee                    Coffee Shop
# 18                          City Brew Coffee                    Coffee Shop
# 19                  Musgraves Gourmet Coffee                           Food
# 20                          City Brew Coffee                    Coffee Shop
# 21                       Smitty's Smoke Shop                     Smoke Shop
# 22                       Casablanca Coffee 2                    Coffee Shop
# 23                           Natural Grocers                Organic Grocery
# 24                                  Best Buy              Electronics Store
# 25                                 City Brew                    Coffee Shop
# 26                   Casablanca Coffee Kiosk                    Coffee Shop
# 27                         Pat's Hotrod Shop                     Hobby Shop
# 28                       Hanks Body Shop Inc                Automotive Shop
# 29                Rock Creek Coffee Roasters                    Coffee Shop
# 30                 Bighorn Fly & Tackle Shop            Sporting Goods Shop
# 31                                 Starbucks                    Coffee Shop
# 32                    Mountain Mudd Espresso                    Coffee Shop
# 33                    City Brew Coffee North                    Coffee Shop
# 34                     the big cup of coffee                 Breakfast Spot
# 35                         MoAV Coffee House                    Coffee Shop
# 36                  Becker's Glass Shop, Inc     Construction & Landscaping
# 37                          City Brew Coffee                    Coffee Shop
# 38                                    Shopko               Department Store
# 39                    Ebon Coffee Collective                    Coffee Shop
# 40                         Accent print shop  Paper / Office Supplies Store
# 41                     Ballistic Barber Shop               Business Service
# 42      Golden Razor Salon and Barber Shoppe             Salon / Barbershop
# 43                     The Rubber Stamp Shop  Paper / Office Supplies Store
# 44                 Yellowstone Sandwich Shop                           Food
# 45                                    Shopco               Department Store
# 46                               Thrift Shop         Thrift / Vintage Store
# 47                             Mega Bud Shop                 Medical School
# 48                                Brake Shop                Automotive Shop
# 49               Omega Chemicals Online Shop        Health & Beauty Service
#
#                      address  cc      city        country    crossStreet  \
# 0              415 N 29th St  US  Billings  United States            NaN
# 1                        NaN  US  Billings  United States            NaN
# 2         1635 Old Hardin Rd  US  Billings  United States            NaN
# 3             1640 Grand Ave  US  Billings  United States     at 17th St
# 4             1603 Grand Ave  US  Billings  United States            NaN
# 5                        NaN  US  Billings  United States            NaN
# 6              320 S 24th St  US  Billings  United States            NaN
# 7            300 S 24th St W  US  Billings  United States            NaN
# 8             1528 24th St W  US  Billings  United States            NaN
# 9             1939 Grand Ave  US  Billings  United States            NaN
# 10             819 Grand Ave  US  Billings  United States            NaN
# 11            1934 Grand Ave  US  Billings  United States            NaN
# 12       1910 Broadwater Ave  US  Billings  United States            NaN
# 13                   11 St W  US  Billings  United States      Grand Ave
# 14     2828 2nd Avenue North  US  Billings  United States            NaN
# 15       1028 Broadwater Ave  US  Billings  United States            NaN
# 16          2501 Montana Ave  US  Billings  United States            NaN
# 17             100 24th St W  US  Billings  United States            NaN
# 18           2425 King Ave W  US  Billings  United States      S 24th St
# 19              1831 Poly Dr  US  Billings  United States            NaN
# 20            1131 N 27th St  US  Billings  United States            NaN
# 21           111 S 24th St W  US  Billings  United States            NaN
# 22            1233 N 30th St  US  Billings  United States            NaN
# 23           304 S 24th St W  US  Billings  United States            NaN
# 24           2450 King Ave W  US  Billings  United States    S 24th St W
# 25    1335 Golden Valley Cir  US  Billings  United States            NaN
# 26           2900 12th Ave N  US  Billings  United States            NaN
# 27                       NaN  US  Billings  United States            NaN
# 28           1845 Lampman Dr  US  Billings  United States            NaN
# 29             124 N 28th St  US  Billings  United States            NaN
# 30           485 S 24th St W  US  Billings  United States            NaN
# 31              27 N 27th St  US  Billings  United States      1st Ave N
# 32            2120 3rd Ave N  US  Billings  United States            NaN
# 33            1211 N 27th St  US  Billings  United States            NaN
# 34          Logan Terminal A  US  Billings  United States            NaN
# 35          2501 Montana Ave  US  Billings  United States      N 25th St
# 36            3325 1st Ave N  US  Billings  United States            NaN
# 37  802 Shiloh Crossing Blvd  US  Billings  United States  at King Ave W
# 38           905 S 24th St W  US  Billings  United States       King Ave
# 39                  2712 2ND  US  Billings  United States            NaN
# 40               9 N 32nd St  US  Billings  United States            NaN
# 41     960 S 24th St W Ste C  US  Billings  United States            NaN
# 42                       NaN  US  Billings  United States            NaN
# 43    2822 3rd Ave N Ste B14  US  Billings  United States            NaN
# 44             115 N 29th St  US  Billings  United States            NaN
# 45                       NaN  US  Billings  United States            NaN
# 46                       NaN  US  Billings  United States  27th W Street
# 47          1335 Holiday Cir  US  Billings  United States            NaN
# 48                       NaN  US  Billings  United States            NaN
# 49              Billings, Mt  US  Billings  United States            NaN
#
#     distance                                   formattedAddress  \
# 0       3638  [415 N 29th St, Billings, MT 59101, United Sta...
# 1       3833                [Billings, MT 59101, United States]
# 2       9064  [1635 Old Hardin Rd, Billings, MT 59101, Unite...
# 3         66  [1640 Grand Ave (at 17th St), Billings, MT 591...
# 4        102      [1603 Grand Ave, Billings, MT, United States]
# 5        299                      [Billings, MT, United States]
# 6       2689  [320 S 24th St, Billings, MT 59101, United Sta...
# 7       2598     [300 S 24th St W, Billings, MT, United States]
# 8       1508  [1528 24th St W, Billings, MT 59102, United St...
# 9        581  [1939 Grand Ave, Billings, MT 59102, United St...
# 10      1604  [819 Grand Ave, Billings, MT 59102, United Sta...
# 11       644  [1934 Grand Ave, Billings, MT 59102, United St...
# 12       984  [1910 Broadwater Ave, Billings, MT 59102, Unit...
# 13      1089  [11 St W (Grand Ave), Billings, MT 59102, Unit...
# 14      4687  [2828 2nd Avenue North, Billings, MT, United S...
# 15      7210  [1028 Broadwater Ave, Billings, MT 59102, Unit...
# 16       998  [2501 Montana Ave, Billings, MT 59101, United ...
# 17      2076  [100 24th St W, Billings, MT 59102, United Sta...
# 18      3503  [2425 King Ave W (S 24th St), Billings, MT 591...
# 19      1299  [1831 Poly Dr, Billings, MT 59102, United States]
# 20      3482  [1131 N 27th St, Billings, MT 59101, United St...
# 21      2335  [111 S 24th St W, Billings, MT 59102, United S...
# 22      3163  [1233 N 30th St, Billings, MT 59101, United St...
# 23      2445  [304 S 24th St W, Billings, MT 59102, United S...
# 24      3706  [2450 King Ave W (S 24th St W), Billings, MT 5...
# 25      3110  [1335 Golden Valley Cir, Billings, MT 59102, U...
# 26      3212  [2900 12th Ave N, Billings, MT 59101, United S...
# 27      2165                [Billings, MT 59102, United States]
# 28      2732  [1845 Lampman Dr, Billings, MT 59102, United S...
# 29      3963  [124 N 28th St, Billings, MT 59101, United Sta...
# 30      2924  [485 S 24th St W, Billings, MT 59102, United S...
# 31      4135  [27 N 27th St (1st Ave N), Billings, MT 59101,...
# 32      3217  [2120 3rd Ave N, Billings, MT 59101, United St...
# 33      3533  [1211 N 27th St, Billings, MT 59101, United St...
# 34      2705  [Logan Terminal A, Billings, MT 59105, United ...
# 35      4360  [2501 Montana Ave (N 25th St), Billings, MT 59...
# 36      3538  [3325 1st Ave N, Billings, MT 59101, United St...
# 37      5460  [802 Shiloh Crossing Blvd (at King Ave W), Bil...
# 38      3662  [905 S 24th St W (King Ave), Billings, MT 5910...
# 39      4030      [2712 2ND, Billings, MT 59101, United States]
# 40      3740   [9 N 32nd St, Billings, MT 59101, United States]
# 41      3692  [960 S 24th St W Ste C, Billings, MT 59102, Un...
# 42      2716                      [Billings, MT, United States]
# 43      3842  [2822 3rd Ave N Ste B14, Billings, MT 59101, U...
# 44      3938  [115 N 29th St, Billings, MT 59101, United Sta...
# 45      3001                [Billings, MT 59102, United States]
# 46      4167       [27th W Street, Billings, MT, United States]
# 47      4228  [1335 Holiday Cir, Billings, MT 59101, United ...
# 48      4393                      [Billings, MT, United States]
# 49      4076  [Billings, Mt, Billings, MT 59101, United States]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'lat': 45.784958, 'lng': -108.51086, 'label'...  45.784958 -108.510860
# 1   [{'lat': 45.78065490722656, 'lng': -108.508590...  45.780655 -108.508591
# 2   [{'lat': 45.800339, 'lng': -108.443274, 'label...  45.800339 -108.443274
# 3   [{'lat': 45.78383755536309, 'lng': -108.558473...  45.783838 -108.558473
# 4   [{'lat': 45.784216, 'lng': -108.559038, 'label...  45.784216 -108.559038
# 5   [{'lat': 45.783222, 'lng': -108.55409, 'label'...  45.783222 -108.554090
# 6   [{'lat': 45.76542140371609, 'lng': -108.579649...  45.765421 -108.579649
# 7   [{'lat': 45.76468, 'lng': -108.57624, 'label':...  45.764680 -108.576240
# 8   [{'lat': 45.786178, 'lng': -108.576922, 'label...  45.786178 -108.576922
# 9   [{'lat': 45.78413, 'lng': -108.56521, 'label':...  45.784130 -108.565210
# 10  [{'lat': 45.78435172937381, 'lng': -108.537052...  45.784352 -108.537052
# 11  [{'lat': 45.784011, 'lng': -108.566014, 'label...  45.784011 -108.566014
# 12  [{'lat': 45.7767647, 'lng': -108.5647513666666...  45.776765 -108.564751
# 13  [{'lat': 45.78388872119463, 'lng': -108.543684...  45.783889 -108.543685
# 14  [{'lat': 45.7772941142321, 'lng': -108.4981419...  45.777294 -108.498142
# 15  [{'lat': 45.810156606377184, 'lng': -108.47265...  45.810157 -108.472651
# 16  [{'lat': 45.777025, 'lng': -108.565579, 'label...  45.777025 -108.565579
# 17  [{'lat': 45.77107032636983, 'lng': -108.576813...  45.771070 -108.576813
# 18  [{'lat': 45.7557254409678, 'lng': -108.5771694...  45.755725 -108.577169
# 19  [{'lat': 45.79512, 'lng': -108.563348, 'label'...  45.795120 -108.563348
# 20  [{'lat': 45.79374465252583, 'lng': -108.515029...  45.793745 -108.515030
# 21  [{'lat': 45.76737029006368, 'lng': -108.575822...  45.767370 -108.575823
# 22  [{'lat': 45.793141, 'lng': -108.519071, 'label...  45.793141 -108.519071
# 23  [{'lat': 45.76655150240635, 'lng': -108.576607...  45.766552 -108.576607
# 24  [{'lat': 45.7540786, 'lng': -108.5782676, 'lab...  45.754079 -108.578268
# 25  [{'lat': 45.783803, 'lng': -108.597782, 'label...  45.783803 -108.597782
# 26  [{'lat': 45.792977, 'lng': -108.518325, 'label...  45.792977 -108.518325
# 27  [{'lat': 45.76811346599074, 'lng': -108.573562...  45.768113 -108.573563
# 28  [{'lat': 45.75999, 'lng': -108.564108, 'label'...  45.759990 -108.564108
# 29  [{'lat': 45.78282279068451, 'lng': -108.506696...  45.782823 -108.506696
# 30  [{'lat': 45.76095400137561, 'lng': -108.575460...  45.760954 -108.575461
# 31  [{'lat': 45.782867, 'lng': -108.504476, 'label...  45.782867 -108.504476
# 32  [{'lat': 45.75612831666667, 'lng': -108.568021...  45.756128 -108.568021
# 33  [{'lat': 45.79406135396124, 'lng': -108.514486...  45.794061 -108.514486
# 34  [{'lat': 45.80374675604687, 'lng': -108.537151...  45.803747 -108.537152
# 35  [{'lat': 45.78312692607741, 'lng': -108.501571...  45.783127 -108.501571
# 36  [{'lat': 45.7789464, 'lng': -108.5127427, 'lab...  45.778946 -108.512743
# 37  [{'lat': 45.75483760428098, 'lng': -108.614128...  45.754838 -108.614129
# 38  [{'lat': 45.753489193379544, 'lng': -108.57492...  45.753489 -108.574923
# 39  [{'lat': 45.783109, 'lng': -108.505819, 'label...  45.783109 -108.505819
# 40  [{'lat': 45.77939435952856, 'lng': -108.510012...  45.779394 -108.510013
# 41  [{'lat': 45.7535497, 'lng': -108.576135, 'labe...  45.753550 -108.576135
# 42  [{'lat': 45.78684113226233, 'lng': -108.592490...  45.786841 -108.592490
# 43  [{'lat': 45.78329, 'lng': -108.50823, 'label':...  45.783290 -108.508230
# 44  [{'lat': 45.781642, 'lng': -108.50711, 'label'...  45.781642 -108.507110
# 45  [{'lat': 45.75983338231644, 'lng': -108.574483...  45.759833 -108.574483
# 46  [{'lat': 45.788524461996786, 'lng': -108.50440...  45.788524 -108.504407
# 47  [{'lat': 45.7462893, 'lng': -108.5528737, 'lab...  45.746289 -108.552874
# 48  [{'lat': 45.788319, 'lng': -108.501438, 'label...  45.788319 -108.501438
# 49  [{'lat': 45.747573998572236, 'lng': -108.55459...  45.747574 -108.554596
#
#    neighborhood postalCode state                        id
# 0           NaN      59101    MT  58a9ad9c2948b344b7704b88
# 1           NaN      59101    MT  503520a9e4b0272a4de301ff
# 2           NaN      59101    MT  4f322ada19836c91c7bccd42
# 3           NaN      59102    MT  4b85967df964a520156731e3
# 4           NaN        NaN    MT  4f3261a519836c91c7d23d55
# 5           NaN        NaN    MT  575c3930498eabc9389298fe
# 6           NaN      59101    MT  4dd187f6d22d67839c47c29d
# 7           NaN        NaN    MT  4f3224fb19836c91c7ba835f
# 8           NaN      59102    MT  595a90cb1de76542ca46d019
# 9           NaN      59102    MT  4f3222b719836c91c7b99b82
# 10          NaN      59102    MT  4b3651a4f964a520c73225e3
# 11          NaN      59102    MT  50b1475be4b0d4508c001a87
# 12          NaN      59102    MT  4c606cfb924b76b0d7cef0b9
# 13          NaN      59102    MT  4c193528fe5a76b0cb3c0315
# 14          NaN        NaN    MT  58796acde0adac0ce98fe4a8
# 15          NaN      59102    MT  4cd0780d6449a0938ccbcacf
# 16          NaN      59101    MT  57369584498ea44d0c2d3cbb
# 17          NaN      59102    MT  4f326c2919836c91c7d64d21
# 18          NaN      59102    MT  4bd98ef80115c9b6e6af7780
# 19          NaN      59102    MT  4f325c8319836c91c7d03ba3
# 20          NaN      59101    MT  4b859620f964a520026731e3
# 21          NaN      59102    MT  4dc71880b0fb5556cd1a1c57
# 22          NaN      59101    MT  5aa0056ecf72a0487e755f34
# 23          NaN      59102    MT  4fe8e2d5e4b0d5efa51c7eb5
# 24          NaN      59102    MT  4baf9fd0f964a52015113ce3
# 25          NaN      59102    MT  58559bae109dfe314276b1ed
# 26          NaN      59101    MT  4f3260e519836c91c7d1f17e
# 27          NaN      59102    MT  5079b7c8e4b034705318b09b
# 28          NaN      59102    MT  5552aec3498e51c5935022e4
# 29     Downtown      59101    MT  4be359d4cbdbef3b0a9360d8
# 30          NaN      59102    MT  4fdf4722e4b03622b26e4ad3
# 31     Downtown      59101    MT  4b9d4282f964a520df9d36e3
# 32          NaN      59101    MT  4c7bd1d897028cfa43f1e1fe
# 33          NaN      59101    MT  5b4640ecb8fd9d002c8b673e
# 34          NaN      59105    MT  50d057dce4b08cc4922cb03c
# 35          NaN      59101    MT  574a5612498e1c0c6fb946a1
# 36          NaN      59101    MT  5106de12e4b056a13ae698a2
# 37     West End      59102    MT  4c715800df6b8cfad4bcba4d
# 38          NaN      59102    MT  4b8c0593f964a5200eb932e3
# 39          NaN      59101    MT  56d772f4498ea2397473477c
# 40          NaN      59101    MT  4b941d4cf964a520166934e3
# 41          NaN      59102    MT  5a09d6548e886a27c46bba17
# 42          NaN        NaN    MT  52bde6a411d27ee2c3968811
# 43          NaN      59101    MT  51ed9a4c498ed28755796d81
# 44          NaN      59101    MT  4f322a0019836c91c7bc79c8
# 45          NaN      59102    MT  4ee23e180e61689f53c1c392
# 46          NaN        NaN    MT  533eed73498ef078be43a618
# 47          NaN      59101    MT  591d4439f427de196f13e5e3
# 48          NaN        NaN    MT  51bf16c0e4b0b87136edfc74
# 49          NaN      59101    MT  5a54ee02b04056149962378f

# %%
dataframe_filtered.name
# Out:
# 0     Stirrup Coffee Shop
# 1     Himmelberger Brewing Company Coffee Shop
# 2     Lighthouse Coffee Shop
# 3     City Brew Coffee
# 4     Musgraves Gourmet Coffee
# 5     Colin's Bike Shop
# 6     Coffee Mill Espresso and More
# 7     The Coffee Mill
# 8     Big Sky Coffee Roasters
# 9     Black Dog Coffee House
# 10    Off the Leaf Coffee Bar
# 11    The Bike Shop
# 12    City Brew Coffee
# 13    Starbucks
# 14    Coffee Tavern
# 15    Casablanca Coffee 2
# 16    City Brew Coffee
# 17    MaAV Coffee House
# 18    The Spoke Shop
# 19    Billings Barber Shop
# 20    MoAV Coffee House
# 21    City Brew Coffee
# 22    Coffee Mill Coffee & More
# 23    Musgraves Gourmet Coffee
# 24    Mountain Mudd Espresso
# 25    Casablanca Coffee Kiosk
# 26    Pat's Hotrod Shop
# 27    Hanks Body Shop Inc
# 28    Rock Creek Coffee Roasters
# 29    Smitty's Smoke Shop
# 30    City Brew Coffee North
# 31    City Brew
# 32    Bighorn Fly & Tackle Shop
# 33    the big cup of coffee
# 34    Becker's Glass Shop, Inc
# 35    Ballistic Barber Shop
# 36    Accent print shop
# 37    The Rubber Stamp Shop
# 38    Yellowstone Sandwich Shop
# 39    City Brew Coffee
# 40    Thrift Shop
# 41    Mega Bud Shop
# 42    Omega Chemicals Online Shop
# 43    The Vape Shop Pros
# 44    Farmer Brothers Coffee Company
# 45    Boyd Coffee Co
# 46    Brake Shop
# 47    Veronika's Pastry Shop
# 48    Castle Coffee
# 49    Al's Bootery & Repair Shop
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
#folium.features.CircleMarker(
  #  [latitude, longitude],
 #   radius=10,
  #  color='red',
  #  popup='CenterPoint',
  #  fill = True,
 #   fill_color = 'red',
  #  fill_opacity = 0.6
#).add_to(venues_map)

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# explore a given venue
venue_id = '4be359d4cbdbef3b0a9360d8' # ID of Rock Creek Roasters
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4be359d4cbdbef3b0a9360d8?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&v=20180604'

# %%
# send get request 
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['beenHere', 'photos', 'timeZone', 'specials', 'contact', 'verified', 'hereNow', 'pageUpdates', 'price', 'reasons', 'id', 'inbox', 'name', 'canonicalUrl', 'allowMenuUrlEdit', 'location', 'ok', 'tips', 'categories', 'attributes', 'listed', 'stats', 'shortUrl', 'createdAt', 'dislike', 'likes'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}],
#     'name': 'Price',
#     'summary': '$',
#     'type': 'price'}]},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'canonicalUrl': 'https://foursquare.com/v/mountain-mudd-espresso/4c7bd1d897028cfa43f1e1fe',
#  'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'primary': True,
#    'shortName': 'Coffee Shop'}],
#  'contact': {},
#  'createdAt': 1283183064,
#  'dislike': False,
#  'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
#  'id': '4c7bd1d897028cfa43f1e1fe',
#  'inbox': {'count': 0, 'items': []},
#  'likes': {'count': 0, 'groups': []},
#  'listed': {'count': 0,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': 'Lists from other people',
#     'type': 'others'}]},
#  'location': {'address': '2120 3rd Ave N',
#   'cc': 'US',
#   'city': 'Billings',
#   'country': 'United States',
#   'formattedAddress': ['2120 3rd Ave N',
#    'Billings, MT 59101',
#    'United States'],
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 45.75612831666667,
#     'lng': -108.5680212}],
#   'lat': 45.75612831666667,
#   'lng': -108.5680212,
#   'postalCode': '59101',
#   'state': 'MT'},
#  'name': 'Mountain Mudd Espresso',
#  'ok': False,
#  'pageUpdates': {'count': 0, 'items': []},
#  'photos': {'count': 0,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': "Friends' check-in photos",
#     'type': 'checkin'}],
#   'summary': 'No photos'},
#  'price': {'currency': '$', 'message': 'Cheap', 'tier': 1},
#  'reasons': {'count': 0, 'items': []},
#  'shortUrl': 'http://4sq.com/aQeJMF',
#  'specials': {'count': 0, 'items': []},
#  'stats': {'tipCount': 0},
#  'timeZone': 'America/Denver',
#  'tips': {'count': 0,
#   'groups': [{'count': 0, 'items': [], 'name': 'All tips', 'type': 'others'}]},
#  'verified': False}

# %%
# get rating - don't need for project but as example
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
# get number of tips
result['response']['venue']['tips']['count']
# Out:
# 0

# %%
# get venue tips
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce3fc999fb6b7757fe61293'},
#  'response': {'tips': {'count': 10,
#    'items': [{'agreeCount': 1,
#      'authorInteractionType': 'liked',
#      'canonicalUrl': 'https://foursquare.com/item/5c38c809cd441c002c65691b',
#      'createdAt': 1547225097,
#      'disagreeCount': 0,
#      'id': '5c38c809cd441c002c65691b',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'text': 'Best Mocha in Billings. Hours are more for the downtown crowd. It’s a nice treat when I can get down there.',
#      'todo': {'count': 0},
#      'type': 'user',
#      'user': {'firstName': 'Nicholas',
#       'gender': 'male',
#       'id': '475923',
#       'lastName': 'S',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/475923_6biwHhUs_PXOaGhLODVGsTVEg4EebintaSPdRD63aDzQw7030IdxZa8rVVo8GfnoD2eakvNnN.jpg'}}}]}}}

# %%
# get tips and list of associated features
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['text', 'createdAt', 'todo', 'lang', 'user', 'logView', 'disagreeCount', 'type', 'agreeCount', 'id', 'likes', 'authorInteractionType', 'canonicalUrl'])

# %%
# Format column width and display all tips
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                           text  \
# 0  Best Mocha in Billings. Hours are more for the downtown crowd. It’s a nice treat when I can get down there.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  1           0              5c38c809cd441c002c65691b  Nicholas
#
#   user.lastName user.gender user.id
# 0  S             male        475923

# %%
# search a foursquare user
user_id = '475923' # only one listed above

url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()
# Out:
# dict_keys(['photo', 'checkins', 'gender', 'canonicalUrl', 'type', 'friends', 'tips', 'homeCity', 'lastName', 'photos', 'contact', 'mayorships', 'lists', 'id', 'lenses', 'bio', 'firstName'])

# %%
print('First Name: ' + user_data['firstName'])
print('Last Name: ' + user_data['lastName'])
print('Home City: ' + user_data['homeCity'])
# Out:
# First Name: Nicholas
# Last Name: S
# Home City: Billings, MT

# %%
# how many tips has user submitted
user_data['tips']
# Out:
# {'count': 5}

# %%
# get all users tips - only one for this guy/gal
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                                                      text  \
# 0  Best Mocha in Billings. Hours are more for the downtown crowd. It’s a nice treat when I can get down there.
# 1  BBQ Chicken Pizza on original dough
# 2  If you have a young child, call ahead of time to make sure there is a barber available willing to cut their hair and if willing, if your child must sit by themselves.
# 3  Love the Spicy Pepperoni pizza!
# 4  The standard cut is now $18.  But I agree with the previous tip - Worth every penny.  Try to get the barber farthest from the door. She's the best!
#
#    agreeCount  disagreeCount                        id
# 0  1           0              5c38c809cd441c002c65691b
# 1  1           0              5bbffdab123a19002c06b138
# 2  0           0              55f2f875498e9ecb5f56d799
# 3  0           0              5327546e11d2596f0058810b
# 4  0           0              52cdd824498e6374904867b9

# %%
# get users friends
user_friends = json_normalize(user_data['friends']['groups'][0]['items'])
user_friends
# Out:
#   bio firstName gender        homeCity        id lastName  \
# 0      Jared     male   Pittsburgh, PA  5702689   Ross
# 1      Mark      male   Irvine, CA      1053475   Roboff
# 2      Waylon    male   Brooklyn        30615004  Lu
#
#                                      lists.groups  \
# 0  [{'items': [], 'type': 'created', 'count': 2}]
# 1  [{'items': [], 'type': 'created', 'count': 2}]
# 2  [{'items': [], 'type': 'created', 'count': 2}]
#
#                         photo.prefix  \
# 0  https://fastly.4sqi.net/img/user/
# 1  https://fastly.4sqi.net/img/user/
# 2  https://fastly.4sqi.net/img/user/
#
#                                                                              photo.suffix  \
# 0  /5B1YJHY0GU55DY1X.jpg
# 1  /1053475_TanRQrT-_EXfwmoycglbie2CNi0gZnmvIw-VM4Amt2WPsUW2cjNeBU90gOwe2mmWluajj1_0p.jpg
# 2  /EW445G3K3TI2P3OZ.jpg
#
#    tips.count
# 0  9
# 1  1
# 2  1

# %%
# retrieve user profile image
user_data
# Out:
# {'bio': '',
#  'canonicalUrl': 'https://foursquare.com/user/475923',
#  'checkins': {'count': 3405, 'items': []},
#  'contact': {},
#  'firstName': 'Nicholas',
#  'friends': {'count': 3,
#   'groups': [{'count': 3,
#     'items': [{'bio': '',
#       'contact': {},
#       'firstName': 'Jared',
#       'gender': 'male',
#       'homeCity': 'Pittsburgh, PA',
#       'id': '5702689',
#       'lastName': 'Ross',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/5B1YJHY0GU55DY1X.jpg'},
#       'tips': {'count': 9}},
#      {'bio': '',
#       'contact': {},
#       'firstName': 'Mark',
#       'gender': 'male',
#       'homeCity': 'Irvine, CA',
#       'id': '1053475',
#       'lastName': 'Roboff',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/1053475_TanRQrT-_EXfwmoycglbie2CNi0gZnmvIw-VM4Amt2WPsUW2cjNeBU90gOwe2mmWluajj1_0p.jpg'},
#       'tips': {'count': 1}},
#      {'bio': '',
#       'contact': {},
#       'firstName': 'Waylon',
#       'gender': 'male',
#       'homeCity': 'Brooklyn',
#       'id': '30615004',
#       'lastName': 'Lu',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/EW445G3K3TI2P3OZ.jpg'},
#       'tips': {'count': 1}}],
#     'name': 'Other friends',
#     'type': 'others'}]},
#  'gender': 'male',
#  'homeCity': 'Billings, MT',
#  'id': '475923',
#  'lastName': 'S',
#  'lenses': [],
#  'lists': {'count': 2,
#   'groups': [{'count': 0, 'items': [], 'type': 'created'},
#    {'count': 0, 'items': [], 'type': 'followed'},
#    {'count': 2,
#     'items': [{'canonicalUrl': 'https://foursquare.com/user/475923/list/todos',
#       'collaborative': False,
#       'description': '',
#       'editable': False,
#       'id': '475923/todos',
#       'listItems': {'count': 0},
#       'name': "Nicholas's Saved Places",
#       'public': True,
#       'type': 'todos',
#       'url': '/user/475923/list/todos'},
#      {'canonicalUrl': 'https://foursquare.com/user/475923/list/venuelikes',
#       'collaborative': False,
#       'description': '',
#       'editable': False,
#       'id': '475923/venuelikes',
#       'listItems': {'count': 0},
#       'name': 'Nicholas’s Liked Places',
#       'public': True,
#       'type': 'likes',
#       'url': '/user/475923/list/venuelikes'}],
#     'type': 'yours'}]},
#  'mayorships': {'count': 0, 'items': []},
#  'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#   'suffix': '/475923_6biwHhUs_PXOaGhLODVGsTVEg4EebintaSPdRD63aDzQw7030IdxZa8rVVo8GfnoD2eakvNnN.jpg'},
#  'photos': {'count': 0, 'items': []},
#  'tips': {'count': 5},
#  'type': 'user'}

# %%
# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://fastly.4sqi.net/img/user/300x300/475923_6biwHhUs_PXOaGhLODVGsTVEg4EebintaSPdRD63aDzQw7030IdxZa8rVVo8GfnoD2eakvNnN.jpg')
# Out:
# <img src="https://fastly.4sqi.net/img/user/300x300/475923_6biwHhUs_PXOaGhLODVGsTVEg4EebintaSPdRD63aDzQw7030IdxZa8rVVo8GfnoD2eakvNnN.jpg"/>

# %%
#explore a location
latitude = 45.784127
longitude = -108.557717

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=45.784127,-108.557717&v=20180604&radius=5000&limit=30'

# %%
#send get
import requests

# %%
#examine results
results = requests.get(url).json()
'There are {} around Billings point.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Billings point.'

# %%
# get relavent part of json
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-531e565711d212634540e19c-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d118951735',
#     'name': 'Grocery Store',
#     'pluralName': 'Grocery Stores',
#     'primary': True,
#     'shortName': 'Grocery Store'}],
#   'id': '531e565711d212634540e19c',
#   'location': {'address': '1603 Grand Ave #135',
#    'cc': 'US',
#    'city': 'Billings',
#    'country': 'United States',
#    'distance': 129,
#    'formattedAddress': ['1603 Grand Ave #135',
#     'Billings, MT 59102',
#     'United States'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 45.78528713558546,
#      'lng': -108.55769883792851}],
#    'lat': 45.78528713558546,
#    'lng': -108.55769883792851,
#    'postalCode': '59102',
#    'state': 'MT'},
#   'name': "Lucky's Market",
#   'photos': {'count': 0, 'groups': []}}}

# %%
# Process JSON and convert it to a clean dataframe
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                          name           categories  \
# 0  Lucky's Market                              Grocery Store
# 1  Red Robin Gourmet Burgers and Brews         Burger Joint
# 2  Fancy Sushi                                 Sushi Restaurant
# 3  Panda Express                               Chinese Restaurant
# 4  Off the Leaf Coffee Bar                     Coffee Shop
# 5  Caramel Cookie Waffles Restaurant & Bakery  Soup Place
# 6  Starbucks                                   Coffee Shop
# 7  The Granary                                 American Restaurant
# 8  Jimmy John's                                Sandwich Place
# 9  Softie's                                    Ice Cream Shop
#
#                   address  cc      city        country   crossStreet  \
# 0  1603 Grand Ave #135     US  Billings  United States  NaN
# 1  1595 Grand Ave Ste 210  US  Billings  United States  NaN
# 2  1313 Grand Ave Ste 3    US  Billings  United States  NaN
# 3  15th & Grand            US  Billings  United States  NaN
# 4  819 Grand Ave           US  Billings  United States  NaN
# 5  1707 17th St W          US  Billings  United States  NaN
# 6  910 Grand Ave           US  Billings  United States  at 9th St W
# 7  1500 Poly Dr            US  Billings  United States  NaN
# 8  805 24th St W Ste 11    US  Billings  United States  NaN
# 9  2407 Broadwater Ave     US  Billings  United States  at 24th St W
#
#    distance  \
# 0  129
# 1  174
# 2  616
# 3  143
# 4  1604
# 5  392
# 6  1457
# 7  1201
# 8  1590
# 9  1661
#
#                                                           formattedAddress  \
# 0  [1603 Grand Ave #135, Billings, MT 59102, United States]
# 1  [1595 Grand Ave Ste 210, Billings, MT 59102, United States]
# 2  [1313 Grand Ave Ste 3, Billings, MT 59102, United States]
# 3  [15th & Grand, Billings, MT 59101, United States]
# 4  [819 Grand Ave, Billings, MT 59102, United States]
# 5  [1707 17th St W, Billings, MT 59102, United States]
# 6  [910 Grand Ave (at 9th St W), Billings, MT 59102, United States]
# 7  [1500 Poly Dr, Billings, MT 59102, United States]
# 8  [805 24th St W Ste 11, Billings, MT 59102, United States]
# 9  [2407 Broadwater Ave (at 24th St W), Billings, MT 59102, United States]
#
#                                                                   labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 45.78528713558546, 'lng': -108.55769883792851}]
# 1  [{'label': 'display', 'lat': 45.78516460863479, 'lng': -108.55602533520695}]
# 2  [{'label': 'display', 'lat': 45.78442744647436, 'lng': -108.54978213638505}]
# 3  [{'label': 'display', 'lat': 45.7844296634073, 'lng': -108.55592043750822}]
# 4  [{'label': 'display', 'lat': 45.78435172937381, 'lng': -108.53705234643124}]
# 5  [{'label': 'display', 'lat': 45.78758019634092, 'lng': -108.55874751020816}]
# 6  [{'label': 'display', 'lat': 45.78380071493462, 'lng': -108.5389466192453}]
# 7  [{'label': 'display', 'lat': 45.794399051953896, 'lng': -108.55294440894728}]
# 8  [{'label': 'display', 'lat': 45.77774493055638, 'lng': -108.57604127399003}]
# 9  [{'label': 'display', 'lat': 45.77721785464744, 'lng': -108.5766851154197}]
#
#          lat         lng            neighborhood postalCode state  \
# 0  45.785287 -108.557699  NaN                     59102      MT
# 1  45.785165 -108.556025  NaN                     59102      MT
# 2  45.784427 -108.549782  NaN                     59102      MT
# 3  45.784430 -108.555920  NaN                     59101      MT
# 4  45.784352 -108.537052  NaN                     59102      MT
# 5  45.787580 -108.558748  NaN                     59102      MT
# 6  45.783801 -108.538947  NaN                     59102      MT
# 7  45.794399 -108.552944  NaN                     59102      MT
# 8  45.777745 -108.576041  NaN                     59102      MT
# 9  45.777218 -108.576685  West End, Billings, MT  59102      MT
#
#                          id
# 0  531e565711d212634540e19c
# 1  4b649525f964a5208dbf2ae3
# 2  4dbb39071e72b351ca93d0aa
# 3  4d1153e40c786ea80d14d0ab
# 4  4b3651a4f964a520c73225e3
# 5  4bb78345cf2fc9b618509e02
# 6  541db26e498e63d8cb364844
# 7  4b663e69f964a520661a2be3
# 8  514213c43d7ca5b4135aa491
# 9  4c0328c20d0e0f475c47029a

# %%
#Let's visualize these items on the map around our location
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Billings',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# trending in Billings?
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce3fea69fb6b775bbb9bd2a'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
# visual trending
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %%
# above was following the FourSquare API lab and adapting it to Billings Montana - all worked well.

# %%
# Next do bar in Billings

# %%
search_query = 'bar'
categoryId = '4d4b7105d754a06376d81259' # nightlife spot
radius = 50000
print(search_query + ' .... OK!')
# Out:
# bar .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT, categoryId)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=45.784127338925,-108.557717907471&v=20180604&query=bar&radius=50000&limit=100&categoryId=4d4b7105d754a06376d81259'

# %%
# get requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce448f64434b921400c3b2c'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '56c55b62cd106598ec3de19b',
#     'location': {'address': '1600 Avenue D',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 317,
#      'formattedAddress': ['1600 Avenue D',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7868314,
#        'lng': -108.5564183}],
#      'lat': 45.7868314,
#      'lng': -108.5564183,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Shooters Casino & Sports Bar',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4bce8489937ca5931fc4ae92',
#     'location': {'address': '1511 Central Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1599,
#      'formattedAddress': ['1511 Central Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.76994199554368,
#        'lng': -108.5544603866783}],
#      'lat': 45.76994199554368,
#      'lng': -108.5544603866783,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Bucks Bar',
#     'referralId': 'v-1558464758',
#     'venuePage': {'id': '87875843'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'primary': True,
#       'shortName': 'Wine Bar'}],
#     'hasPerk': False,
#     'id': '4f321a5619836c91c7b620c1',
#     'location': {'address': '1640 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': 'at 17th St W',
#      'distance': 87,
#      'formattedAddress': ['1640 Grand Ave (at 17th St W)',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78389583225354,
#        'lng': -108.55879962444304}],
#      'lat': 45.78389583225354,
#      'lng': -108.55879962444304,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'City Vineyard Wine Bar',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11d941735',
#       'name': 'Sports Bar',
#       'pluralName': 'Sports Bars',
#       'primary': True,
#       'shortName': 'Sports Bar'}],
#     'hasPerk': False,
#     'id': '4ba2e9d8f964a520392238e3',
#     'location': {'address': '1600 Avenue D',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 314,
#      'formattedAddress': ['1600 Avenue D',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78682884105392,
#        'lng': -108.55651188036636}],
#      'lat': 45.78682884105392,
#      'lng': -108.55651188036636,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Shooters Sports Bar',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b3651a4f964a520c73225e3',
#     'location': {'address': '819 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1604,
#      'formattedAddress': ['819 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78435172937381,
#        'lng': -108.53705234643124}],
#      'lat': 45.78435172937381,
#      'lng': -108.53705234643124,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Off the Leaf Coffee Bar',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4f32c92d19836c91c7fa7345',
#     'location': {'address': '321 Glee Pl',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1357,
#      'formattedAddress': ['321 Glee Pl',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.773157,
#        'lng': -108.565362}],
#      'lat': 45.773157,
#      'lng': -108.565362,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Goofies Bar and Grill',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11d941735',
#       'name': 'Sports Bar',
#       'pluralName': 'Sports Bars',
#       'primary': True,
#       'shortName': 'Sports Bar'}],
#     'hasPerk': False,
#     'id': '55e14a35498e25aa1e6629d8',
#     'location': {'address': '905 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1465,
#      'formattedAddress': ['905 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78451,
#        'lng': -108.538842}],
#      'lat': 45.78451,
#      'lng': -108.538842,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Grandstand Sports Bar and Casino',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '58090bb738fa83fadfd2a95e',
#     'location': {'address': '1233 N 27th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3424,
#      'formattedAddress': ['1233 N 27th St', 'Billings, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.79524551443195,
#        'lng': -108.5165855773255}],
#      'lat': 45.79524551443195,
#      'lng': -108.5165855773255,
#      'state': 'MT'},
#     'name': '406 Bar',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4f32bbbf19836c91c7f48cdf',
#     'location': {'address': '1 US Highway 3',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2077,
#      'formattedAddress': ['1 US Highway 3', 'Billings, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.8026,
#        'lng': -108.553871}],
#      'lat': 45.8026,
#      'lng': -108.553871,
#      'state': 'MT'},
#     'name': 'Cozy Corner Bar',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11d941735',
#       'name': 'Sports Bar',
#       'pluralName': 'Sports Bars',
#       'primary': True,
#       'shortName': 'Sports Bar'}],
#     'hasPerk': False,
#     'id': '4b9b312ef964a520fef835e3',
#     'location': {'address': '1744 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 266,
#      'formattedAddress': ['1744 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7838121199554,
#        'lng': -108.56112385171296}],
#      'lat': 45.7838121199554,
#      'lng': -108.56112385171296,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': "Cadillac Jax's",
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11d941735',
#       'name': 'Sports Bar',
#       'pluralName': 'Sports Bars',
#       'primary': True,
#       'shortName': 'Sports Bar'}],
#     'hasPerk': False,
#     'id': '4c27f3e09fb5d13a04f29857',
#     'location': {'address': '5104 Southgate Dr',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3620,
#      'formattedAddress': ['5104 Southgate Dr',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.75341638556679,
#        'lng': -108.54237565782432}],
#      'lat': 45.75341638556679,
#      'lng': -108.54237565782432,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': "Fiddler's Green Sports Bar",
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '56628484498e8952482ba00a',
#     'location': {'address': '4020 Montana Sapphire Dr',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 5887,
#      'formattedAddress': ['4020 Montana Sapphire Dr',
#       'Billings, MT 59106',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7521847,
#        'lng': -108.6181482}],
#      'lat': 45.7521847,
#      'lng': -108.6181482,
#      'postalCode': '59106',
#      'state': 'MT'},
#     'name': 'The Divide Bar & Grill',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '4b4eac72f964a520d2f326e3',
#     'location': {'address': '113 N 28th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 4007,
#      'formattedAddress': ['113 N 28th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.782575988969484,
#        'lng': -108.50613743593512}],
#      'lat': 45.782575988969484,
#      'lng': -108.50613743593512,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Montana Brewing Company',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4ba4620ef964a520f09938e3',
#     'location': {'address': '2658 Grand Ave',
#      'cc': 'US',
#      'city': 'Yellowstone County',
#      'country': 'United States',
#      'distance': 1975,
#      'formattedAddress': ['2658 Grand Ave',
#       'Yellowstone County, MT',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78378287447059,
#        'lng': -108.5831564888471}],
#      'lat': 45.78378287447059,
#      'lng': -108.5831564888471,
#      'state': 'MT'},
#     'name': 'Hudsons',
#     'referralId': 'v-1558464758'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4e39b746c65bab738fd34ac6',
#     'location': {'cc': 'US',
#      'country': 'United States',
#      'distance': 23096,
#      'formattedAddress': ['Montana', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.89624848937236,
#        'lng': -108.30712744075109}],
#      'lat': 45.89624848937236,
#      'lng': -108.30712744075109,
#      'state': 'Montana'},
#     'name': 'Blue Cat Bar & Grille',
#     'referralId': 'v-1558464758'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Bar', 'primary': True, 'icon':...    False
# 1  [{'shortName': 'Bar', 'primary': True, 'icon':...    False
# 2  [{'shortName': 'Wine Bar', 'primary': True, 'i...    False
# 3  [{'shortName': 'Sports Bar', 'primary': True, ...    False
# 4  [{'shortName': 'Coffee Shop', 'primary': True,...    False
#
#                          id  location.address location.cc location.city  \
# 0  56c55b62cd106598ec3de19b     1600 Avenue D          US      Billings
# 1  4bce8489937ca5931fc4ae92  1511 Central Ave          US      Billings
# 2  4f321a5619836c91c7b620c1    1640 Grand Ave          US      Billings
# 3  4ba2e9d8f964a520392238e3     1600 Avenue D          US      Billings
# 4  4b3651a4f964a520c73225e3     819 Grand Ave          US      Billings
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN                317
# 1    United States                  NaN               1599
# 2    United States         at 17th St W                 87
# 3    United States                  NaN                314
# 4    United States                  NaN               1604
#
#                            location.formattedAddress  \
# 0  [1600 Avenue D, Billings, MT 59102, United Sta...
# 1  [1511 Central Ave, Billings, MT 59102, United ...
# 2  [1640 Grand Ave (at 17th St W), Billings, MT 5...
# 3  [1600 Avenue D, Billings, MT 59102, United Sta...
# 4  [819 Grand Ave, Billings, MT 59102, United Sta...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 45.7868314, 'lng': -108.5564183, 'lab...     45.786831
# 1  [{'lat': 45.76994199554368, 'lng': -108.554460...     45.769942
# 2  [{'lat': 45.78389583225354, 'lng': -108.558799...     45.783896
# 3  [{'lat': 45.78682884105392, 'lng': -108.556511...     45.786829
# 4  [{'lat': 45.78435172937381, 'lng': -108.537052...     45.784352
#
#    location.lng location.postalCode location.state  \
# 0   -108.556418               59102             MT
# 1   -108.554460               59102             MT
# 2   -108.558800               59102             MT
# 3   -108.556512               59102             MT
# 4   -108.537052               59102             MT
#
#                            name    referralId venuePage.id
# 0  Shooters Casino & Sports Bar  v-1558464758          NaN
# 1                     Bucks Bar  v-1558464758     87875843
# 2        City Vineyard Wine Bar  v-1558464758          NaN
# 3           Shooters Sports Bar  v-1558464758          NaN
# 4       Off the Leaf Coffee Bar  v-1558464758          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                 name   categories                   address  \
# 0       Shooters Casino & Sports Bar          Bar             1600 Avenue D
# 1                          Bucks Bar          Bar          1511 Central Ave
# 2             City Vineyard Wine Bar     Wine Bar            1640 Grand Ave
# 3                Shooters Sports Bar   Sports Bar             1600 Avenue D
# 4            Off the Leaf Coffee Bar  Coffee Shop             819 Grand Ave
# 5              Goofies Bar and Grill          Bar               321 Glee Pl
# 6   Grandstand Sports Bar and Casino   Sports Bar             905 Grand Ave
# 7                            406 Bar          Bar            1233 N 27th St
# 8                    Cozy Corner Bar          Bar            1 US Highway 3
# 9                     Cadillac Jax's   Sports Bar            1744 Grand Ave
# 10        Fiddler's Green Sports Bar   Sports Bar         5104 Southgate Dr
# 11            The Divide Bar & Grill          Pub  4020 Montana Sapphire Dr
# 12           Montana Brewing Company      Brewery             113 N 28th St
# 13                           Hudsons          Bar            2658 Grand Ave
# 14             Blue Cat Bar & Grille          Bar                       NaN
#
#     cc                city        country   crossStreet  distance  \
# 0   US            Billings  United States           NaN       317
# 1   US            Billings  United States           NaN      1599
# 2   US            Billings  United States  at 17th St W        87
# 3   US            Billings  United States           NaN       314
# 4   US            Billings  United States           NaN      1604
# 5   US            Billings  United States           NaN      1357
# 6   US            Billings  United States           NaN      1465
# 7   US            Billings  United States           NaN      3424
# 8   US            Billings  United States           NaN      2077
# 9   US            Billings  United States           NaN       266
# 10  US            Billings  United States           NaN      3620
# 11  US            Billings  United States           NaN      5887
# 12  US            Billings  United States           NaN      4007
# 13  US  Yellowstone County  United States           NaN      1975
# 14  US                 NaN  United States           NaN     23096
#
#                                      formattedAddress  \
# 0   [1600 Avenue D, Billings, MT 59102, United Sta...
# 1   [1511 Central Ave, Billings, MT 59102, United ...
# 2   [1640 Grand Ave (at 17th St W), Billings, MT 5...
# 3   [1600 Avenue D, Billings, MT 59102, United Sta...
# 4   [819 Grand Ave, Billings, MT 59102, United Sta...
# 5    [321 Glee Pl, Billings, MT 59102, United States]
# 6   [905 Grand Ave, Billings, MT 59102, United Sta...
# 7       [1233 N 27th St, Billings, MT, United States]
# 8       [1 US Highway 3, Billings, MT, United States]
# 9   [1744 Grand Ave, Billings, MT 59102, United St...
# 10  [5104 Southgate Dr, Billings, MT 59101, United...
# 11  [4020 Montana Sapphire Dr, Billings, MT 59106,...
# 12  [113 N 28th St, Billings, MT 59101, United Sta...
# 13  [2658 Grand Ave, Yellowstone County, MT, Unite...
# 14                           [Montana, United States]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'lat': 45.7868314, 'lng': -108.5564183, 'lab...  45.786831 -108.556418
# 1   [{'lat': 45.76994199554368, 'lng': -108.554460...  45.769942 -108.554460
# 2   [{'lat': 45.78389583225354, 'lng': -108.558799...  45.783896 -108.558800
# 3   [{'lat': 45.78682884105392, 'lng': -108.556511...  45.786829 -108.556512
# 4   [{'lat': 45.78435172937381, 'lng': -108.537052...  45.784352 -108.537052
# 5   [{'lat': 45.773157, 'lng': -108.565362, 'label...  45.773157 -108.565362
# 6   [{'lat': 45.78451, 'lng': -108.538842, 'label'...  45.784510 -108.538842
# 7   [{'lat': 45.79524551443195, 'lng': -108.516585...  45.795246 -108.516586
# 8   [{'lat': 45.8026, 'lng': -108.553871, 'label':...  45.802600 -108.553871
# 9   [{'lat': 45.7838121199554, 'lng': -108.5611238...  45.783812 -108.561124
# 10  [{'lat': 45.75341638556679, 'lng': -108.542375...  45.753416 -108.542376
# 11  [{'lat': 45.7521847, 'lng': -108.6181482, 'lab...  45.752185 -108.618148
# 12  [{'lat': 45.782575988969484, 'lng': -108.50613...  45.782576 -108.506137
# 13  [{'lat': 45.78378287447059, 'lng': -108.583156...  45.783783 -108.583156
# 14  [{'lat': 45.89624848937236, 'lng': -108.307127...  45.896248 -108.307127
#
#    postalCode    state                        id
# 0       59102       MT  56c55b62cd106598ec3de19b
# 1       59102       MT  4bce8489937ca5931fc4ae92
# 2       59102       MT  4f321a5619836c91c7b620c1
# 3       59102       MT  4ba2e9d8f964a520392238e3
# 4       59102       MT  4b3651a4f964a520c73225e3
# 5       59102       MT  4f32c92d19836c91c7fa7345
# 6       59102       MT  55e14a35498e25aa1e6629d8
# 7         NaN       MT  58090bb738fa83fadfd2a95e
# 8         NaN       MT  4f32bbbf19836c91c7f48cdf
# 9       59102       MT  4b9b312ef964a520fef835e3
# 10      59101       MT  4c27f3e09fb5d13a04f29857
# 11      59106       MT  56628484498e8952482ba00a
# 12      59101       MT  4b4eac72f964a520d2f326e3
# 13        NaN       MT  4ba4620ef964a520f09938e3
# 14        NaN  Montana  4e39b746c65bab738fd34ac6

# %%
dataframe_filtered.name
# Out:
# 0         Shooters Casino & Sports Bar
# 1                            Bucks Bar
# 2               City Vineyard Wine Bar
# 3                  Shooters Sports Bar
# 4              Off the Leaf Coffee Bar
# 5                Goofies Bar and Grill
# 6     Grandstand Sports Bar and Casino
# 7                              406 Bar
# 8                      Cozy Corner Bar
# 9                       Cadillac Jax's
# 10          Fiddler's Green Sports Bar
# 11              The Divide Bar & Grill
# 12             Montana Brewing Company
# 13                             Hudsons
# 14               Blue Cat Bar & Grille
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
#folium.features.CircleMarker(
  #  [latitude, longitude],
 #   radius=10,
  #  color='red',
  #  popup='CenterPoint',
  #  fill = True,
 #   fill_color = 'red',
  #  fill_opacity = 0.6
#).add_to(venues_map)

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# search query by category
search_query = 'pharmacy'
categoryId = '4bf58dd8d48988d10f951735' # pharmacy
radius = 50000
print(search_query + ' .... OK!')
# Out:
# pharmacy .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT, categoryId)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=45.784127338925,-108.557717907471&v=20180604&query=pharmacy&radius=50000&limit=100&categoryId=4bf58dd8d48988d10f951735'

# %%
# get requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce449691ed21914c1550a5f'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5009a42be4b02ee07a7c22aa',
#     'location': {'address': '2043 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 881,
#      'formattedAddress': ['2043 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7843326,
#        'lng': -108.5690713}],
#      'lat': 45.7843326,
#      'lng': -108.5690713,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': "JURO's PHARMACY HEALTH & WELLNESS",
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4d8b9cfa0c4e41bd7048667f',
#     'location': {'address': '1311 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 651,
#      'formattedAddress': ['1311 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.789254603919595,
#        'lng': -108.561764158204}],
#      'lat': 45.789254603919595,
#      'lng': -108.561764158204,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'CVS pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5a3ef94817556227e485405c',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2593,
#      'formattedAddress': ['Billings, MT 59102', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.770274,
#        'lng': -108.530859}],
#      'lat': 45.770274,
#      'lng': -108.530859,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'CVS pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5cd097a2c66666002ca99761',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1451,
#      'formattedAddress': ['Billings, MT 59102', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.777169,
#        'lng': -108.54191}],
#      'lat': 45.777169,
#      'lng': -108.54191,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Billings Clinic Specialty Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4c1668e61b5cef3bbb7deec4',
#     'location': {'address': '1212 Grand St Billings',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 662,
#      'formattedAddress': ['1212 Grand St Billings',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.784765513563165,
#        'lng': -108.54922857562056}],
#      'lat': 45.784765513563165,
#      'lng': -108.54922857562056,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'CVS pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4c12813e8aedd13a554e5137',
#     'location': {'address': '2402 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1489,
#      'formattedAddress': ['2402 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.783733878025814,
#        'lng': -108.57689977394085}],
#      'lat': 45.783733878025814,
#      'lng': -108.57689977394085,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'CVS pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4c166aee1b5cef3b677eeec4',
#     'location': {'address': '511 Central Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2730,
#      'formattedAddress': ['511 Central Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.770269,
#        'lng': -108.528704}],
#      'lat': 45.770269,
#      'lng': -108.528704,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Albertsons Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5745e8a0498e90b028ec23b3',
#     'location': {'address': '1212 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 784,
#      'formattedAddress': ['1212 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.782658805819054,
#        'lng': -108.54783967148256}],
#      'lat': 45.782658805819054,
#      'lng': -108.54783967148256,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Albertsons Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5a37e3558ad62e7211882094',
#     'location': {'address': '1233 N 30th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3150,
#      'formattedAddress': ['1233 N 30th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.793161434542604,
#        'lng': -108.51925313472742}],
#      'lat': 45.793161434542604,
#      'lng': -108.51925313472742,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'SCL Health Pharmacy Services - Saint Vincent Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4c166a861b5cef3b497eeec4',
#     'location': {'address': '611 N 27th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3846,
#      'formattedAddress': ['611 N 27th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7880269,
#        'lng': -108.5084831}],
#      'lat': 45.7880269,
#      'lng': -108.5084831,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Albertsons Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5b918f1ee17910002ba14778',
#     'location': {'address': '1015 Broadwater Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1455,
#      'formattedAddress': ['1015 Broadwater Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.77735,
#        'lng': -108.54169}],
#      'lat': 45.77735,
#      'lng': -108.54169,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Specialty Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '59e8daed0a464d0d412fd48a',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3205,
#      'formattedAddress': ['Billings, MT 59101', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.792803,
#        'lng': -108.518342}],
#      'lat': 45.792803,
#      'lng': -108.518342,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Pharmacy One',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5745e8a0498e90b028ec23a7',
#     'location': {'address': '2334 Central Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2280,
#      'formattedAddress': ['2334 Central Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7679954,
#        'lng': -108.5758187}],
#      'lat': 45.7679954,
#      'lng': -108.5758187,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Albertsons Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5745e8a0498e90b028ec23bc',
#     'location': {'address': '3137 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2732,
#      'formattedAddress': ['3137 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7852696261156,
#        'lng': -108.59287939500064}],
#      'lat': 45.7852696261156,
#      'lng': -108.59287939500064,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Albertsons Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '551c1116498e6d8696180986',
#     'location': {'address': '2525 King Ave W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3609,
#      'formattedAddress': ['2525 King Ave W',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7552854021962,
#        'lng': -108.578949689312}],
#      'lat': 45.7552854021962,
#      'lng': -108.578949689312,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Walmart Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5091c3b4e4b0a82b99bacf37',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3531,
#      'formattedAddress': ['Billings, MT 59101', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78917931270237,
#        'lng': -108.51279962141288}],
#      'lat': 45.78917931270237,
#      'lng': -108.51279962141288,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Billings Clinic Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4f6caa24e4b032eb624d3f94',
#     'location': {'address': 'King Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': '24th St W',
#      'distance': 3890,
#      'formattedAddress': ['King Ave (24th St W)',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.76706813775725,
#        'lng': -108.51398665500909}],
#      'lat': 45.76706813775725,
#      'lng': -108.51398665500909,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'VA Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '55ce54c6498ef585bc13bf36',
#     'location': {'address': '4420 King Ave E',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 4068,
#      'formattedAddress': ['4420 King Ave E',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.755358,
#        'lng': -108.525397}],
#      'lat': 45.755358,
#      'lng': -108.525397,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': "Sam's Club Pharmacy",
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4c16694d1b5cef3bdf7deec4',
#     'location': {'address': '425 Main St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 7006,
#      'formattedAddress': ['425 Main St',
#       'Billings, MT 59105',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.80720543861389,
#        'lng': -108.47372531890869}],
#      'lat': 45.80720543861389,
#      'lng': -108.47372531890869,
#      'postalCode': '59105',
#      'state': 'MT'},
#     'name': 'CVS pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5745e8a0498e90b028ec23a4',
#     'location': {'address': '670 Main St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 7186,
#      'formattedAddress': ['670 Main St',
#       'Billings, MT 59105',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.8100783,
#        'lng': -108.4729272}],
#      'lat': 45.8100783,
#      'lng': -108.4729272,
#      'postalCode': '59105',
#      'state': 'MT'},
#     'name': 'Albertsons Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '551c1117498e6d8696183a3c',
#     'location': {'address': '1649 Main St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 8367,
#      'formattedAddress': ['1649 Main St',
#       'Billings, MT 59105',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.8287391891892,
#        'lng': -108.470932432432}],
#      'lat': 45.8287391891892,
#      'lng': -108.470932432432,
#      'postalCode': '59105',
#      'state': 'MT'},
#     'name': 'Walmart Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4d8b9cfa0c4e41bd9a48667f',
#     'location': {'address': '307 SE 4th St',
#      'cc': 'US',
#      'city': 'Laurel',
#      'country': 'United States',
#      'distance': 29549,
#      'formattedAddress': ['307 SE 4th St',
#       'Laurel, MT 59044',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.624754103049625,
#        'lng': -108.86168496601212}],
#      'lat': 45.624754103049625,
#      'lng': -108.86168496601212,
#      'postalCode': '59044',
#      'state': 'MT'},
#     'name': 'CVS pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4c1669a81b5cef3b047eeec4',
#     'location': {'address': '307 SE 4th St',
#      'cc': 'US',
#      'city': 'Laurel',
#      'country': 'United States',
#      'distance': 20959,
#      'formattedAddress': ['307 SE 4th St',
#       'Laurel, MT 59044',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.6649604162638,
#        'lng': -108.76653809052735}],
#      'lat': 45.6649604162638,
#      'lng': -108.76653809052735,
#      'postalCode': '59044',
#      'state': 'MT'},
#     'name': 'CVS pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '551c1119498e6d86961865a2',
#     'location': {'address': '101 Bernhardt Rd',
#      'cc': 'US',
#      'city': 'Laurel',
#      'country': 'United States',
#      'distance': 20404,
#      'formattedAddress': ['101 Bernhardt Rd',
#       'Laurel, MT 59044',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.66827,
#        'lng': -108.76118}],
#      'lat': 45.66827,
#      'lng': -108.76118,
#      'postalCode': '59044',
#      'state': 'MT'},
#     'name': 'Walmart Pharmacy',
#     'referralId': 'v-1558464873'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4c2f88fd7cc0c9b629e6eb9a',
#     'location': {'address': '111 E Main St',
#      'cc': 'US',
#      'city': 'Laurel',
#      'country': 'United States',
#      'distance': 20932,
#      'formattedAddress': ['111 E Main St',
#       'Laurel, MT 59044',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.66982019199341,
#        'lng': -108.77160113864664}],
#      'lat': 45.66982019199341,
#      'lng': -108.77160113864664,
#      'postalCode': '59044',
#      'state': 'MT'},
#     'name': "Gene's Pharmacy",
#     'referralId': 'v-1558464873'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Pharmacy', 'primary': True, 'i...    False
# 1  [{'shortName': 'Pharmacy', 'primary': True, 'i...    False
# 2  [{'shortName': 'Pharmacy', 'primary': True, 'i...    False
# 3  [{'shortName': 'Pharmacy', 'primary': True, 'i...    False
# 4  [{'shortName': 'Pharmacy', 'primary': True, 'i...    False
#
#                          id        location.address location.cc location.city  \
# 0  5009a42be4b02ee07a7c22aa          2043 Grand Ave          US      Billings
# 1  4d8b9cfa0c4e41bd7048667f          1311 Grand Ave          US      Billings
# 2  5a3ef94817556227e485405c                     NaN          US      Billings
# 3  5cd097a2c66666002ca99761                     NaN          US      Billings
# 4  4c1668e61b5cef3bbb7deec4  1212 Grand St Billings          US      Billings
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN                881
# 1    United States                  NaN                651
# 2    United States                  NaN               2593
# 3    United States                  NaN               1451
# 4    United States                  NaN                662
#
#                            location.formattedAddress  \
# 0  [2043 Grand Ave, Billings, MT 59102, United St...
# 1  [1311 Grand Ave, Billings, MT 59102, United St...
# 2                [Billings, MT 59102, United States]
# 3                [Billings, MT 59102, United States]
# 4  [1212 Grand St Billings, Billings, MT 59102, U...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 45.7843326, 'lng': -108.5690713, 'lab...     45.784333
# 1  [{'lat': 45.789254603919595, 'lng': -108.56176...     45.789255
# 2  [{'lat': 45.770274, 'lng': -108.530859, 'label...     45.770274
# 3  [{'lat': 45.777169, 'lng': -108.54191, 'label'...     45.777169
# 4  [{'lat': 45.784765513563165, 'lng': -108.54922...     45.784766
#
#    location.lng location.postalCode location.state  \
# 0   -108.569071               59102             MT
# 1   -108.561764               59102             MT
# 2   -108.530859               59102             MT
# 3   -108.541910               59102             MT
# 4   -108.549229               59102             MT
#
#                                  name    referralId
# 0   JURO's PHARMACY HEALTH & WELLNESS  v-1558464873
# 1                        CVS pharmacy  v-1558464873
# 2                        CVS pharmacy  v-1558464873
# 3  Billings Clinic Specialty Pharmacy  v-1558464873
# 4                        CVS pharmacy  v-1558464873

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name categories  \
# 0                   JURO's PHARMACY HEALTH & WELLNESS   Pharmacy
# 1                                        CVS pharmacy   Pharmacy
# 2                                        CVS pharmacy   Pharmacy
# 3                  Billings Clinic Specialty Pharmacy   Pharmacy
# 4                                        CVS pharmacy   Pharmacy
# 5                                        CVS pharmacy   Pharmacy
# 6                                 Albertsons Pharmacy   Pharmacy
# 7                                 Albertsons Pharmacy   Pharmacy
# 8   SCL Health Pharmacy Services - Saint Vincent P...   Pharmacy
# 9                                 Albertsons Pharmacy   Pharmacy
# 10                                 Specialty Pharmacy   Pharmacy
# 11                                       Pharmacy One   Pharmacy
# 12                                Albertsons Pharmacy   Pharmacy
# 13                                Albertsons Pharmacy   Pharmacy
# 14                                   Walmart Pharmacy   Pharmacy
# 15                           Billings Clinic Pharmacy   Pharmacy
# 16                                        VA Pharmacy   Pharmacy
# 17                                Sam's Club Pharmacy   Pharmacy
# 18                                       CVS pharmacy   Pharmacy
# 19                                Albertsons Pharmacy   Pharmacy
# 20                                   Walmart Pharmacy   Pharmacy
# 21                                       CVS pharmacy   Pharmacy
# 22                                       CVS pharmacy   Pharmacy
# 23                                   Walmart Pharmacy   Pharmacy
# 24                                    Gene's Pharmacy   Pharmacy
#
#                    address  cc      city        country crossStreet  distance  \
# 0           2043 Grand Ave  US  Billings  United States         NaN       881
# 1           1311 Grand Ave  US  Billings  United States         NaN       651
# 2                      NaN  US  Billings  United States         NaN      2593
# 3                      NaN  US  Billings  United States         NaN      1451
# 4   1212 Grand St Billings  US  Billings  United States         NaN       662
# 5           2402 Grand Ave  US  Billings  United States         NaN      1489
# 6          511 Central Ave  US  Billings  United States         NaN      2730
# 7           1212 Grand Ave  US  Billings  United States         NaN       784
# 8           1233 N 30th St  US  Billings  United States         NaN      3150
# 9            611 N 27th St  US  Billings  United States         NaN      3846
# 10     1015 Broadwater Ave  US  Billings  United States         NaN      1455
# 11                     NaN  US  Billings  United States         NaN      3205
# 12        2334 Central Ave  US  Billings  United States         NaN      2280
# 13          3137 Grand Ave  US  Billings  United States         NaN      2732
# 14         2525 King Ave W  US  Billings  United States         NaN      3609
# 15                     NaN  US  Billings  United States         NaN      3531
# 16                King Ave  US  Billings  United States   24th St W      3890
# 17         4420 King Ave E  US  Billings  United States         NaN      4068
# 18             425 Main St  US  Billings  United States         NaN      7006
# 19             670 Main St  US  Billings  United States         NaN      7186
# 20            1649 Main St  US  Billings  United States         NaN      8367
# 21           307 SE 4th St  US    Laurel  United States         NaN     29549
# 22           307 SE 4th St  US    Laurel  United States         NaN     20959
# 23        101 Bernhardt Rd  US    Laurel  United States         NaN     20404
# 24           111 E Main St  US    Laurel  United States         NaN     20932
#
#                                      formattedAddress  \
# 0   [2043 Grand Ave, Billings, MT 59102, United St...
# 1   [1311 Grand Ave, Billings, MT 59102, United St...
# 2                 [Billings, MT 59102, United States]
# 3                 [Billings, MT 59102, United States]
# 4   [1212 Grand St Billings, Billings, MT 59102, U...
# 5   [2402 Grand Ave, Billings, MT 59102, United St...
# 6   [511 Central Ave, Billings, MT 59102, United S...
# 7   [1212 Grand Ave, Billings, MT 59102, United St...
# 8   [1233 N 30th St, Billings, MT 59101, United St...
# 9   [611 N 27th St, Billings, MT 59101, United Sta...
# 10  [1015 Broadwater Ave, Billings, MT 59102, Unit...
# 11                [Billings, MT 59101, United States]
# 12  [2334 Central Ave, Billings, MT 59102, United ...
# 13  [3137 Grand Ave, Billings, MT 59102, United St...
# 14  [2525 King Ave W, Billings, MT 59102, United S...
# 15                [Billings, MT 59101, United States]
# 16  [King Ave (24th St W), Billings, MT 59102, Uni...
# 17  [4420 King Ave E, Billings, MT 59101, United S...
# 18   [425 Main St, Billings, MT 59105, United States]
# 19   [670 Main St, Billings, MT 59105, United States]
# 20  [1649 Main St, Billings, MT 59105, United States]
# 21   [307 SE 4th St, Laurel, MT 59044, United States]
# 22   [307 SE 4th St, Laurel, MT 59044, United States]
# 23  [101 Bernhardt Rd, Laurel, MT 59044, United St...
# 24   [111 E Main St, Laurel, MT 59044, United States]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'lat': 45.7843326, 'lng': -108.5690713, 'lab...  45.784333 -108.569071
# 1   [{'lat': 45.789254603919595, 'lng': -108.56176...  45.789255 -108.561764
# 2   [{'lat': 45.770274, 'lng': -108.530859, 'label...  45.770274 -108.530859
# 3   [{'lat': 45.777169, 'lng': -108.54191, 'label'...  45.777169 -108.541910
# 4   [{'lat': 45.784765513563165, 'lng': -108.54922...  45.784766 -108.549229
# 5   [{'lat': 45.783733878025814, 'lng': -108.57689...  45.783734 -108.576900
# 6   [{'lat': 45.770269, 'lng': -108.528704, 'label...  45.770269 -108.528704
# 7   [{'lat': 45.782658805819054, 'lng': -108.54783...  45.782659 -108.547840
# 8   [{'lat': 45.793161434542604, 'lng': -108.51925...  45.793161 -108.519253
# 9   [{'lat': 45.7880269, 'lng': -108.5084831, 'lab...  45.788027 -108.508483
# 10  [{'lat': 45.77735, 'lng': -108.54169, 'label':...  45.777350 -108.541690
# 11  [{'lat': 45.792803, 'lng': -108.518342, 'label...  45.792803 -108.518342
# 12  [{'lat': 45.7679954, 'lng': -108.5758187, 'lab...  45.767995 -108.575819
# 13  [{'lat': 45.7852696261156, 'lng': -108.5928793...  45.785270 -108.592879
# 14  [{'lat': 45.7552854021962, 'lng': -108.5789496...  45.755285 -108.578950
# 15  [{'lat': 45.78917931270237, 'lng': -108.512799...  45.789179 -108.512800
# 16  [{'lat': 45.76706813775725, 'lng': -108.513986...  45.767068 -108.513987
# 17  [{'lat': 45.755358, 'lng': -108.525397, 'label...  45.755358 -108.525397
# 18  [{'lat': 45.80720543861389, 'lng': -108.473725...  45.807205 -108.473725
# 19  [{'lat': 45.8100783, 'lng': -108.4729272, 'lab...  45.810078 -108.472927
# 20  [{'lat': 45.8287391891892, 'lng': -108.4709324...  45.828739 -108.470932
# 21  [{'lat': 45.624754103049625, 'lng': -108.86168...  45.624754 -108.861685
# 22  [{'lat': 45.6649604162638, 'lng': -108.7665380...  45.664960 -108.766538
# 23  [{'lat': 45.66827, 'lng': -108.76118, 'label':...  45.668270 -108.761180
# 24  [{'lat': 45.66982019199341, 'lng': -108.771601...  45.669820 -108.771601
#
#    postalCode state                        id
# 0       59102    MT  5009a42be4b02ee07a7c22aa
# 1       59102    MT  4d8b9cfa0c4e41bd7048667f
# 2       59102    MT  5a3ef94817556227e485405c
# 3       59102    MT  5cd097a2c66666002ca99761
# 4       59102    MT  4c1668e61b5cef3bbb7deec4
# 5       59102    MT  4c12813e8aedd13a554e5137
# 6       59102    MT  4c166aee1b5cef3b677eeec4
# 7       59102    MT  5745e8a0498e90b028ec23b3
# 8       59101    MT  5a37e3558ad62e7211882094
# 9       59101    MT  4c166a861b5cef3b497eeec4
# 10      59102    MT  5b918f1ee17910002ba14778
# 11      59101    MT  59e8daed0a464d0d412fd48a
# 12      59102    MT  5745e8a0498e90b028ec23a7
# 13      59102    MT  5745e8a0498e90b028ec23bc
# 14      59102    MT  551c1116498e6d8696180986
# 15      59101    MT  5091c3b4e4b0a82b99bacf37
# 16      59102    MT  4f6caa24e4b032eb624d3f94
# 17      59101    MT  55ce54c6498ef585bc13bf36
# 18      59105    MT  4c16694d1b5cef3bdf7deec4
# 19      59105    MT  5745e8a0498e90b028ec23a4
# 20      59105    MT  551c1117498e6d8696183a3c
# 21      59044    MT  4d8b9cfa0c4e41bd9a48667f
# 22      59044    MT  4c1669a81b5cef3b047eeec4
# 23      59044    MT  551c1119498e6d86961865a2
# 24      59044    MT  4c2f88fd7cc0c9b629e6eb9a

# %%
dataframe_filtered.name
# Out:
# 0     JURO's PHARMACY HEALTH & WELLNESS
# 1     CVS pharmacy
# 2     CVS pharmacy
# 3     Billings Clinic Specialty Pharmacy
# 4     CVS pharmacy
# 5     Albertsons Pharmacy
# 6     CVS pharmacy
# 7     Albertsons Pharmacy
# 8     SCL Health Pharmacy Services - Saint Vincent Pharmacy
# 9     Albertsons Pharmacy
# 10    Specialty Pharmacy
# 11    Pharmacy One
# 12    Albertsons Pharmacy
# 13    Albertsons Pharmacy
# 14    Walmart Pharmacy
# 15    Billings Clinic Pharmacy
# 16    VA Pharmacy
# 17    Sam's Club Pharmacy
# 18    Albertsons Pharmacy
# 19    CVS pharmacy
# 20    Walmart Pharmacy
# 21    CVS pharmacy
# 22    CVS pharmacy
# 23    Walmart Pharmacy
# 24    Gene's Pharmacy
# 25    Stillwater Family Pharmacy
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
#folium.features.CircleMarker(
  #  [latitude, longitude],
 #   radius=10,
  #  color='red',
  #  popup='CenterPoint',
  #  fill = True,
 #   fill_color = 'red',
  #  fill_opacity = 0.6
#).add_to(venues_map)

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# search query by category
search_query = 'brewery'
categoryId = '50327c8591d4c4b30a586d5d' # brewery
radius = 50000
print(search_query + ' .... OK!')
# Out:
# brewery .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT, categoryId)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=45.784127338925,-108.557717907471&v=20180604&query=brewery&radius=50000&limit=100&categoryId=50327c8591d4c4b30a586d5d'

# %%
# get requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce449d39fb6b775bbaf88af'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '4ffb8502e4b073bb7b46b8ff',
#     'location': {'address': '20 N 30th St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 3870,
#      'formattedAddress': ['20 N 30th St',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.780563609155536,
#        'lng': -108.50812693069913}],
#      'lat': 45.780563609155536,
#      'lng': -108.50812693069913,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Angry Hanks Brewery',
#     'referralId': 'v-1558464979'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '50f53cd072dad2b9bb4dbbc6',
#     'location': {'address': '3008 1st Ave N',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 4744,
#      'formattedAddress': ['3008 1st Ave N',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.77436034578745,
#        'lng': -108.49822998046875}],
#      'lat': 45.77436034578745,
#      'lng': -108.49822998046875,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Himmelberger Brewery',
#     'referralId': 'v-1558464979'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '4b6de657f964a520279a2ce3',
#     'location': {'address': '2526 Montana Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 4334,
#      'formattedAddress': ['2526 Montana Ave',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.782390358087966,
#        'lng': -108.50194443834928}],
#      'lat': 45.782390358087966,
#      'lng': -108.50194443834928,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': "Carter's Brewing",
#     'referralId': 'v-1558464979'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Brewery', 'primary': True, 'ic...    False
# 1  [{'shortName': 'Brewery', 'primary': True, 'ic...    False
# 2  [{'shortName': 'Brewery', 'primary': True, 'ic...    False
#
#                          id  location.address location.cc location.city  \
# 0  4ffb8502e4b073bb7b46b8ff      20 N 30th St          US      Billings
# 1  50f53cd072dad2b9bb4dbbc6    3008 1st Ave N          US      Billings
# 2  4b6de657f964a520279a2ce3  2526 Montana Ave          US      Billings
#
#   location.country  location.distance  \
# 0    United States               3870
# 1    United States               4744
# 2    United States               4334
#
#                            location.formattedAddress  \
# 0  [20 N 30th St, Billings, MT 59101, United States]
# 1  [3008 1st Ave N, Billings, MT 59101, United St...
# 2  [2526 Montana Ave, Billings, MT 59101, United ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 45.780563609155536, 'lng': -108.50812...     45.780564
# 1  [{'lat': 45.77436034578745, 'lng': -108.498229...     45.774360
# 2  [{'lat': 45.782390358087966, 'lng': -108.50194...     45.782390
#
#    location.lng location.postalCode location.state                  name  \
# 0   -108.508127               59101             MT   Angry Hanks Brewery
# 1   -108.498230               59101             MT  Himmelberger Brewery
# 2   -108.501944               59101             MT      Carter's Brewing
#
#      referralId
# 0  v-1558464979
# 1  v-1558464979
# 2  v-1558464979

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                    name categories           address  cc      city  \
# 0   Angry Hanks Brewery    Brewery      20 N 30th St  US  Billings
# 1  Himmelberger Brewery    Brewery    3008 1st Ave N  US  Billings
# 2      Carter's Brewing    Brewery  2526 Montana Ave  US  Billings
#
#          country  distance                                   formattedAddress  \
# 0  United States      3870  [20 N 30th St, Billings, MT 59101, United States]
# 1  United States      4744  [3008 1st Ave N, Billings, MT 59101, United St...
# 2  United States      4334  [2526 Montana Ave, Billings, MT 59101, United ...
#
#                                       labeledLatLngs        lat         lng  \
# 0  [{'lat': 45.780563609155536, 'lng': -108.50812...  45.780564 -108.508127
# 1  [{'lat': 45.77436034578745, 'lng': -108.498229...  45.774360 -108.498230
# 2  [{'lat': 45.782390358087966, 'lng': -108.50194...  45.782390 -108.501944
#
#   postalCode state                        id
# 0      59101    MT  4ffb8502e4b073bb7b46b8ff
# 1      59101    MT  50f53cd072dad2b9bb4dbbc6
# 2      59101    MT  4b6de657f964a520279a2ce3

# %%
dataframe_filtered.name
# Out:
# 0     Angry Hanks Brewery
# 1    Himmelberger Brewery
# 2        Carter's Brewing
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
#folium.features.CircleMarker(
  #  [latitude, longitude],
 #   radius=10,
  #  color='red',
  #  popup='CenterPoint',
  #  fill = True,
 #   fill_color = 'red',
  #  fill_opacity = 0.6
#).add_to(venues_map)

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# search query by category
search_query = 'liquor stores'
categoryId = '4bf58dd8d48988d186941735' # liquor stores
radius = 50000
print(search_query + ' .... OK!')
# Out:
# liquor stores .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT, categoryId)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=45.784127338925,-108.557717907471&v=20180604&query=liquor stores&radius=50000&limit=100&categoryId=4bf58dd8d48988d186941735'

# %%
# get requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce44aa3dd57970e24ed0485'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4c3e0e7f0596c9289dc28378',
#     'location': {'address': '1420 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 413,
#      'formattedAddress': ['1420 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78371021898516,
#        'lng': -108.55242629417147}],
#      'lat': 45.78371021898516,
#      'lng': -108.55242629417147,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'State Liquor Store #3',
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4f32772c19836c91c7da7b15',
#     'location': {'address': '100 24th St W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2023,
#      'formattedAddress': ['100 24th St W',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.77134,
#        'lng': -108.576238}],
#      'lat': 45.77134,
#      'lng': -108.576238,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Liquor Store Montana-Retail 196',
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4bdd005f383276b04fe47369',
#     'location': {'address': '711 15th St W',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': 'Broadwater Ave',
#      'distance': 838,
#      'formattedAddress': ['711 15th St W (Broadwater Ave)',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.777406096458435,
#        'lng': -108.552846}],
#      'lat': 45.777406096458435,
#      'lng': -108.552846,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': "Doc & Eddy's Liquor Store",
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4d9bc044b8b2224b24268855',
#     'location': {'address': '825 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 1572,
#      'formattedAddress': ['825 Grand Ave',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.78433913333333,
#        'lng': -108.53746243333333}],
#      'lat': 45.78433913333333,
#      'lng': -108.53746243333333,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'Grand Liquor',
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4bbe659585fbb71335ba7067',
#     'location': {'address': '2349 Grand Ave',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'crossStreet': '24th',
#      'distance': 1412,
#      'formattedAddress': ['2349 Grand Ave (24th)',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.784411969722136,
#        'lng': -108.57590960565152}],
#      'lat': 45.784411969722136,
#      'lng': -108.57590960565152,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': "Montana Lil's Casino Liquor Store",
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4ee3a81a5c5cfa48f9ab45fb',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2115,
#      'formattedAddress': ['Billings, MT 59102', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.771306109916374,
#        'lng': -108.5778349174579}],
#      'lat': 45.771306109916374,
#      'lng': -108.5778349174579,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': 'State Liquor store',
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d119951735',
#       'name': 'Wine Shop',
#       'pluralName': 'Wine Shops',
#       'primary': True,
#       'shortName': 'Wine Shop'}],
#     'hasPerk': False,
#     'id': '5c679e8bc9a517002c7b7c87',
#     'location': {'address': '100 24th St W #2',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2099,
#      'formattedAddress': ['100 24th St W #2',
#       'Billings, MT 59102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.7716255,
#        'lng': -108.5779678}],
#      'lat': 45.7716255,
#      'lng': -108.5779678,
#      'postalCode': '59102',
#      'state': 'MT'},
#     'name': '24th Street State Liquor Store',
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4dd70f96d22d38ef42dfb3d1',
#     'location': {'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 2156,
#      'formattedAddress': ['Billings, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.769773157016054,
#        'lng': -108.57637065830883}],
#      'lat': 45.769773157016054,
#      'lng': -108.57637065830883,
#      'state': 'MT'},
#     'name': 'Discount Wines State Liquor Store',
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4c07ee63ffb8c9b6a56f6761',
#     'location': {'address': '1019 1st Ave N',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 5716,
#      'formattedAddress': ['1019 1st Ave N',
#       'Billings, MT 59101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.79237270928667,
#        'lng': -108.48503630312182}],
#      'lat': 45.79237270928667,
#      'lng': -108.48503630312182,
#      'postalCode': '59101',
#      'state': 'MT'},
#     'name': 'Montana Liquor Inc',
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4d2674b777a2a1cdf1ee4fb7',
#     'location': {'address': '247 Main St',
#      'cc': 'US',
#      'city': 'Billings',
#      'country': 'United States',
#      'distance': 6634,
#      'formattedAddress': ['247 Main St',
#       'Billings, MT 59105',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.80356356702017,
#        'lng': -108.47691517018504}],
#      'lat': 45.80356356702017,
#      'lng': -108.47691517018504,
#      'postalCode': '59105',
#      'state': 'MT'},
#     'name': 'Bottles & Shots',
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4f32722719836c91c7d895cc',
#     'location': {'address': '215 E Main St',
#      'cc': 'US',
#      'city': 'Laurel',
#      'country': 'United States',
#      'distance': 20770,
#      'formattedAddress': ['215 E Main St',
#       'Laurel, MT 59044',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.670057,
#        'lng': -108.769234}],
#      'lat': 45.670057,
#      'lng': -108.769234,
#      'postalCode': '59044',
#      'state': 'MT'},
#     'name': 'Statewide Liquors',
#     'referralId': 'v-1558465187'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '50857f3ae4b0a0ddb4c93d4e',
#     'location': {'cc': 'US',
#      'city': 'Laurel',
#      'country': 'United States',
#      'distance': 21048,
#      'formattedAddress': ['Laurel, MT 59044', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.6771125793457,
#        'lng': -108.78104400634766}],
#      'lat': 45.6771125793457,
#      'lng': -108.78104400634766,
#      'postalCode': '59044',
#      'state': 'MT'},
#     'name': 'state liquor laurel montana',
#     'referralId': 'v-1558465187'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Liquor Store', 'primary': True...    False
# 1  [{'shortName': 'Liquor Store', 'primary': True...    False
# 2  [{'shortName': 'Liquor Store', 'primary': True...    False
# 3  [{'shortName': 'Liquor Store', 'primary': True...    False
# 4  [{'shortName': 'Liquor Store', 'primary': True...    False
#
#                          id location.address location.cc location.city  \
# 0  4c3e0e7f0596c9289dc28378   1420 Grand Ave          US      Billings
# 1  4f32772c19836c91c7da7b15    100 24th St W          US      Billings
# 2  4bdd005f383276b04fe47369    711 15th St W          US      Billings
# 3  4d9bc044b8b2224b24268855    825 Grand Ave          US      Billings
# 4  4bbe659585fbb71335ba7067   2349 Grand Ave          US      Billings
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN                413
# 1    United States                  NaN               2023
# 2    United States       Broadwater Ave                838
# 3    United States                  NaN               1572
# 4    United States                 24th               1412
#
#                            location.formattedAddress  \
# 0  [1420 Grand Ave, Billings, MT 59102, United St...
# 1  [100 24th St W, Billings, MT 59102, United Sta...
# 2  [711 15th St W (Broadwater Ave), Billings, MT ...
# 3  [825 Grand Ave, Billings, MT 59102, United Sta...
# 4  [2349 Grand Ave (24th), Billings, MT 59102, Un...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 45.78371021898516, 'lng': -108.552426...     45.783710
# 1  [{'lat': 45.77134, 'lng': -108.576238, 'label'...     45.771340
# 2  [{'lat': 45.777406096458435, 'lng': -108.55284...     45.777406
# 3  [{'lat': 45.78433913333333, 'lng': -108.537462...     45.784339
# 4  [{'lat': 45.784411969722136, 'lng': -108.57590...     45.784412
#
#    location.lng location.postalCode location.state  \
# 0   -108.552426               59102             MT
# 1   -108.576238               59102             MT
# 2   -108.552846               59102             MT
# 3   -108.537462               59102             MT
# 4   -108.575910               59102             MT
#
#                                 name    referralId
# 0              State Liquor Store #3  v-1558465187
# 1    Liquor Store Montana-Retail 196  v-1558465187
# 2          Doc & Eddy's Liquor Store  v-1558465187
# 3                       Grand Liquor  v-1558465187
# 4  Montana Lil's Casino Liquor Store  v-1558465187

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                  name    categories           address  cc  \
# 0               State Liquor Store #3  Liquor Store    1420 Grand Ave  US
# 1     Liquor Store Montana-Retail 196  Liquor Store     100 24th St W  US
# 2           Doc & Eddy's Liquor Store  Liquor Store     711 15th St W  US
# 3                        Grand Liquor  Liquor Store     825 Grand Ave  US
# 4   Montana Lil's Casino Liquor Store  Liquor Store    2349 Grand Ave  US
# 5                  State Liquor store  Liquor Store               NaN  US
# 6      24th Street State Liquor Store     Wine Shop  100 24th St W #2  US
# 7   Discount Wines State Liquor Store  Liquor Store               NaN  US
# 8                  Montana Liquor Inc  Liquor Store    1019 1st Ave N  US
# 9                     Bottles & Shots  Liquor Store       247 Main St  US
# 10                  Statewide Liquors  Liquor Store     215 E Main St  US
# 11        state liquor laurel montana  Liquor Store               NaN  US
#
#         city        country     crossStreet  distance  \
# 0   Billings  United States             NaN       413
# 1   Billings  United States             NaN      2023
# 2   Billings  United States  Broadwater Ave       838
# 3   Billings  United States             NaN      1572
# 4   Billings  United States            24th      1412
# 5   Billings  United States             NaN      2115
# 6   Billings  United States             NaN      2099
# 7   Billings  United States             NaN      2156
# 8   Billings  United States             NaN      5716
# 9   Billings  United States             NaN      6634
# 10    Laurel  United States             NaN     20770
# 11    Laurel  United States             NaN     21048
#
#                                      formattedAddress  \
# 0   [1420 Grand Ave, Billings, MT 59102, United St...
# 1   [100 24th St W, Billings, MT 59102, United Sta...
# 2   [711 15th St W (Broadwater Ave), Billings, MT ...
# 3   [825 Grand Ave, Billings, MT 59102, United Sta...
# 4   [2349 Grand Ave (24th), Billings, MT 59102, Un...
# 5                 [Billings, MT 59102, United States]
# 6   [100 24th St W #2, Billings, MT 59102, United ...
# 7                       [Billings, MT, United States]
# 8   [1019 1st Ave N, Billings, MT 59101, United St...
# 9    [247 Main St, Billings, MT 59105, United States]
# 10   [215 E Main St, Laurel, MT 59044, United States]
# 11                  [Laurel, MT 59044, United States]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'lat': 45.78371021898516, 'lng': -108.552426...  45.783710 -108.552426
# 1   [{'lat': 45.77134, 'lng': -108.576238, 'label'...  45.771340 -108.576238
# 2   [{'lat': 45.777406096458435, 'lng': -108.55284...  45.777406 -108.552846
# 3   [{'lat': 45.78433913333333, 'lng': -108.537462...  45.784339 -108.537462
# 4   [{'lat': 45.784411969722136, 'lng': -108.57590...  45.784412 -108.575910
# 5   [{'lat': 45.771306109916374, 'lng': -108.57783...  45.771306 -108.577835
# 6   [{'lat': 45.7716255, 'lng': -108.5779678, 'lab...  45.771625 -108.577968
# 7   [{'lat': 45.769773157016054, 'lng': -108.57637...  45.769773 -108.576371
# 8   [{'lat': 45.79237270928667, 'lng': -108.485036...  45.792373 -108.485036
# 9   [{'lat': 45.80356356702017, 'lng': -108.476915...  45.803564 -108.476915
# 10  [{'lat': 45.670057, 'lng': -108.769234, 'label...  45.670057 -108.769234
# 11  [{'lat': 45.6771125793457, 'lng': -108.7810440...  45.677113 -108.781044
#
#    postalCode state                        id
# 0       59102    MT  4c3e0e7f0596c9289dc28378
# 1       59102    MT  4f32772c19836c91c7da7b15
# 2       59102    MT  4bdd005f383276b04fe47369
# 3       59102    MT  4d9bc044b8b2224b24268855
# 4       59102    MT  4bbe659585fbb71335ba7067
# 5       59102    MT  4ee3a81a5c5cfa48f9ab45fb
# 6       59102    MT  5c679e8bc9a517002c7b7c87
# 7         NaN    MT  4dd70f96d22d38ef42dfb3d1
# 8       59101    MT  4c07ee63ffb8c9b6a56f6761
# 9       59105    MT  4d2674b777a2a1cdf1ee4fb7
# 10      59044    MT  4f32722719836c91c7d895cc
# 11      59044    MT  50857f3ae4b0a0ddb4c93d4e

# %%
dataframe_filtered.name
# Out:
# 0                 State Liquor Store #3
# 1       Liquor Store Montana-Retail 196
# 2                          Grand Liquor
# 3             Doc & Eddy's Liquor Store
# 4     Montana Lil's Casino Liquor Store
# 5                    State Liquor store
# 6        24th Street State Liquor Store
# 7     Discount Wines State Liquor Store
# 8                    Montana Liquor Inc
# 9                       Bottles & Shots
# 10                    Statewide Liquors
# 11          state liquor laurel montana
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
#folium.features.CircleMarker(
  #  [latitude, longitude],
 #   radius=10,
  #  color='red',
  #  popup='CenterPoint',
  #  fill = True,
 #   fill_color = 'red',
  #  fill_opacity = 0.6
#).add_to(venues_map)

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Next: Missoula vendors

address = '631 S Higgins, Missoula, MT'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 46.8722217 -113.993395

# %%
search_query = 'Coffee Shop'
categoryId = '4bf58dd8d48988d1e0931735' # Coffee Shop
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Coffee Shop .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=46.8722217,-113.993395&v=20180604&query=Coffee Shop&radius=50000&limit=100'

# %%
# get requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce5468e9fb6b7757fa7bf19'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4c62a462ec94a59339b329ca',
#     'location': {'address': '2710-2 Brooks',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Belvue',
#      'distance': 3207,
#      'formattedAddress': ['2710-2 Brooks (Belvue)',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.851353952084715,
#        'lng': -114.02244346096595}],
#      'lat': 46.851353952084715,
#      'lng': -114.02244346096595,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Green Bean coffee shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '5726529b498e11c98359e54b',
#     'location': {'address': '1951 Kensington Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Johnson',
#      'distance': 3349,
#      'formattedAddress': ['1951 Kensington Ave (Johnson)',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.85322,
#        'lng': -114.02751}],
#      'lat': 46.85322,
#      'lng': -114.02751,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Sunrise Coffee Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'primary': True,
#       'shortName': 'Art Gallery'}],
#     'hasPerk': False,
#     'id': '4b6cbe24f964a520eb502ce3',
#     'location': {'address': '304 N Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 17,
#      'formattedAddress': ['304 N Higgins Ave',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87233834444417,
#        'lng': -113.99353981018066}],
#      'lat': 46.87233834444417,
#      'lng': -113.99353981018066,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': "Missoula Artist's Shop",
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'primary': True,
#       'shortName': 'Gym / Fitness'}],
#     'hasPerk': False,
#     'id': '56ff1fb3498ea80cbf4dff22',
#     'location': {'address': '225 N Higgins Ave Ste B',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 98,
#      'formattedAddress': ['225 N Higgins Ave Ste B',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8719671,
#        'lng': -113.9946347}],
#      'lat': 46.8719671,
#      'lng': -113.9946347,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'The Sweat Shop Studio',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'primary': True,
#       'shortName': 'Sandwiches'}],
#     'hasPerk': False,
#     'id': '4bc8be1b14d7952129c069e9',
#     'location': {'address': '214 N Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 113,
#      'formattedAddress': ['214 N Higgins Ave',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87145558692316,
#        'lng': -113.99438452570183}],
#      'lat': 46.87145558692316,
#      'lng': -113.99438452570183,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': "Doc's Sandwich Shop",
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '4c6581ad19f3c9b6fd3e9dff',
#     'location': {'address': '101 E Front St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 303,
#      'formattedAddress': ['101 E Front St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86983691515358,
#        'lng': -113.99532360065982}],
#      'lat': 46.86983691515358,
#      'lng': -113.99532360065982,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Hunter Bay Coffee Bar',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '55b50814498e519aa04a5911',
#     'location': {'address': '1000 E Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1092,
#      'formattedAddress': ['1000 E Broadway St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.868279,
#        'lng': -113.980252}],
#      'lat': 46.868279,
#      'lng': -113.980252,
#      'neighborhood': 'Heart of Missoula',
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Drum Coffee',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'primary': True,
#       'shortName': "Doctor's Office"}],
#     'hasPerk': False,
#     'id': '59980b9bda5e5606a99840e4',
#     'location': {'address': '401 North Russell Street',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2487,
#      'formattedAddress': ['401 North Russell Street',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display', 'lat': 46.85, 'lng': -113.99}],
#      'lat': 46.85,
#      'lng': -113.99,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'The Coffee Joint MMJ Dispensary',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116951735',
#       'name': 'Antique Shop',
#       'pluralName': 'Antique Shops',
#       'primary': True,
#       'shortName': 'Antiques'}],
#     'hasPerk': False,
#     'id': '5ad5f2b266fc6554d678fb0f',
#     'location': {'address': '122 W Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 108,
#      'formattedAddress': ['122 W Broadway St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8725111,
#        'lng': -113.9947524}],
#      'lat': 46.8725111,
#      'lng': -113.9947524,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Jem Shoppe Jewelers',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d123951735',
#       'name': 'Smoke Shop',
#       'pluralName': 'Smoke Shops',
#       'primary': True,
#       'shortName': 'Smoke Shop'}],
#     'hasPerk': False,
#     'id': '4e5874953151bb7383ae3734',
#     'location': {'address': '115 W Main St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 173,
#      'formattedAddress': ['115 W Main St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87146402464034,
#        'lng': -113.9953916947469}],
#      'lat': 46.87146402464034,
#      'lng': -113.9953916947469,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Atmosphere Smoke Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '4bc9f62868f976b0003f5e83',
#     'location': {'address': '143 W Main St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 192,
#      'formattedAddress': ['143 W Main St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87151349173336,
#        'lng': -113.9957086608098}],
#      'lat': 46.87151349173336,
#      'lng': -113.9957086608098,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Main Street Barber Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '5037dd59e4b0b68ee3d3b2eb',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 245,
#      'formattedAddress': ['Missoula, MT 59802', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87173,
#        'lng': -113.996539}],
#      'lat': 46.87173,
#      'lng': -113.996539,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Capitol Barber Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f43664b19834bc91f568b99',
#     'location': {'address': '1330 Howell St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1690,
#      'formattedAddress': ['1330 Howell St', 'Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.88203,
#        'lng': -114.010356}],
#      'lat': 46.88203,
#      'lng': -114.010356,
#      'state': 'MT'},
#     'name': 'Coffee Communications',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '5630f771498eb5d455b2a76d',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 785,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86568111843868,
#        'lng': -113.99726787874847}],
#      'lat': 46.86568111843868,
#      'lng': -113.99726787874847,
#      'state': 'MT'},
#     'name': 'clyde coffee',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4bd0ab3577b29c74bf3a8b82',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 286,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87088,
#        'lng': -113.99661}],
#      'lat': 46.87088,
#      'lng': -113.99661,
#      'state': 'MT'},
#     'name': 'Trout River Coffee',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d162941735',
#       'name': 'Other Great Outdoors',
#       'pluralName': 'Other Great Outdoors',
#       'primary': True,
#       'shortName': 'Other Outdoors'}],
#     'hasPerk': False,
#     'id': '5626c4be498e7c342679007b',
#     'location': {'address': '215 W Front St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 318,
#      'formattedAddress': ['215 W Front St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87063,
#        'lng': -113.99688}],
#      'lat': 46.87063,
#      'lng': -113.99688,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Grizzly Hackle Fly Shop',
#     'referralId': 'v-1558529678',
#     'venuePage': {'id': '143537530'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '58484ee5b6e67d44e9b89dfb',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': '(lower level of Missoula Public Library)',
#      'distance': 337,
#      'formattedAddress': ['(lower level of Missoula Public Library)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.869698,
#        'lng': -113.99094}],
#      'lat': 46.869698,
#      'lng': -113.99094,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Trapper Peak Coffee Co.',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '50dc6c3be4b09036bf2d5405',
#     'location': {'address': '221 E Front St (back door)',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 337,
#      'formattedAddress': ['221 E Front St (back door)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.869197,
#        'lng': -113.99317}],
#      'lat': 46.869197,
#      'lng': -113.99317,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Alpine Start Coffee @ The Trail Head',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10e941735',
#       'name': 'Greek Restaurant',
#       'pluralName': 'Greek Restaurants',
#       'primary': True,
#       'shortName': 'Greek'}],
#     'hasPerk': False,
#     'id': '4b2ab12ff964a520c9ad24e3',
#     'location': {'address': '520 S 5th St W',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1135,
#      'formattedAddress': ['520 S 5th St W',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.865184554346484,
#        'lng': -114.00419114566701}],
#      'lat': 46.865184554346484,
#      'lng': -114.00419114566701,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Greek Pastry Shop & #1 Gyros',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '59987bc0603d2a6715b44c8e',
#     'location': {'address': '736 S Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 929,
#      'formattedAddress': ['736 S Higgins Ave',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8643,
#        'lng': -113.997265}],
#      'lat': 46.8643,
#      'lng': -113.997265,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Compass Barber Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d117941735',
#       'name': 'Beer Garden',
#       'pluralName': 'Beer Gardens',
#       'primary': True,
#       'shortName': 'Beer Garden'}],
#     'hasPerk': False,
#     'id': '551c7bd7498ef15ec506fda4',
#     'location': {'address': '229 E Front St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 308,
#      'formattedAddress': ['229 E Front St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86947155532024,
#        'lng': -113.99285809506895}],
#      'lat': 46.86947155532024,
#      'lng': -113.99285809506895,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'The Dram Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b630e15f964a5201d602ae3',
#     'location': {'address': '400 W Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Orange St.',
#      'distance': 437,
#      'formattedAddress': ['400 W Broadway St (Orange St.)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.873704556192365,
#        'lng': -113.99872461776526}],
#      'lat': 46.873704556192365,
#      'lng': -113.99872461776526,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'City Brew',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '53505310498edc226edd484d',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 794,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.879355,
#        'lng': -113.993042}],
#      'lat': 46.879355,
#      'lng': -113.993042,
#      'state': 'MT'},
#     'name': 'Florence Coffee Company',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/surfspot_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f1941735',
#       'name': 'Board Shop',
#       'pluralName': 'Board Shops',
#       'primary': True,
#       'shortName': 'Board Shop'}],
#     'hasPerk': False,
#     'id': '545d764a498e306f280d1da9',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 882,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.878299,
#        'lng': -114.000832}],
#      'lat': 46.878299,
#      'lng': -114.000832,
#      'state': 'MT'},
#     'name': 'elements board shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'primary': True,
#       'shortName': 'Sandwiches'}],
#     'hasPerk': False,
#     'id': '56ca59fecd109783d03ffaef',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 839,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.865385,
#        'lng': -113.998053}],
#      'lat': 46.865385,
#      'lng': -113.998053,
#      'state': 'MT'},
#     'name': "Erbert & Gerbert's Sandwich Shop",
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_fishmarket_',
#        'suffix': '.png'},
#       'id': '52f2ab2ebcbc57f1066b8b16',
#       'name': 'Fishing Store',
#       'pluralName': 'Fishing Stores',
#       'primary': True,
#       'shortName': 'Fishing Store'}],
#     'hasPerk': False,
#     'id': '52054ce111d26505db892a6f',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 986,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.863784,
#        'lng': -113.997339}],
#      'lat': 46.863784,
#      'lng': -113.997339,
#      'state': 'MT'},
#     'name': 'Missoula Angler Fly Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'primary': True,
#       'shortName': 'Art Gallery'}],
#     'hasPerk': False,
#     'id': '4f29abe7e4b005595f16bc95',
#     'location': {'address': '425 S Orange St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'S. Third Street West',
#      'distance': 975,
#      'formattedAddress': ['425 S Orange St (S. Third Street West)',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86705081697663,
#        'lng': -114.00374496966869}],
#      'lat': 46.86705081697663,
#      'lng': -114.00374496966869,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Talc - Art & Coffee',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4c6dbafc4ee776b00fca531b',
#     'location': {'address': '525 E Spruce St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1938,
#      'formattedAddress': ['525 E Spruce St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.871794123536006,
#        'lng': -114.01886379286843}],
#      'lat': 46.871794123536006,
#      'lng': -114.01886379286843,
#      'neighborhood': 'Downtown',
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Black Coffee Roasting Co.',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'primary': True,
#       'shortName': 'Apparel'}],
#     'hasPerk': False,
#     'id': '4ee1164477c804cac6f93cff',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1072,
#      'formattedAddress': ['Missoula, MT 59801', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.870134,
#        'lng': -114.007154}],
#      'lat': 46.870134,
#      'lng': -114.007154,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'The Shirt Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'primary': True,
#       'shortName': 'Gift Shop'}],
#     'hasPerk': False,
#     'id': '4b9c092bf964a5204a4336e3',
#     'location': {'address': '811 S Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'S 6th St',
#      'distance': 999,
#      'formattedAddress': ['811 S Higgins Ave (S 6th St)',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8638,
#        'lng': -113.99795}],
#      'lat': 46.8638,
#      'lng': -113.99795,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Bitterroot Flower Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '504a309ae4b043e9ecf82b67',
#     'location': {'address': 'Phyllis J. Washington Building',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1244,
#      'formattedAddress': ['Phyllis J. Washington Building',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86275923149255,
#        'lng': -113.98469200689307}],
#      'lat': 46.86275923149255,
#      'lng': -113.98469200689307,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Recess Coffee',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ac941735',
#       'name': 'College Theater',
#       'pluralName': 'College Theaters',
#       'primary': True,
#       'shortName': 'Theater'}],
#     'hasPerk': False,
#     'id': '51474865e4b0ff6e3c3733ca',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1087,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86408233642578,
#        'lng': -113.98548126220703}],
#      'lat': 46.86408233642578,
#      'lng': -113.98548126220703,
#      'state': 'MT'},
#     'name': 'PARTV Light Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'primary': True,
#       'shortName': 'Classroom'}],
#     'hasPerk': False,
#     'id': '514a1a41e4b0944727fae79e',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1285,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86168472330862,
#        'lng': -113.9864768924007}],
#      'lat': 46.86168472330862,
#      'lng': -113.9864768924007,
#      'state': 'MT'},
#     'name': 'UM Print Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '5824f35a5496250a92a82255',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1475,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.861018,
#        'lng': -113.983045}],
#      'lat': 46.861018,
#      'lng': -113.983045,
#      'state': 'MT'},
#     'name': 'Black Coffee Roasting at University Center',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '4e3851f345ddd221469f80f2',
#     'location': {'address': '1415 S Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1631,
#      'formattedAddress': ['1415 S Higgins Ave',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.857854036528266,
#        'lng': -113.99759402666187}],
#      'lat': 46.857854036528266,
#      'lng': -113.99759402666187,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': "Dan's Barber Shop",
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d101951735',
#       'name': 'Thrift / Vintage Store',
#       'pluralName': 'Thrift / Vintage Stores',
#       'primary': True,
#       'shortName': 'Thrift / Vintage'}],
#     'hasPerk': False,
#     'id': '51c4ce01498e67098bd2e0df',
#     'location': {'address': '1444 W Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1976,
#      'formattedAddress': ['1444 W Broadway St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.878295,
#        'lng': -114.017806}],
#      'lat': 46.878295,
#      'lng': -114.017806,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Zootown Thrift',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d123951735',
#       'name': 'Smoke Shop',
#       'pluralName': 'Smoke Shops',
#       'primary': True,
#       'shortName': 'Smoke Shop'}],
#     'hasPerk': False,
#     'id': '520ae715498e86ccd4586290',
#     'location': {'address': '2530 S 3rd St W',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1496,
#      'formattedAddress': ['2530 S 3rd St W',
#       'Missoula, MT 59804',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87787628173828,
#        'lng': -114.01123809814453}],
#      'lat': 46.87787628173828,
#      'lng': -114.01123809814453,
#      'postalCode': '59804',
#      'state': 'MT'},
#     'name': 'Natural Grocers By Vitamin Cottage',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '4c5c018299ff76b00e59a99e',
#     'location': {'address': '2000 W Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2536,
#      'formattedAddress': ['2000 W Broadway St',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.88269837933208,
#        'lng': -114.02299098909111}],
#      'lat': 46.88269837933208,
#      'lng': -114.02299098909111,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Black Cat Bake Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4dc17d387d8bf48713c3a52e',
#     'location': {'address': '2200-2298 Oxford St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2986,
#      'formattedAddress': ['2200-2298 Oxford St',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.85038164791027,
#        'lng': -114.01618840045005}],
#      'lat': 46.85038164791027,
#      'lng': -114.01618840045005,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Florence Coffee',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b4636ddf964a520491a26e3',
#     'location': {'address': '2504 S Reserve Street',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 4352,
#      'formattedAddress': ['2504 S Reserve Street',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.84853,
#        'lng': -114.03888}],
#      'lat': 46.84853,
#      'lng': -114.03888,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Starbucks',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '5bcde77a4a1cc0002c33df1f',
#     'location': {'address': '1460 S Russell St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2278,
#      'formattedAddress': ['1460 S Russell St',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86106,
#        'lng': -114.018486}],
#      'lat': 46.86106,
#      'lng': -114.018486,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Nitro Coffee',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '56f595d1cd10a3b06aca635a',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2761,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.84909,
#        'lng': -114.006506}],
#      'lat': 46.84909,
#      'lng': -114.006506,
#      'state': 'MT'},
#     'name': 'Drum Coffee',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4f32706619836c91c7d7e869',
#     'location': {'address': '1701 Stephens Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2425,
#      'formattedAddress': ['1701 Stephens Ave',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.855068,
#        'lng': -114.013036}],
#      'lat': 46.855068,
#      'lng': -114.013036,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Mountain Town Coffee Station',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '5ba54fa77c891c002d6f0efa',
#     'location': {'address': '1124 W Central Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2935,
#      'formattedAddress': ['1124 W Central Ave',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.851044,
#        'lng': -114.016365}],
#      'lat': 46.851044,
#      'lng': -114.016365,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'The Man Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'primary': True,
#       'shortName': 'Building'}],
#     'hasPerk': False,
#     'id': '4c503d272a73c92836a52bd2',
#     'location': {'address': '1100 South Ave W',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Malfunction',
#      'distance': 3059,
#      'formattedAddress': ['1100 South Ave W (Malfunction)',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8560832,
#        'lng': -114.0259301}],
#      'lat': 46.8560832,
#      'lng': -114.0259301,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'The Bike Shop',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4f3244ba19836c91c7c6e40a',
#     'location': {'address': '420 N Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2701,
#      'formattedAddress': ['420 N Higgins Ave',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.84826214481185,
#        'lng': -113.98776896960078}],
#      'lat': 46.84826214481185,
#      'lng': -113.98776896960078,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Starbucks',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '55c39da4498ecf4c8ae016c2',
#     'location': {'address': '3751 N Reserve St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 5059,
#      'formattedAddress': ['3751 N Reserve St',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.90528500000001,
#        'lng': -114.0390255}],
#      'lat': 46.90528500000001,
#      'lng': -114.0390255,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Copper Mountain Coffee',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4b56184ef964a5201f0028e3',
#     'location': {'address': '5260 Grant Creek Road',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 5568,
#      'formattedAddress': ['5260 Grant Creek Road',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.91432485497331,
#        'lng': -114.03292722377361}],
#      'lat': 46.91432485497331,
#      'lng': -114.03292722377361,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Starbucks',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4d87e70d7139b1f70d7997d4',
#     'location': {'address': '1701 Rankin St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 3336,
#      'formattedAddress': ['1701 Rankin St',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.88802136,
#        'lng': -114.03066053}],
#      'lat': 46.88802136,
#      'lng': -114.03066053,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Farmer Brothers Coffee!',
#     'referralId': 'v-1558529678'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'primary': True,
#       'shortName': 'Nail Salon'}],
#     'hasPerk': False,
#     'id': '51fc0ebd498e9ba30834e815',
#     'location': {'address': '9th St.',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'S. Reserve',
#      'distance': 3685,
#      'formattedAddress': ['9th St. (S. Reserve)',
#       'Missoula, MT',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.861242,
#        'lng': -114.039074}],
#      'lat': 46.861242,
#      'lng': -114.039074,
#      'state': 'MT'},
#     'name': 'One Stop Nail Shop',
#     'referralId': 'v-1558529678'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Coffee Shop', 'icon': {'suffix': '....    False
# 1  [{'name': 'Coffee Shop', 'icon': {'suffix': '....    False
# 2  [{'name': 'Art Gallery', 'icon': {'suffix': '....    False
# 3  [{'name': 'Gym / Fitness Center', 'icon': {'su...    False
# 4  [{'name': 'Sandwich Place', 'icon': {'suffix':...    False
#
#                          id         location.address location.cc  \
# 0  4c62a462ec94a59339b329ca            2710-2 Brooks          US
# 1  5726529b498e11c98359e54b      1951 Kensington Ave          US
# 2  4b6cbe24f964a520eb502ce3        304 N Higgins Ave          US
# 3  56ff1fb3498ea80cbf4dff22  225 N Higgins Ave Ste B          US
# 4  4bc8be1b14d7952129c069e9        214 N Higgins Ave          US
#
#   location.city location.country location.crossStreet  location.distance  \
# 0      Missoula    United States               Belvue               3207
# 1      Missoula    United States              Johnson               3349
# 2      Missoula    United States                  NaN                 17
# 3      Missoula    United States                  NaN                 98
# 4      Missoula    United States                  NaN                113
#
#                            location.formattedAddress  \
# 0  [2710-2 Brooks (Belvue), Missoula, MT 59801, U...
# 1  [1951 Kensington Ave (Johnson), Missoula, MT 5...
# 2  [304 N Higgins Ave, Missoula, MT 59802, United...
# 3  [225 N Higgins Ave Ste B, Missoula, MT 59802, ...
# 4  [214 N Higgins Ave, Missoula, MT 59802, United...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lng': -114.022443460965...     46.851354
# 1  [{'label': 'display', 'lng': -114.02751, 'lat'...     46.853220
# 2  [{'label': 'display', 'lng': -113.993539810180...     46.872338
# 3  [{'label': 'display', 'lng': -113.9946347, 'la...     46.871967
# 4  [{'label': 'display', 'lng': -113.994384525701...     46.871456
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0   -114.022443                   NaN               59801             MT
# 1   -114.027510                   NaN               59801             MT
# 2   -113.993540                   NaN               59802             MT
# 3   -113.994635                   NaN               59802             MT
# 4   -113.994385                   NaN               59802             MT
#
#                      name    referralId venuePage.id
# 0  Green Bean coffee shop  v-1558529678          NaN
# 1     Sunrise Coffee Shop  v-1558529678          NaN
# 2  Missoula Artist's Shop  v-1558529678          NaN
# 3   The Sweat Shop Studio  v-1558529678          NaN
# 4     Doc's Sandwich Shop  v-1558529678          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                           name              categories  \
# 0                       Green Bean coffee shop             Coffee Shop
# 1                          Sunrise Coffee Shop             Coffee Shop
# 2                       Missoula Artist's Shop             Art Gallery
# 3                        The Sweat Shop Studio    Gym / Fitness Center
# 4                          Doc's Sandwich Shop          Sandwich Place
# 5                        Hunter Bay Coffee Bar                    Café
# 6                                  Drum Coffee             Coffee Shop
# 7              The Coffee Joint MMJ Dispensary         Doctor's Office
# 8                          Jem Shoppe Jewelers            Antique Shop
# 9                        Atmosphere Smoke Shop              Smoke Shop
# 10                     Main Street Barber Shop      Salon / Barbershop
# 11                         Capitol Barber Shop      Salon / Barbershop
# 12                       Coffee Communications                    Food
# 13                                clyde coffee                    Café
# 14                          Trout River Coffee             Coffee Shop
# 15                     Grizzly Hackle Fly Shop    Other Great Outdoors
# 16                     Trapper Peak Coffee Co.             Coffee Shop
# 17        Alpine Start Coffee @ The Trail Head             Coffee Shop
# 18                Greek Pastry Shop & #1 Gyros        Greek Restaurant
# 19                         Compass Barber Shop      Salon / Barbershop
# 20                               The Dram Shop             Beer Garden
# 21                                   City Brew             Coffee Shop
# 22                     Florence Coffee Company             Coffee Shop
# 23                         elements board shop              Board Shop
# 24            Erbert & Gerbert's Sandwich Shop          Sandwich Place
# 25                    Missoula Angler Fly Shop           Fishing Store
# 26                         Talc - Art & Coffee             Art Gallery
# 27                   Black Coffee Roasting Co.             Coffee Shop
# 28                              The Shirt Shop          Clothing Store
# 29                      Bitterroot Flower Shop               Gift Shop
# 30                               Recess Coffee             Coffee Shop
# 31                            PARTV Light Shop         College Theater
# 32                               UM Print Shop       College Classroom
# 33  Black Coffee Roasting at University Center                    Café
# 34                           Dan's Barber Shop      Salon / Barbershop
# 35                              Zootown Thrift  Thrift / Vintage Store
# 36          Natural Grocers By Vitamin Cottage              Smoke Shop
# 37                         Black Cat Bake Shop                  Bakery
# 38                             Florence Coffee             Coffee Shop
# 39                                   Starbucks             Coffee Shop
# 40                                Nitro Coffee             Coffee Shop
# 41                                 Drum Coffee             Coffee Shop
# 42                Mountain Town Coffee Station             Coffee Shop
# 43                                The Man Shop      Salon / Barbershop
# 44                               The Bike Shop                Building
# 45                                   Starbucks             Coffee Shop
# 46                      Copper Mountain Coffee                    Café
# 47                                   Starbucks             Coffee Shop
# 48                     Farmer Brothers Coffee!             Coffee Shop
# 49                          One Stop Nail Shop              Nail Salon
#
#                            address  cc      city        country  \
# 0                    2710-2 Brooks  US  Missoula  United States
# 1              1951 Kensington Ave  US  Missoula  United States
# 2                304 N Higgins Ave  US  Missoula  United States
# 3          225 N Higgins Ave Ste B  US  Missoula  United States
# 4                214 N Higgins Ave  US  Missoula  United States
# 5                   101 E Front St  US  Missoula  United States
# 6               1000 E Broadway St  US  Missoula  United States
# 7         401 North Russell Street  US  Missoula  United States
# 8                122 W Broadway St  US  Missoula  United States
# 9                    115 W Main St  US  Missoula  United States
# 10                   143 W Main St  US  Missoula  United States
# 11                             NaN  US  Missoula  United States
# 12                  1330 Howell St  US  Missoula  United States
# 13                             NaN  US  Missoula  United States
# 14                             NaN  US  Missoula  United States
# 15                  215 W Front St  US  Missoula  United States
# 16                             NaN  US  Missoula  United States
# 17      221 E Front St (back door)  US  Missoula  United States
# 18                  520 S 5th St W  US  Missoula  United States
# 19               736 S Higgins Ave  US  Missoula  United States
# 20                  229 E Front St  US  Missoula  United States
# 21               400 W Broadway St  US  Missoula  United States
# 22                             NaN  US  Missoula  United States
# 23                             NaN  US  Missoula  United States
# 24                             NaN  US  Missoula  United States
# 25                             NaN  US  Missoula  United States
# 26                 425 S Orange St  US  Missoula  United States
# 27                 525 E Spruce St  US  Missoula  United States
# 28                             NaN  US  Missoula  United States
# 29               811 S Higgins Ave  US  Missoula  United States
# 30  Phyllis J. Washington Building  US  Missoula  United States
# 31                             NaN  US  Missoula  United States
# 32                             NaN  US  Missoula  United States
# 33                             NaN  US  Missoula  United States
# 34              1415 S Higgins Ave  US  Missoula  United States
# 35              1444 W Broadway St  US  Missoula  United States
# 36                 2530 S 3rd St W  US  Missoula  United States
# 37              2000 W Broadway St  US  Missoula  United States
# 38             2200-2298 Oxford St  US  Missoula  United States
# 39           2504 S Reserve Street  US  Missoula  United States
# 40               1460 S Russell St  US  Missoula  United States
# 41                             NaN  US  Missoula  United States
# 42               1701 Stephens Ave  US  Missoula  United States
# 43              1124 W Central Ave  US  Missoula  United States
# 44                1100 South Ave W  US  Missoula  United States
# 45               420 N Higgins Ave  US  Missoula  United States
# 46               3751 N Reserve St  US  Missoula  United States
# 47           5260 Grant Creek Road  US  Missoula  United States
# 48                  1701 Rankin St  US  Missoula  United States
# 49                         9th St.  US  Missoula  United States
#
#                                  crossStreet  distance  \
# 0                                     Belvue      3207
# 1                                    Johnson      3349
# 2                                        NaN        17
# 3                                        NaN        98
# 4                                        NaN       113
# 5                                        NaN       303
# 6                                        NaN      1092
# 7                                        NaN      2487
# 8                                        NaN       108
# 9                                        NaN       173
# 10                                       NaN       192
# 11                                       NaN       245
# 12                                       NaN      1690
# 13                                       NaN       785
# 14                                       NaN       286
# 15                                       NaN       318
# 16  (lower level of Missoula Public Library)       337
# 17                                       NaN       337
# 18                                       NaN      1135
# 19                                       NaN       929
# 20                                       NaN       308
# 21                                Orange St.       437
# 22                                       NaN       794
# 23                                       NaN       882
# 24                                       NaN       839
# 25                                       NaN       986
# 26                      S. Third Street West       975
# 27                                       NaN      1938
# 28                                       NaN      1072
# 29                                  S 6th St       999
# 30                                       NaN      1244
# 31                                       NaN      1087
# 32                                       NaN      1285
# 33                                       NaN      1475
# 34                                       NaN      1631
# 35                                       NaN      1976
# 36                                       NaN      1496
# 37                                       NaN      2536
# 38                                       NaN      2986
# 39                                       NaN      4352
# 40                                       NaN      2278
# 41                                       NaN      2761
# 42                                       NaN      2425
# 43                                       NaN      2935
# 44                               Malfunction      3059
# 45                                       NaN      2701
# 46                                       NaN      5059
# 47                                       NaN      5568
# 48                                       NaN      3336
# 49                                S. Reserve      3685
#
#                                      formattedAddress  \
# 0   [2710-2 Brooks (Belvue), Missoula, MT 59801, U...
# 1   [1951 Kensington Ave (Johnson), Missoula, MT 5...
# 2   [304 N Higgins Ave, Missoula, MT 59802, United...
# 3   [225 N Higgins Ave Ste B, Missoula, MT 59802, ...
# 4   [214 N Higgins Ave, Missoula, MT 59802, United...
# 5   [101 E Front St, Missoula, MT 59802, United St...
# 6   [1000 E Broadway St, Missoula, MT 59802, Unite...
# 7   [401 North Russell Street, Missoula, MT 59801,...
# 8   [122 W Broadway St, Missoula, MT 59802, United...
# 9   [115 W Main St, Missoula, MT 59802, United Sta...
# 10  [143 W Main St, Missoula, MT 59802, United Sta...
# 11                [Missoula, MT 59802, United States]
# 12      [1330 Howell St, Missoula, MT, United States]
# 13                      [Missoula, MT, United States]
# 14                      [Missoula, MT, United States]
# 15  [215 W Front St, Missoula, MT 59802, United St...
# 16  [(lower level of Missoula Public Library), Mis...
# 17  [221 E Front St (back door), Missoula, MT 5980...
# 18  [520 S 5th St W, Missoula, MT 59801, United St...
# 19  [736 S Higgins Ave, Missoula, MT 59801, United...
# 20  [229 E Front St, Missoula, MT 59802, United St...
# 21  [400 W Broadway St (Orange St.), Missoula, MT ...
# 22                      [Missoula, MT, United States]
# 23                      [Missoula, MT, United States]
# 24                      [Missoula, MT, United States]
# 25                      [Missoula, MT, United States]
# 26  [425 S Orange St (S. Third Street West), Misso...
# 27  [525 E Spruce St, Missoula, MT 59802, United S...
# 28                [Missoula, MT 59801, United States]
# 29  [811 S Higgins Ave (S 6th St), Missoula, MT 59...
# 30  [Phyllis J. Washington Building, Missoula, MT ...
# 31                      [Missoula, MT, United States]
# 32                      [Missoula, MT, United States]
# 33                      [Missoula, MT, United States]
# 34  [1415 S Higgins Ave, Missoula, MT 59801, Unite...
# 35  [1444 W Broadway St, Missoula, MT 59802, Unite...
# 36  [2530 S 3rd St W, Missoula, MT 59804, United S...
# 37  [2000 W Broadway St, Missoula, MT 59808, Unite...
# 38  [2200-2298 Oxford St, Missoula, MT 59801, Unit...
# 39  [2504 S Reserve Street, Missoula, MT 59801, Un...
# 40  [1460 S Russell St, Missoula, MT 59801, United...
# 41                      [Missoula, MT, United States]
# 42  [1701 Stephens Ave, Missoula, MT 59801, United...
# 43  [1124 W Central Ave, Missoula, MT 59801, Unite...
# 44  [1100 South Ave W (Malfunction), Missoula, MT ...
# 45  [420 N Higgins Ave, Missoula, MT 59802, United...
# 46  [3751 N Reserve St, Missoula, MT 59808, United...
# 47  [5260 Grant Creek Road, Missoula, MT 59808, Un...
# 48  [1701 Rankin St, Missoula, MT 59808, United St...
# 49  [9th St. (S. Reserve), Missoula, MT, United St...
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'label': 'display', 'lng': -114.022443460965...  46.851354 -114.022443
# 1   [{'label': 'display', 'lng': -114.02751, 'lat'...  46.853220 -114.027510
# 2   [{'label': 'display', 'lng': -113.993539810180...  46.872338 -113.993540
# 3   [{'label': 'display', 'lng': -113.9946347, 'la...  46.871967 -113.994635
# 4   [{'label': 'display', 'lng': -113.994384525701...  46.871456 -113.994385
# 5   [{'label': 'display', 'lng': -113.995323600659...  46.869837 -113.995324
# 6   [{'label': 'display', 'lng': -113.980252, 'lat...  46.868279 -113.980252
# 7   [{'label': 'display', 'lng': -113.99, 'lat': 4...  46.850000 -113.990000
# 8   [{'label': 'display', 'lng': -113.9947524, 'la...  46.872511 -113.994752
# 9   [{'label': 'display', 'lng': -113.995391694746...  46.871464 -113.995392
# 10  [{'label': 'display', 'lng': -113.995708660809...  46.871513 -113.995709
# 11  [{'label': 'display', 'lng': -113.996539, 'lat...  46.871730 -113.996539
# 12  [{'label': 'display', 'lng': -114.010356, 'lat...  46.882030 -114.010356
# 13  [{'label': 'display', 'lng': -113.997267878748...  46.865681 -113.997268
# 14  [{'label': 'display', 'lng': -113.99661, 'lat'...  46.870880 -113.996610
# 15  [{'label': 'display', 'lng': -113.99688, 'lat'...  46.870630 -113.996880
# 16  [{'label': 'display', 'lng': -113.99094, 'lat'...  46.869698 -113.990940
# 17  [{'label': 'display', 'lng': -113.99317, 'lat'...  46.869197 -113.993170
# 18  [{'label': 'display', 'lng': -114.004191145667...  46.865185 -114.004191
# 19  [{'label': 'display', 'lng': -113.997265, 'lat...  46.864300 -113.997265
# 20  [{'label': 'display', 'lng': -113.992858095068...  46.869472 -113.992858
# 21  [{'label': 'display', 'lng': -113.998724617765...  46.873705 -113.998725
# 22  [{'label': 'display', 'lng': -113.993042, 'lat...  46.879355 -113.993042
# 23  [{'label': 'display', 'lng': -114.000832, 'lat...  46.878299 -114.000832
# 24  [{'label': 'display', 'lng': -113.998053, 'lat...  46.865385 -113.998053
# 25  [{'label': 'display', 'lng': -113.997339, 'lat...  46.863784 -113.997339
# 26  [{'label': 'display', 'lng': -114.003744969668...  46.867051 -114.003745
# 27  [{'label': 'display', 'lng': -114.018863792868...  46.871794 -114.018864
# 28  [{'label': 'display', 'lng': -114.007154, 'lat...  46.870134 -114.007154
# 29  [{'label': 'display', 'lng': -113.99795, 'lat'...  46.863800 -113.997950
# 30  [{'label': 'display', 'lng': -113.984692006893...  46.862759 -113.984692
# 31  [{'label': 'display', 'lng': -113.985481262207...  46.864082 -113.985481
# 32  [{'label': 'display', 'lng': -113.986476892400...  46.861685 -113.986477
# 33  [{'label': 'display', 'lng': -113.983045, 'lat...  46.861018 -113.983045
# 34  [{'label': 'display', 'lng': -113.997594026661...  46.857854 -113.997594
# 35  [{'label': 'display', 'lng': -114.017806, 'lat...  46.878295 -114.017806
# 36  [{'label': 'display', 'lng': -114.011238098144...  46.877876 -114.011238
# 37  [{'label': 'display', 'lng': -114.022990989091...  46.882698 -114.022991
# 38  [{'label': 'display', 'lng': -114.016188400450...  46.850382 -114.016188
# 39  [{'label': 'display', 'lng': -114.03888, 'lat'...  46.848530 -114.038880
# 40  [{'label': 'display', 'lng': -114.018486, 'lat...  46.861060 -114.018486
# 41  [{'label': 'display', 'lng': -114.006506, 'lat...  46.849090 -114.006506
# 42  [{'label': 'display', 'lng': -114.013036, 'lat...  46.855068 -114.013036
# 43  [{'label': 'display', 'lng': -114.016365, 'lat...  46.851044 -114.016365
# 44  [{'label': 'display', 'lng': -114.0259301, 'la...  46.856083 -114.025930
# 45  [{'label': 'display', 'lng': -113.987768969600...  46.848262 -113.987769
# 46  [{'label': 'display', 'lng': -114.0390255, 'la...  46.905285 -114.039025
# 47  [{'label': 'display', 'lng': -114.032927223773...  46.914325 -114.032927
# 48  [{'label': 'display', 'lng': -114.03066053, 'l...  46.888021 -114.030661
# 49  [{'label': 'display', 'lng': -114.039074, 'lat...  46.861242 -114.039074
#
#          neighborhood postalCode state                        id
# 0                 NaN      59801    MT  4c62a462ec94a59339b329ca
# 1                 NaN      59801    MT  5726529b498e11c98359e54b
# 2                 NaN      59802    MT  4b6cbe24f964a520eb502ce3
# 3                 NaN      59802    MT  56ff1fb3498ea80cbf4dff22
# 4                 NaN      59802    MT  4bc8be1b14d7952129c069e9
# 5                 NaN      59802    MT  4c6581ad19f3c9b6fd3e9dff
# 6   Heart of Missoula      59802    MT  55b50814498e519aa04a5911
# 7                 NaN      59801    MT  59980b9bda5e5606a99840e4
# 8                 NaN      59802    MT  5ad5f2b266fc6554d678fb0f
# 9                 NaN      59802    MT  4e5874953151bb7383ae3734
# 10                NaN      59802    MT  4bc9f62868f976b0003f5e83
# 11                NaN      59802    MT  5037dd59e4b0b68ee3d3b2eb
# 12                NaN        NaN    MT  4f43664b19834bc91f568b99
# 13                NaN        NaN    MT  5630f771498eb5d455b2a76d
# 14                NaN        NaN    MT  4bd0ab3577b29c74bf3a8b82
# 15                NaN      59802    MT  5626c4be498e7c342679007b
# 16                NaN      59802    MT  58484ee5b6e67d44e9b89dfb
# 17                NaN      59802    MT  50dc6c3be4b09036bf2d5405
# 18                NaN      59801    MT  4b2ab12ff964a520c9ad24e3
# 19                NaN      59801    MT  59987bc0603d2a6715b44c8e
# 20                NaN      59802    MT  551c7bd7498ef15ec506fda4
# 21                NaN      59802    MT  4b630e15f964a5201d602ae3
# 22                NaN        NaN    MT  53505310498edc226edd484d
# 23                NaN        NaN    MT  545d764a498e306f280d1da9
# 24                NaN        NaN    MT  56ca59fecd109783d03ffaef
# 25                NaN        NaN    MT  52054ce111d26505db892a6f
# 26                NaN      59801    MT  4f29abe7e4b005595f16bc95
# 27           Downtown      59802    MT  4c6dbafc4ee776b00fca531b
# 28                NaN      59801    MT  4ee1164477c804cac6f93cff
# 29                NaN      59801    MT  4b9c092bf964a5204a4336e3
# 30                NaN      59801    MT  504a309ae4b043e9ecf82b67
# 31                NaN        NaN    MT  51474865e4b0ff6e3c3733ca
# 32                NaN        NaN    MT  514a1a41e4b0944727fae79e
# 33                NaN        NaN    MT  5824f35a5496250a92a82255
# 34                NaN      59801    MT  4e3851f345ddd221469f80f2
# 35                NaN      59802    MT  51c4ce01498e67098bd2e0df
# 36                NaN      59804    MT  520ae715498e86ccd4586290
# 37                NaN      59808    MT  4c5c018299ff76b00e59a99e
# 38                NaN      59801    MT  4dc17d387d8bf48713c3a52e
# 39                NaN      59801    MT  4b4636ddf964a520491a26e3
# 40                NaN      59801    MT  5bcde77a4a1cc0002c33df1f
# 41                NaN        NaN    MT  56f595d1cd10a3b06aca635a
# 42                NaN      59801    MT  4f32706619836c91c7d7e869
# 43                NaN      59801    MT  5ba54fa77c891c002d6f0efa
# 44                NaN      59801    MT  4c503d272a73c92836a52bd2
# 45                NaN      59802    MT  4f3244ba19836c91c7c6e40a
# 46                NaN      59808    MT  55c39da4498ecf4c8ae016c2
# 47                NaN      59808    MT  4b56184ef964a5201f0028e3
# 48                NaN      59808    MT  4d87e70d7139b1f70d7997d4
# 49                NaN        NaN    MT  51fc0ebd498e9ba30834e815

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
#folium.features.CircleMarker(
  #  [latitude, longitude],
 #   radius=10,
  #  color='red',
  #  popup='CenterPoint',
  #  fill = True,
 #   fill_color = 'red',
  #  fill_opacity = 0.6
#).add_to(venues_map)

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query = 'bar'
categoryId = '4d4b7105d754a06376d81259' # nightlife spot
radius = 50000
print(search_query + ' .... OK!')
# Out:
# bar .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=46.8722217,-113.993395&v=20180604&query=bar&radius=50000&limit=100'

# %%
# get requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce54d5fdb04f52f5f8b4119'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4b3d4538f964a520629125e3',
#     'location': {'address': '127 W Alder St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 307,
#      'formattedAddress': ['127 W Alder St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8749831689638,
#        'lng': -113.99329289923597}],
#      'lat': 46.8749831689638,
#      'lng': -113.99329289923597,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'James Bar',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4b56aadff964a520091828e3',
#     'location': {'address': '125 W Front St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'at Ryman St',
#      'distance': 298,
#      'formattedAddress': ['125 W Front St (at Ryman St)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87022934126112,
#        'lng': -113.99601674181957}],
#      'lat': 46.87022934126112,
#      'lng': -113.99601674181957,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': "Stockman's Bar & Lunch",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a06',
#       'name': 'Irish Pub',
#       'pluralName': 'Irish Pubs',
#       'primary': True,
#       'shortName': 'Irish'}],
#     'hasPerk': False,
#     'id': '5498c1bf498ea7de4fbd025d',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 167,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.873614907671836,
#        'lng': -113.99423102254114}],
#      'lat': 46.873614907671836,
#      'lng': -113.99423102254114,
#      'state': 'MT'},
#     'name': 'The Thomas Meagher Bar',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '4c6581ad19f3c9b6fd3e9dff',
#     'location': {'address': '101 E Front St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 303,
#      'formattedAddress': ['101 E Front St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86983691515358,
#        'lng': -113.99532360065982}],
#      'lat': 46.86983691515358,
#      'lng': -113.99532360065982,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Hunter Bay Coffee Bar',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '4b293fcaf964a520ac9b24e3',
#     'location': {'address': '111 N Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': '@ W Main St',
#      'distance': 220,
#      'formattedAddress': ['111 N Higgins Ave (@ W Main St)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87062802905879,
#        'lng': -113.99510781846985}],
#      'lat': 46.87062802905879,
#      'lng': -113.99510781846985,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Catalyst Cafe & Espresso Bar',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4ea2657d4690104bb38d49ff',
#     'location': {'address': '225 Ryman St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Btwn W Boradway St. & W Main St.',
#      'distance': 182,
#      'formattedAddress': ['225 Ryman St (Btwn W Boradway St. & W Main St.)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87234597339605,
#        'lng': -113.99578914202914}],
#      'lat': 46.87234597339605,
#      'lng': -113.99578914202914,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': "Monk's Bar",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4c9ab3ac80958cfacf8945d4',
#     'location': {'address': '200 S Pattee St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'at Front St',
#      'distance': 457,
#      'formattedAddress': ['200 S Pattee St (at Front St)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86814029271177,
#        'lng': -113.99406769384906}],
#      'lat': 46.86814029271177,
#      'lng': -113.99406769384906,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Brooks & Browns Bar & Grill',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '4d9965f7178e60fcaef47f60',
#     'location': {'address': '301 E Main St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Front St Entrance of Missoula Public Library',
#      'distance': 271,
#      'formattedAddress': ['301 E Main St (Front St Entrance of Missoula Public Library)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.870207,
#        'lng': -113.991373}],
#      'lat': 46.870207,
#      'lng': -113.991373,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Civitella Espresso Bar',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4b63c60af964a520fc902ae3',
#     'location': {'address': '217 Ryman St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'btwn Broadway & Main',
#      'distance': 200,
#      'formattedAddress': ['217 Ryman St (btwn Broadway & Main)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8720181963696,
#        'lng': -113.99601500626852}],
#      'lat': 46.8720181963696,
#      'lng': -113.99601500626852,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': "Red's Bar",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4b9710e7f964a5203ff634e3',
#     'location': {'address': '143 W Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'at Ryman St',
#      'distance': 141,
#      'formattedAddress': ['143 W Broadway St (at Ryman St)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87236860505371,
#        'lng': -113.99524041026676}],
#      'lat': 46.87236860505371,
#      'lng': -113.99524041026676,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'The Central Bar & Grill',
#     'referralId': 'v-1558531424',
#     'venuePage': {'id': '94609070'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4f32cec019836c91c7fce390',
#     'location': {'address': '231 W Front St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 320,
#      'formattedAddress': ['231 W Front St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.871019,
#        'lng': -113.997216}],
#      'lat': 46.871019,
#      'lng': -113.997216,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Whitewater Bar and Grill',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4c1a75d3e9c4ef3b087845aa',
#     'location': {'address': '321 Westview Dr',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 43,
#      'formattedAddress': ['321 Westview Dr',
#       'Missoula, MT 59803',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.872592323852054,
#        'lng': -113.9935899708429}],
#      'lat': 46.872592323852054,
#      'lng': -113.9935899708429,
#      'postalCode': '59803',
#      'state': 'MT'},
#     'name': "Feruqi's",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d118941735',
#       'name': 'Dive Bar',
#       'pluralName': 'Dive Bars',
#       'primary': True,
#       'shortName': 'Dive Bar'}],
#     'hasPerk': False,
#     'id': '4bd7bd550b779c74d0e505a0',
#     'location': {'address': '307 Railroad St W',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 500,
#      'formattedAddress': ['307 Railroad St W',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87658062650846,
#        'lng': -113.99498793621893}],
#      'lat': 46.87658062650846,
#      'lng': -113.99498793621893,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Silver Dollar Bar',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'primary': True,
#       'shortName': 'Wine Bar'}],
#     'hasPerk': False,
#     'id': '51561a09e4b071544e9c5d30',
#     'location': {'address': '322 N Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 61,
#      'formattedAddress': ['322 N Higgins Ave',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87277414801122,
#        'lng': -113.99342975320207}],
#      'lat': 46.87277414801122,
#      'lng': -113.99342975320207,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Plonk',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4b84bfddf964a520194331e3',
#     'location': {'address': '119 W Alder St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Ryman St',
#      'distance': 318,
#      'formattedAddress': ['119 W Alder St (Ryman St)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.875075665619754,
#        'lng': -113.99308136299489}],
#      'lat': 46.875075665619754,
#      'lng': -113.99308136299489,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': "Al's & Vic's Bar",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4c20ea230110b713f6a59ae7',
#     'location': {'address': '1112 W Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1258,
#      'formattedAddress': ['1112 W Broadway St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.876489,
#        'lng': -114.008705}],
#      'lat': 46.876489,
#      'lng': -114.008705,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Trails End Bar',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '54541900498ea6ccd0202697',
#       'name': 'Health & Beauty Service',
#       'pluralName': 'Health & Beauty Services',
#       'primary': True,
#       'shortName': 'Health & Beauty'}],
#     'hasPerk': False,
#     'id': '5888e5bffebfbd14c69252b0',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2086,
#      'formattedAddress': ['Missoula, MT 59801', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.866188,
#        'lng': -114.019356}],
#      'lat': 46.866188,
#      'lng': -114.019356,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Bliss Beauty Bar',
#     'referralId': 'v-1558531424'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '54952758498e4aec577e77df',
#     'location': {'cc': 'US',
#      'city': 'Missoula, MT, US',
#      'country': 'United States',
#      'distance': 1762,
#      'formattedAddress': ['Missoula, MT, US, WA', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8625,
#        'lng': -114.011667}],
#      'lat': 46.8625,
#      'lng': -114.011667,
#      'state': 'WA'},
#     'name': "Flipper's Bar & Casino",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '4f32496a19836c91c7c8c660',
#     'location': {'address': '111 N Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 167,
#      'formattedAddress': ['111 N Higgins Ave',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.871063,
#        'lng': -113.994796}],
#      'lat': 46.871063,
#      'lng': -113.994796,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Ambrose-Barton and McDowell Wedding Caks and Fne Dsrts',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'primary': True,
#       'shortName': 'Gym'}],
#     'hasPerk': False,
#     'id': '4f4c2a86e4b088c4acd80c4d',
#     'location': {'address': '1900 W Broadway St Ste F',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2428,
#      'formattedAddress': ['1900 W Broadway St Ste F',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.882462191489445,
#        'lng': -114.02158190215316}],
#      'lat': 46.882462191489445,
#      'lng': -114.02158190215316,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Monkey Bar Gymnasium',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d117941735',
#       'name': 'Beer Garden',
#       'pluralName': 'Beer Gardens',
#       'primary': True,
#       'shortName': 'Beer Garden'}],
#     'hasPerk': False,
#     'id': '51b91a69498eb404cc78c133',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1799,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.868709,
#        'lng': -114.01648}],
#      'lat': 46.868709,
#      'lng': -114.01648,
#      'state': 'MT'},
#     'name': "Hauser's Bar and Harvest",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'primary': True,
#       'shortName': 'Wine Bar'}],
#     'hasPerk': False,
#     'id': '4b0c5081f964a5200a3b23e3',
#     'location': {'address': '120 W Front St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 259,
#      'formattedAddress': ['120 W Front St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87038417370668,
#        'lng': -113.99549028649137}],
#      'lat': 46.87038417370668,
#      'lng': -113.99549028649137,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Red Bird',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '4bc9f62868f976b0003f5e83',
#     'location': {'address': '143 W Main St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 192,
#      'formattedAddress': ['143 W Main St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87151349173336,
#        'lng': -113.9957086608098}],
#      'lat': 46.87151349173336,
#      'lng': -113.9957086608098,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Main Street Barber Shop',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'primary': True,
#       'shortName': 'Building'}],
#     'hasPerk': False,
#     'id': '56eb9bd8cd10d9e24d8c77b5',
#     'location': {'address': '336 W Spruce St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 448,
#      'formattedAddress': ['336 W Spruce St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.875576,
#        'lng': -113.996662}],
#      'lat': 46.875576,
#      'lng': -113.996662,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Barnes Melody MSW, LCSW, LAC,',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '5037dd59e4b0b68ee3d3b2eb',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 245,
#      'formattedAddress': ['Missoula, MT 59802', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87173,
#        'lng': -113.996539}],
#      'lat': 46.87173,
#      'lng': -113.996539,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Capitol Barber Shop',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'primary': True,
#       'shortName': "Doctor's Office"}],
#     'hasPerk': False,
#     'id': '5012c5b6e4b0748a78b35bae',
#     'location': {'address': '500 W. Broadway',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 597,
#      'formattedAddress': ['500 W. Broadway',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.874825708047176,
#        'lng': -114.0002631685301}],
#      'lat': 46.874825708047176,
#      'lng': -114.0002631685301,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Bariatrics Clinic',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'id': '5032897c91d4c4b30a586d69',
#       'name': 'Pet Service',
#       'pluralName': 'Pet Services',
#       'primary': True,
#       'shortName': 'Pet Service'}],
#     'hasPerk': False,
#     'id': '5cc200120d173f002cea08b0',
#     'location': {'address': '450 W Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 512,
#      'formattedAddress': ['450 W Broadway St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.873981520209846,
#        'lng': -113.99961589814757}],
#      'lat': 46.873981520209846,
#      'lng': -113.99961589814757,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': "2 Barking Sisters' Dog Spaw",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d101951735',
#       'name': 'Thrift / Vintage Store',
#       'pluralName': 'Thrift / Vintage Stores',
#       'primary': True,
#       'shortName': 'Thrift / Vintage'}],
#     'hasPerk': False,
#     'id': '50ac0d29e4b0c7ff4eb76035',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1530,
#      'formattedAddress': ['Missoula, MT 59801', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.868946,
#        'lng': -114.01293}],
#      'lat': 46.868946,
#      'lng': -114.01293,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Bargain Corner',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4b8cb0c5f964a5209ada32e3',
#     'location': {'address': '201 Railroad St W',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 407,
#      'formattedAddress': ['201 Railroad St W',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87587424598599,
#        'lng': -113.99383503856687}],
#      'lat': 46.87587424598599,
#      'lng': -113.99383503856687,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'The Depot',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'primary': True,
#       'shortName': 'Medical'}],
#     'hasPerk': False,
#     'id': '5b369bf8535d6f002c8b0f77',
#     'location': {'address': '500 West Broadway, 5th Floor',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 608,
#      'formattedAddress': ['500 West Broadway, 5th Floor',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8753292,
#        'lng': -113.9999814}],
#      'lat': 46.8753292,
#      'lng': -113.9999814,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Providence Bariatric Services - Missoula',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '59987bc0603d2a6715b44c8e',
#     'location': {'address': '736 S Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 929,
#      'formattedAddress': ['736 S Higgins Ave',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8643,
#        'lng': -113.997265}],
#      'lat': 46.8643,
#      'lng': -113.997265,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Compass Barber Shop',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'primary': True,
#       'shortName': 'Gym / Fitness'}],
#     'hasPerk': False,
#     'id': '5974c9110802d42bc8d79e9b',
#     'location': {'address': '812 Toole Ave Ste C',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 949,
#      'formattedAddress': ['812 Toole Ave Ste C',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.878259,
#        'lng': -114.002205}],
#      'lat': 46.878259,
#      'lng': -114.002205,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Pure Barre',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'primary': True,
#       'shortName': 'Spa'}],
#     'hasPerk': False,
#     'id': '4b4e1151f964a5205ae026e3',
#     'location': {'address': '725 W Alder St Ste 14',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'btw Alder & Spruce',
#      'distance': 911,
#      'formattedAddress': ['725 W Alder St Ste 14 (btw Alder & Spruce)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87735126308178,
#        'lng': -114.00272515261365}],
#      'lat': 46.87735126308178,
#      'lng': -114.00272515261365,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'The Grizzly Bare Waxing Studio',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '4e3851f345ddd221469f80f2',
#     'location': {'address': '1415 S Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1631,
#      'formattedAddress': ['1415 S Higgins Ave',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.857854036528266,
#        'lng': -113.99759402666187}],
#      'lat': 46.857854036528266,
#      'lng': -113.99759402666187,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': "Dan's Barber Shop",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'id': '5032897c91d4c4b30a586d69',
#       'name': 'Pet Service',
#       'pluralName': 'Pet Services',
#       'primary': True,
#       'shortName': 'Pet Service'}],
#     'hasPerk': False,
#     'id': '53c183c2498e27a169c0b77f',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2146,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87856359855902,
#        'lng': -114.0200393436868}],
#      'lat': 46.87856359855902,
#      'lng': -114.0200393436868,
#      'state': 'MT'},
#     'name': "Two Barking Sisters' Dog Spaw",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11d941735',
#       'name': 'Sports Bar',
#       'pluralName': 'Sports Bars',
#       'primary': True,
#       'shortName': 'Sports Bar'}],
#     'hasPerk': False,
#     'id': '4b09f969f964a520a32023e3',
#     'location': {'address': '835 E Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 851,
#      'formattedAddress': ['835 E Broadway St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86847381428886,
#        'lng': -113.98364740835306}],
#      'lat': 46.86847381428886,
#      'lng': -113.98364740835306,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Press Box Restaurant Casino',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4b537a44f964a520f19e27e3',
#     'location': {'address': 'University of MT Missoula',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Washington - Grizzly Stadium',
#      'distance': 1103,
#      'formattedAddress': ['University of MT Missoula (Washington - Grizzly Stadium)',
#       'Missoula, MT 59812',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86631982903953,
#        'lng': -113.98174528239882}],
#      'lat': 46.86631982903953,
#      'lng': -113.98174528239882,
#      'postalCode': '59812',
#      'state': 'MT'},
#     'name': "Jacob's Island Bark Park",
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d114951735',
#       'name': 'Bookstore',
#       'pluralName': 'Bookstores',
#       'primary': True,
#       'shortName': 'Bookstore'}],
#     'hasPerk': False,
#     'id': '4b4d62b7f964a520c4d126e3',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'at American Way',
#      'distance': 3896,
#      'formattedAddress': ['Missoula, MT 59808', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.89043687109915,
#        'lng': -114.03712034225464}],
#      'lat': 46.89043687109915,
#      'lng': -114.03712034225464,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Barnes & Noble',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '4b783574f964a52073bc2ee3',
#     'location': {'address': '2929 Expo Pkwy',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 5741,
#      'formattedAddress': ['2929 Expo Pkwy',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.91504159436638,
#        'lng': -114.03547407707468}],
#      'lat': 46.91504159436638,
#      'lng': -114.03547407707468,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Cracker Barrel Old Country Store',
#     'referralId': 'v-1558531424'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '500b66f7e4b0715bfcbf0a73',
#     'location': {'cc': 'US',
#      'city': 'Saint Ignatius',
#      'country': 'United States',
#      'distance': 50306,
#      'formattedAddress': ['Saint Ignatius, MT 59865', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.318851345625575,
#        'lng': -114.09462267566325}],
#      'lat': 47.318851345625575,
#      'lng': -114.09462267566325,
#      'postalCode': '59865',
#      'state': 'MT'},
#     'name': 'Silver Dollar Bar and Grill',
#     'referralId': 'v-1558531424'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Bar', 'icon': {'suffix': '.png', 'p...    False
# 1  [{'name': 'Bar', 'icon': {'suffix': '.png', 'p...    False
# 2  [{'name': 'Irish Pub', 'icon': {'suffix': '.pn...    False
# 3  [{'name': 'Café', 'icon': {'suffix': '.png', '...    False
# 4  [{'name': 'Breakfast Spot', 'icon': {'suffix':...    False
#
#                          id   location.address location.cc location.city  \
# 0  4b3d4538f964a520629125e3     127 W Alder St          US      Missoula
# 1  4b56aadff964a520091828e3     125 W Front St          US      Missoula
# 2  5498c1bf498ea7de4fbd025d                NaN          US      Missoula
# 3  4c6581ad19f3c9b6fd3e9dff     101 E Front St          US      Missoula
# 4  4b293fcaf964a520ac9b24e3  111 N Higgins Ave          US      Missoula
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN                307
# 1    United States          at Ryman St                298
# 2    United States                  NaN                167
# 3    United States                  NaN                303
# 4    United States          @ W Main St                220
#
#                            location.formattedAddress  \
# 0  [127 W Alder St, Missoula, MT 59802, United St...
# 1  [125 W Front St (at Ryman St), Missoula, MT 59...
# 2                      [Missoula, MT, United States]
# 3  [101 E Front St, Missoula, MT 59802, United St...
# 4  [111 N Higgins Ave (@ W Main St), Missoula, MT...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lng': -113.993292899235...     46.874983
# 1  [{'label': 'display', 'lng': -113.996016741819...     46.870229
# 2  [{'label': 'display', 'lng': -113.994231022541...     46.873615
# 3  [{'label': 'display', 'lng': -113.995323600659...     46.869837
# 4  [{'label': 'display', 'lng': -113.995107818469...     46.870628
#
#    location.lng location.postalCode location.state  \
# 0   -113.993293               59802             MT
# 1   -113.996017               59802             MT
# 2   -113.994231                 NaN             MT
# 3   -113.995324               59802             MT
# 4   -113.995108               59802             MT
#
#                            name    referralId venuePage.id
# 0                     James Bar  v-1558531424          NaN
# 1        Stockman's Bar & Lunch  v-1558531424          NaN
# 2        The Thomas Meagher Bar  v-1558531424          NaN
# 3         Hunter Bay Coffee Bar  v-1558531424          NaN
# 4  Catalyst Cafe & Espresso Bar  v-1558531424          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                                           James Bar
# 1                              Stockman's Bar & Lunch
# 2                              The Thomas Meagher Bar
# 3                               Hunter Bay Coffee Bar
# 4                        Catalyst Cafe & Espresso Bar
# 5                                          Monk's Bar
# 6                         Brooks & Browns Bar & Grill
# 7                              Civitella Espresso Bar
# 8                                           Red's Bar
# 9                             The Central Bar & Grill
# 10                           Whitewater Bar and Grill
# 11                                           Feruqi's
# 12                                  Silver Dollar Bar
# 13                                              Plonk
# 14                                   Al's & Vic's Bar
# 15                                     Trails End Bar
# 16                                   Bliss Beauty Bar
# 17                             Flipper's Bar & Casino
# 18  Ambrose-Barton and McDowell Wedding Caks and F...
# 19                               Monkey Bar Gymnasium
# 20                           Hauser's Bar and Harvest
# 21                                           Red Bird
# 22                            Main Street Barber Shop
# 23                      Barnes Melody MSW, LCSW, LAC,
# 24                                Capitol Barber Shop
# 25                                  Bariatrics Clinic
# 26                        2 Barking Sisters' Dog Spaw
# 27                                     Bargain Corner
# 28                                          The Depot
# 29           Providence Bariatric Services - Missoula
# 30                                Compass Barber Shop
# 31                                         Pure Barre
# 32                     The Grizzly Bare Waxing Studio
# 33                                  Dan's Barber Shop
# 34                      Two Barking Sisters' Dog Spaw
# 35                        Press Box Restaurant Casino
# 36                           Jacob's Island Bark Park
# 37                                     Barnes & Noble
# 38                   Cracker Barrel Old Country Store
# 39                        Silver Dollar Bar and Grill
#
#                  categories                       address  cc  \
# 0                       Bar                127 W Alder St  US
# 1                       Bar                125 W Front St  US
# 2                 Irish Pub                           NaN  US
# 3                      Café                101 E Front St  US
# 4            Breakfast Spot             111 N Higgins Ave  US
# 5                       Bar                  225 Ryman St  US
# 6                Restaurant               200 S Pattee St  US
# 7               Coffee Shop                 301 E Main St  US
# 8                       Bar                  217 Ryman St  US
# 9                       Bar             143 W Broadway St  US
# 10                      Bar                231 W Front St  US
# 11                      Bar               321 Westview Dr  US
# 12                 Dive Bar             307 Railroad St W  US
# 13                 Wine Bar             322 N Higgins Ave  US
# 14                      Bar                119 W Alder St  US
# 15                      Bar            1112 W Broadway St  US
# 16  Health & Beauty Service                           NaN  US
# 17                     None                           NaN  US
# 18                   Bakery             111 N Higgins Ave  US
# 19                      Gym      1900 W Broadway St Ste F  US
# 20              Beer Garden                           NaN  US
# 21                 Wine Bar                120 W Front St  US
# 22       Salon / Barbershop                 143 W Main St  US
# 23                 Building               336 W Spruce St  US
# 24       Salon / Barbershop                           NaN  US
# 25          Doctor's Office               500 W. Broadway  US
# 26              Pet Service             450 W Broadway St  US
# 27   Thrift / Vintage Store                           NaN  US
# 28                      Bar             201 Railroad St W  US
# 29           Medical Center  500 West Broadway, 5th Floor  US
# 30       Salon / Barbershop             736 S Higgins Ave  US
# 31     Gym / Fitness Center           812 Toole Ave Ste C  US
# 32                      Spa         725 W Alder St Ste 14  US
# 33       Salon / Barbershop            1415 S Higgins Ave  US
# 34              Pet Service                           NaN  US
# 35               Sports Bar             835 E Broadway St  US
# 36                     Park     University of MT Missoula  US
# 37                Bookstore                           NaN  US
# 38      American Restaurant                2929 Expo Pkwy  US
# 39                      Bar                           NaN  US
#
#                 city        country  \
# 0           Missoula  United States
# 1           Missoula  United States
# 2           Missoula  United States
# 3           Missoula  United States
# 4           Missoula  United States
# 5           Missoula  United States
# 6           Missoula  United States
# 7           Missoula  United States
# 8           Missoula  United States
# 9           Missoula  United States
# 10          Missoula  United States
# 11          Missoula  United States
# 12          Missoula  United States
# 13          Missoula  United States
# 14          Missoula  United States
# 15          Missoula  United States
# 16          Missoula  United States
# 17  Missoula, MT, US  United States
# 18          Missoula  United States
# 19          Missoula  United States
# 20          Missoula  United States
# 21          Missoula  United States
# 22          Missoula  United States
# 23          Missoula  United States
# 24          Missoula  United States
# 25          Missoula  United States
# 26          Missoula  United States
# 27          Missoula  United States
# 28          Missoula  United States
# 29          Missoula  United States
# 30          Missoula  United States
# 31          Missoula  United States
# 32          Missoula  United States
# 33          Missoula  United States
# 34          Missoula  United States
# 35          Missoula  United States
# 36          Missoula  United States
# 37          Missoula  United States
# 38          Missoula  United States
# 39    Saint Ignatius  United States
#
#                                      crossStreet  distance  \
# 0                                            NaN       307
# 1                                    at Ryman St       298
# 2                                            NaN       167
# 3                                            NaN       303
# 4                                    @ W Main St       220
# 5               Btwn W Boradway St. & W Main St.       182
# 6                                    at Front St       457
# 7   Front St Entrance of Missoula Public Library       271
# 8                           btwn Broadway & Main       200
# 9                                    at Ryman St       141
# 10                                           NaN       320
# 11                                           NaN        43
# 12                                           NaN       500
# 13                                           NaN        61
# 14                                      Ryman St       318
# 15                                           NaN      1258
# 16                                           NaN      2086
# 17                                           NaN      1762
# 18                                           NaN       167
# 19                                           NaN      2428
# 20                                           NaN      1799
# 21                                           NaN       259
# 22                                           NaN       192
# 23                                           NaN       448
# 24                                           NaN       245
# 25                                           NaN       597
# 26                                           NaN       512
# 27                                           NaN      1530
# 28                                           NaN       407
# 29                                           NaN       608
# 30                                           NaN       929
# 31                                           NaN       949
# 32                            btw Alder & Spruce       911
# 33                                           NaN      1631
# 34                                           NaN      2146
# 35                                           NaN       851
# 36                  Washington - Grizzly Stadium      1103
# 37                               at American Way      3896
# 38                                           NaN      5741
# 39                                           NaN     50306
#
#                                      formattedAddress  \
# 0   [127 W Alder St, Missoula, MT 59802, United St...
# 1   [125 W Front St (at Ryman St), Missoula, MT 59...
# 2                       [Missoula, MT, United States]
# 3   [101 E Front St, Missoula, MT 59802, United St...
# 4   [111 N Higgins Ave (@ W Main St), Missoula, MT...
# 5   [225 Ryman St (Btwn W Boradway St. & W Main St...
# 6   [200 S Pattee St (at Front St), Missoula, MT 5...
# 7   [301 E Main St (Front St Entrance of Missoula ...
# 8   [217 Ryman St (btwn Broadway & Main), Missoula...
# 9   [143 W Broadway St (at Ryman St), Missoula, MT...
# 10  [231 W Front St, Missoula, MT 59802, United St...
# 11  [321 Westview Dr, Missoula, MT 59803, United S...
# 12  [307 Railroad St W, Missoula, MT 59802, United...
# 13  [322 N Higgins Ave, Missoula, MT 59802, United...
# 14  [119 W Alder St (Ryman St), Missoula, MT 59802...
# 15  [1112 W Broadway St, Missoula, MT 59802, Unite...
# 16                [Missoula, MT 59801, United States]
# 17              [Missoula, MT, US, WA, United States]
# 18  [111 N Higgins Ave, Missoula, MT 59802, United...
# 19  [1900 W Broadway St Ste F, Missoula, MT 59808,...
# 20                      [Missoula, MT, United States]
# 21  [120 W Front St, Missoula, MT 59802, United St...
# 22  [143 W Main St, Missoula, MT 59802, United Sta...
# 23  [336 W Spruce St, Missoula, MT 59802, United S...
# 24                [Missoula, MT 59802, United States]
# 25  [500 W. Broadway, Missoula, MT 59802, United S...
# 26  [450 W Broadway St, Missoula, MT 59802, United...
# 27                [Missoula, MT 59801, United States]
# 28  [201 Railroad St W, Missoula, MT 59802, United...
# 29  [500 West Broadway, 5th Floor, Missoula, MT 59...
# 30  [736 S Higgins Ave, Missoula, MT 59801, United...
# 31  [812 Toole Ave Ste C, Missoula, MT 59802, Unit...
# 32  [725 W Alder St Ste 14 (btw Alder & Spruce), M...
# 33  [1415 S Higgins Ave, Missoula, MT 59801, Unite...
# 34                      [Missoula, MT, United States]
# 35  [835 E Broadway St, Missoula, MT 59802, United...
# 36  [University of MT Missoula (Washington - Grizz...
# 37                [Missoula, MT 59808, United States]
# 38  [2929 Expo Pkwy, Missoula, MT 59808, United St...
# 39          [Saint Ignatius, MT 59865, United States]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'label': 'display', 'lng': -113.993292899235...  46.874983 -113.993293
# 1   [{'label': 'display', 'lng': -113.996016741819...  46.870229 -113.996017
# 2   [{'label': 'display', 'lng': -113.994231022541...  46.873615 -113.994231
# 3   [{'label': 'display', 'lng': -113.995323600659...  46.869837 -113.995324
# 4   [{'label': 'display', 'lng': -113.995107818469...  46.870628 -113.995108
# 5   [{'label': 'display', 'lng': -113.995789142029...  46.872346 -113.995789
# 6   [{'label': 'display', 'lng': -113.994067693849...  46.868140 -113.994068
# 7   [{'label': 'display', 'lng': -113.991373, 'lat...  46.870207 -113.991373
# 8   [{'label': 'display', 'lng': -113.996015006268...  46.872018 -113.996015
# 9   [{'label': 'display', 'lng': -113.995240410266...  46.872369 -113.995240
# 10  [{'label': 'display', 'lng': -113.997216, 'lat...  46.871019 -113.997216
# 11  [{'label': 'display', 'lng': -113.993589970842...  46.872592 -113.993590
# 12  [{'label': 'display', 'lng': -113.994987936218...  46.876581 -113.994988
# 13  [{'label': 'display', 'lng': -113.993429753202...  46.872774 -113.993430
# 14  [{'label': 'display', 'lng': -113.993081362994...  46.875076 -113.993081
# 15  [{'label': 'display', 'lng': -114.008705, 'lat...  46.876489 -114.008705
# 16  [{'label': 'display', 'lng': -114.019356, 'lat...  46.866188 -114.019356
# 17  [{'label': 'display', 'lng': -114.011667, 'lat...  46.862500 -114.011667
# 18  [{'label': 'display', 'lng': -113.994796, 'lat...  46.871063 -113.994796
# 19  [{'label': 'display', 'lng': -114.021581902153...  46.882462 -114.021582
# 20  [{'label': 'display', 'lng': -114.01648, 'lat'...  46.868709 -114.016480
# 21  [{'label': 'display', 'lng': -113.995490286491...  46.870384 -113.995490
# 22  [{'label': 'display', 'lng': -113.995708660809...  46.871513 -113.995709
# 23  [{'label': 'display', 'lng': -113.996662, 'lat...  46.875576 -113.996662
# 24  [{'label': 'display', 'lng': -113.996539, 'lat...  46.871730 -113.996539
# 25  [{'label': 'display', 'lng': -114.000263168530...  46.874826 -114.000263
# 26  [{'label': 'display', 'lng': -113.999615898147...  46.873982 -113.999616
# 27  [{'label': 'display', 'lng': -114.01293, 'lat'...  46.868946 -114.012930
# 28  [{'label': 'display', 'lng': -113.993835038566...  46.875874 -113.993835
# 29  [{'label': 'display', 'lng': -113.9999814, 'la...  46.875329 -113.999981
# 30  [{'label': 'display', 'lng': -113.997265, 'lat...  46.864300 -113.997265
# 31  [{'label': 'display', 'lng': -114.002205, 'lat...  46.878259 -114.002205
# 32  [{'label': 'display', 'lng': -114.002725152613...  46.877351 -114.002725
# 33  [{'label': 'display', 'lng': -113.997594026661...  46.857854 -113.997594
# 34  [{'label': 'display', 'lng': -114.020039343686...  46.878564 -114.020039
# 35  [{'label': 'display', 'lng': -113.983647408353...  46.868474 -113.983647
# 36  [{'label': 'display', 'lng': -113.981745282398...  46.866320 -113.981745
# 37  [{'label': 'display', 'lng': -114.037120342254...  46.890437 -114.037120
# 38  [{'label': 'display', 'lng': -114.035474077074...  46.915042 -114.035474
# 39  [{'label': 'display', 'lng': -114.094622675663...  47.318851 -114.094623
#
#    postalCode state                        id
# 0       59802    MT  4b3d4538f964a520629125e3
# 1       59802    MT  4b56aadff964a520091828e3
# 2         NaN    MT  5498c1bf498ea7de4fbd025d
# 3       59802    MT  4c6581ad19f3c9b6fd3e9dff
# 4       59802    MT  4b293fcaf964a520ac9b24e3
# 5       59802    MT  4ea2657d4690104bb38d49ff
# 6       59802    MT  4c9ab3ac80958cfacf8945d4
# 7       59802    MT  4d9965f7178e60fcaef47f60
# 8       59802    MT  4b63c60af964a520fc902ae3
# 9       59802    MT  4b9710e7f964a5203ff634e3
# 10      59802    MT  4f32cec019836c91c7fce390
# 11      59803    MT  4c1a75d3e9c4ef3b087845aa
# 12      59802    MT  4bd7bd550b779c74d0e505a0
# 13      59802    MT  51561a09e4b071544e9c5d30
# 14      59802    MT  4b84bfddf964a520194331e3
# 15      59802    MT  4c20ea230110b713f6a59ae7
# 16      59801    MT  5888e5bffebfbd14c69252b0
# 17        NaN    WA  54952758498e4aec577e77df
# 18      59802    MT  4f32496a19836c91c7c8c660
# 19      59808    MT  4f4c2a86e4b088c4acd80c4d
# 20        NaN    MT  51b91a69498eb404cc78c133
# 21      59802    MT  4b0c5081f964a5200a3b23e3
# 22      59802    MT  4bc9f62868f976b0003f5e83
# 23      59802    MT  56eb9bd8cd10d9e24d8c77b5
# 24      59802    MT  5037dd59e4b0b68ee3d3b2eb
# 25      59802    MT  5012c5b6e4b0748a78b35bae
# 26      59802    MT  5cc200120d173f002cea08b0
# 27      59801    MT  50ac0d29e4b0c7ff4eb76035
# 28      59802    MT  4b8cb0c5f964a5209ada32e3
# 29      59802    MT  5b369bf8535d6f002c8b0f77
# 30      59801    MT  59987bc0603d2a6715b44c8e
# 31      59802    MT  5974c9110802d42bc8d79e9b
# 32      59802    MT  4b4e1151f964a5205ae026e3
# 33      59801    MT  4e3851f345ddd221469f80f2
# 34        NaN    MT  53c183c2498e27a169c0b77f
# 35      59802    MT  4b09f969f964a520a32023e3
# 36      59812    MT  4b537a44f964a520f19e27e3
# 37      59808    MT  4b4d62b7f964a520c4d126e3
# 38      59808    MT  4b783574f964a52073bc2ee3
# 39      59865    MT  500b66f7e4b0715bfcbf0a73

# %%
dataframe_filtered.name
# Out:
# 0                                             James Bar
# 1                                Stockman's Bar & Lunch
# 2                                The Thomas Meagher Bar
# 3                                 Hunter Bay Coffee Bar
# 4                          Catalyst Cafe & Espresso Bar
# 5                                            Monk's Bar
# 6                           Brooks & Browns Bar & Grill
# 7                                Civitella Espresso Bar
# 8                                             Red's Bar
# 9                               The Central Bar & Grill
# 10                             Whitewater Bar and Grill
# 11                                             Feruqi's
# 12                                    Silver Dollar Bar
# 13                                                Plonk
# 14                                     Al's & Vic's Bar
# 15                                       Trails End Bar
# 16                                     Bliss Beauty Bar
# 17                               Flipper's Bar & Casino
# 18    Ambrose-Barton and McDowell Wedding Caks and F...
# 19                                 Monkey Bar Gymnasium
# 20                             Hauser's Bar and Harvest
# 21                                             Red Bird
# 22                              Main Street Barber Shop
# 23                        Barnes Melody MSW, LCSW, LAC,
# 24                                  Capitol Barber Shop
# 25                                    Bariatrics Clinic
# 26                          2 Barking Sisters' Dog Spaw
# 27                                       Bargain Corner
# 28                                            The Depot
# 29             Providence Bariatric Services - Missoula
# 30                                  Compass Barber Shop
# 31                                           Pure Barre
# 32                       The Grizzly Bare Waxing Studio
# 33                                    Dan's Barber Shop
# 34                        Two Barking Sisters' Dog Spaw
# 35                          Press Box Restaurant Casino
# 36                             Jacob's Island Bark Park
# 37                                       Barnes & Noble
# 38                     Cracker Barrel Old Country Store
# 39                          Silver Dollar Bar and Grill
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
#folium.features.CircleMarker(
  #  [latitude, longitude],
 #   radius=10,
  #  color='red',
  #  popup='CenterPoint',
  #  fill = True,
 #   fill_color = 'red',
  #  fill_opacity = 0.6
#).add_to(venues_map)

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query = 'pharmacy'
categoryId = '4bf58dd8d48988d10f951735' # pharmacy
radius = 50000
print(search_query + ' .... OK!')
# Out:
# pharmacy .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=46.8722217,-113.993395&v=20180604&query=pharmacy&radius=50000&limit=100'

# %%
# get requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce4569ff594df57eda9ed9d'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4d8b9d4f0c4e41bd669e667f',
#     'location': {'address': '1914 Brooks St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2532,
#      'formattedAddress': ['1914 Brooks St',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.85258416253534,
#        'lng': -114.01020018144806}],
#      'lat': 46.85258416253534,
#      'lng': -114.01020018144806,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'CVS pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5745e8a0498e90b028ec239e',
#     'location': {'address': '1003 E Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1068,
#      'formattedAddress': ['1003 E Broadway St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8675817,
#        'lng': -113.9811003}],
#      'lat': 46.8675817,
#      'lng': -113.9811003,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Albertsons Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '50f59a61e4b0f23328273ad9',
#     'location': {'address': '634 Eddy Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1123,
#      'formattedAddress': ['634 Eddy Ave',
#       'Missoula, MT 59812',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.863056,
#        'lng': -113.987215}],
#      'lat': 46.863056,
#      'lng': -113.987215,
#      'postalCode': '59812',
#      'state': 'MT'},
#     'name': 'Health Service Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4de51f69d164df85753a4972',
#     'location': {'address': '3800 Russell St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 4342,
#      'formattedAddress': ['3800 Russell St',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.83632,
#        'lng': -114.0156977}],
#      'lat': 46.83632,
#      'lng': -114.0156977,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Albertsons Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '593b38e67564f74a3fb7cd5d',
#     'location': {'address': '3220 N Reserve St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 4238,
#      'formattedAddress': ['3220 N Reserve St',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.895245,
#        'lng': -114.03777}],
#      'lat': 46.895245,
#      'lng': -114.03777,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Costco Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5a8e707c7564f71732894928',
#     'location': {'address': '1315 Wyoming St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1710,
#      'formattedAddress': ['1315 Wyoming St',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8711139,
#        'lng': -114.0158109}],
#      'lat': 46.8711139,
#      'lng': -114.0158109,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': '406 Clinic Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '5745e8a0498e90b028ec2398',
#     'location': {'address': '2205 Oxford St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2999,
#      'formattedAddress': ['2205 Oxford St',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.85106477408421,
#        'lng': -114.01780682808749}],
#      'lat': 46.85106477408421,
#      'lng': -114.01780682808749,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Albertsons Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4e1355a462e1d997a6b07236',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 3819,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.860415,
#        'lng': -114.040517}],
#      'lat': 46.860415,
#      'lng': -114.040517,
#      'state': 'MT'},
#     'name': 'Missoula Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '551c1118498e6d869618466c',
#     'location': {'address': '3555 Mullan Rd',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 3642,
#      'formattedAddress': ['3555 Mullan Rd',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.88518298883073,
#        'lng': -114.03734386703765}],
#      'lat': 46.88518298883073,
#      'lng': -114.03734386703765,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Walmart Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '57473f72498e71b6d3adfa16',
#     'location': {'address': '2230 N Reserve St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 3601,
#      'formattedAddress': ['2230 N Reserve St',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.885870649002555,
#        'lng': -114.03631487492021}],
#      'lat': 46.885870649002555,
#      'lng': -114.03631487492021,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Albertsons Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '54f11eec498e6903bf0a3d7f',
#     'location': {'address': '2230 27th Ave #2',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 4614,
#      'formattedAddress': ['2230 27th Ave #2',
#       'Missoula, MT 59804',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.85017369687557,
#        'lng': -114.0447398275137}],
#      'lat': 46.85017369687557,
#      'lng': -114.0447398275137,
#      'postalCode': '59804',
#      'state': 'MT'},
#     'name': 'Granite Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '551c1116498e6d86961818e6',
#     'location': {'address': '4000 Hwy 93 South',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 6024,
#      'formattedAddress': ['4000 Hwy 93 South',
#       'Missoula, MT 59804',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8333629,
#        'lng': -114.048468}],
#      'lat': 46.8333629,
#      'lng': -114.048468,
#      'postalCode': '59804',
#      'state': 'MT'},
#     'name': 'Walmart Pharmacy',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/video_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d126951735',
#       'name': 'Video Store',
#       'pluralName': 'Video Stores',
#       'primary': True,
#       'shortName': 'Video Store'}],
#     'hasPerk': False,
#     'id': '4e31c4302fb6ede816e37ab9',
#     'location': {'address': '2350 S Reserve St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 3002,
#      'formattedAddress': ['2350 S Reserve St',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.856274,
#        'lng': -114.025207}],
#      'lat': 46.856274,
#      'lng': -114.025207,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Redbox',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '599306066661167aebe7459e',
#     'location': {'address': '3555 Mullan Rd',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 3973,
#      'formattedAddress': ['3555 Mullan Rd',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.88536149,
#        'lng': -114.0419525}],
#      'lat': 46.88536149,
#      'lng': -114.0419525,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Walmart Bakery',
#     'referralId': 'v-1558468255'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '5992d9bbf870fd2c30740e82',
#     'location': {'address': '4000 Hwy 93 South',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 6012,
#      'formattedAddress': ['4000 Hwy 93 South',
#       'Missoula, MT 59804',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8334211,
#        'lng': -114.048341}],
#      'lat': 46.8334211,
#      'lng': -114.048341,
#      'postalCode': '59804',
#      'state': 'MT'},
#     'name': 'Walmart Bakery',
#     'referralId': 'v-1558468255'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Pharmacy', 'primary': True, 'i...    False
# 1  [{'shortName': 'Pharmacy', 'primary': True, 'i...    False
# 2  [{'shortName': 'Pharmacy', 'primary': True, 'i...    False
# 3  [{'shortName': 'Pharmacy', 'primary': True, 'i...    False
# 4  [{'shortName': 'Pharmacy', 'primary': True, 'i...    False
#
#                          id    location.address location.cc location.city  \
# 0  4d8b9d4f0c4e41bd669e667f      1914 Brooks St          US      Missoula
# 1  5745e8a0498e90b028ec239e  1003 E Broadway St          US      Missoula
# 2  50f59a61e4b0f23328273ad9        634 Eddy Ave          US      Missoula
# 3  4de51f69d164df85753a4972     3800 Russell St          US      Missoula
# 4  593b38e67564f74a3fb7cd5d   3220 N Reserve St          US      Missoula
#
#   location.country  location.distance  \
# 0    United States               2532
# 1    United States               1068
# 2    United States               1123
# 3    United States               4342
# 4    United States               4238
#
#                            location.formattedAddress  \
# 0  [1914 Brooks St, Missoula, MT 59801, United St...
# 1  [1003 E Broadway St, Missoula, MT 59802, Unite...
# 2  [634 Eddy Ave, Missoula, MT 59812, United States]
# 3  [3800 Russell St, Missoula, MT 59801, United S...
# 4  [3220 N Reserve St, Missoula, MT 59808, United...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 46.85258416253534, 'lng': -114.010200...     46.852584
# 1  [{'lat': 46.8675817, 'lng': -113.9811003, 'lab...     46.867582
# 2  [{'lat': 46.863056, 'lng': -113.987215, 'label...     46.863056
# 3  [{'lat': 46.83632, 'lng': -114.0156977, 'label...     46.836320
# 4  [{'lat': 46.895245, 'lng': -114.03777, 'label'...     46.895245
#
#    location.lng location.postalCode location.state                     name  \
# 0   -114.010200               59801             MT             CVS pharmacy
# 1   -113.981100               59802             MT      Albertsons Pharmacy
# 2   -113.987215               59812             MT  Health Service Pharmacy
# 3   -114.015698               59801             MT      Albertsons Pharmacy
# 4   -114.037770               59808             MT          Costco Pharmacy
#
#      referralId
# 0  v-1558468255
# 1  v-1558468255
# 2  v-1558468255
# 3  v-1558468255
# 4  v-1558468255

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                        name   categories             address  cc      city  \
# 0              CVS pharmacy     Pharmacy      1914 Brooks St  US  Missoula
# 1       Albertsons Pharmacy     Pharmacy  1003 E Broadway St  US  Missoula
# 2   Health Service Pharmacy     Pharmacy        634 Eddy Ave  US  Missoula
# 3       Albertsons Pharmacy     Pharmacy     3800 Russell St  US  Missoula
# 4           Costco Pharmacy     Pharmacy   3220 N Reserve St  US  Missoula
# 5       406 Clinic Pharmacy     Pharmacy     1315 Wyoming St  US  Missoula
# 6       Albertsons Pharmacy     Pharmacy      2205 Oxford St  US  Missoula
# 7         Missoula Pharmacy     Pharmacy                 NaN  US  Missoula
# 8          Walmart Pharmacy     Pharmacy      3555 Mullan Rd  US  Missoula
# 9       Albertsons Pharmacy     Pharmacy   2230 N Reserve St  US  Missoula
# 10         Granite Pharmacy     Pharmacy    2230 27th Ave #2  US  Missoula
# 11         Walmart Pharmacy     Pharmacy   4000 Hwy 93 South  US  Missoula
# 12                   Redbox  Video Store   2350 S Reserve St  US  Missoula
# 13           Walmart Bakery       Bakery      3555 Mullan Rd  US  Missoula
# 14           Walmart Bakery       Bakery   4000 Hwy 93 South  US  Missoula
#
#           country  distance  \
# 0   United States      2532
# 1   United States      1068
# 2   United States      1123
# 3   United States      4342
# 4   United States      4238
# 5   United States      1710
# 6   United States      2999
# 7   United States      3819
# 8   United States      3642
# 9   United States      3601
# 10  United States      4614
# 11  United States      6024
# 12  United States      3002
# 13  United States      3973
# 14  United States      6012
#
#                                      formattedAddress  \
# 0   [1914 Brooks St, Missoula, MT 59801, United St...
# 1   [1003 E Broadway St, Missoula, MT 59802, Unite...
# 2   [634 Eddy Ave, Missoula, MT 59812, United States]
# 3   [3800 Russell St, Missoula, MT 59801, United S...
# 4   [3220 N Reserve St, Missoula, MT 59808, United...
# 5   [1315 Wyoming St, Missoula, MT 59801, United S...
# 6   [2205 Oxford St, Missoula, MT 59801, United St...
# 7                       [Missoula, MT, United States]
# 8   [3555 Mullan Rd, Missoula, MT 59808, United St...
# 9   [2230 N Reserve St, Missoula, MT 59808, United...
# 10  [2230 27th Ave #2, Missoula, MT 59804, United ...
# 11  [4000 Hwy 93 South, Missoula, MT 59804, United...
# 12  [2350 S Reserve St, Missoula, MT 59801, United...
# 13  [3555 Mullan Rd, Missoula, MT 59808, United St...
# 14  [4000 Hwy 93 South, Missoula, MT 59804, United...
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'lat': 46.85258416253534, 'lng': -114.010200...  46.852584 -114.010200
# 1   [{'lat': 46.8675817, 'lng': -113.9811003, 'lab...  46.867582 -113.981100
# 2   [{'lat': 46.863056, 'lng': -113.987215, 'label...  46.863056 -113.987215
# 3   [{'lat': 46.83632, 'lng': -114.0156977, 'label...  46.836320 -114.015698
# 4   [{'lat': 46.895245, 'lng': -114.03777, 'label'...  46.895245 -114.037770
# 5   [{'lat': 46.8711139, 'lng': -114.0158109, 'lab...  46.871114 -114.015811
# 6   [{'lat': 46.85106477408421, 'lng': -114.017806...  46.851065 -114.017807
# 7   [{'lat': 46.860415, 'lng': -114.040517, 'label...  46.860415 -114.040517
# 8   [{'lat': 46.88518298883073, 'lng': -114.037343...  46.885183 -114.037344
# 9   [{'lat': 46.885870649002555, 'lng': -114.03631...  46.885871 -114.036315
# 10  [{'lat': 46.85017369687557, 'lng': -114.044739...  46.850174 -114.044740
# 11  [{'lat': 46.8333629, 'lng': -114.048468, 'labe...  46.833363 -114.048468
# 12  [{'lat': 46.856274, 'lng': -114.025207, 'label...  46.856274 -114.025207
# 13  [{'lat': 46.88536149, 'lng': -114.0419525, 'la...  46.885361 -114.041952
# 14  [{'lat': 46.8334211, 'lng': -114.048341, 'labe...  46.833421 -114.048341
#
#    postalCode state                        id
# 0       59801    MT  4d8b9d4f0c4e41bd669e667f
# 1       59802    MT  5745e8a0498e90b028ec239e
# 2       59812    MT  50f59a61e4b0f23328273ad9
# 3       59801    MT  4de51f69d164df85753a4972
# 4       59808    MT  593b38e67564f74a3fb7cd5d
# 5       59801    MT  5a8e707c7564f71732894928
# 6       59801    MT  5745e8a0498e90b028ec2398
# 7         NaN    MT  4e1355a462e1d997a6b07236
# 8       59808    MT  551c1118498e6d869618466c
# 9       59808    MT  57473f72498e71b6d3adfa16
# 10      59804    MT  54f11eec498e6903bf0a3d7f
# 11      59804    MT  551c1116498e6d86961818e6
# 12      59801    MT  4e31c4302fb6ede816e37ab9
# 13      59808    MT  599306066661167aebe7459e
# 14      59804    MT  5992d9bbf870fd2c30740e82

# %%
dataframe_filtered.name
# Out:
# 0                CVS pharmacy
# 1         Albertsons Pharmacy
# 2     Health Service Pharmacy
# 3         Albertsons Pharmacy
# 4             Costco Pharmacy
# 5         406 Clinic Pharmacy
# 6         Albertsons Pharmacy
# 7           Missoula Pharmacy
# 8            Walmart Pharmacy
# 9         Albertsons Pharmacy
# 10           Granite Pharmacy
# 11           Walmart Pharmacy
# 12                     Redbox
# 13             Walmart Bakery
# 14             Walmart Bakery
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# search query by category
search_query = 'brewery'
categoryId = '50327c8591d4c4b30a586d5d' # brewery
radius = 50000
print(search_query + ' .... OK!')
# Out:
# brewery .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=46.8722217,-113.993395&v=20180604&query=brewery&radius=50000&limit=100'

# %%
# get requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce453d26a6071493bae9f63'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d118941735',
#       'name': 'Dive Bar',
#       'pluralName': 'Dive Bars',
#       'primary': True,
#       'shortName': 'Dive Bar'}],
#     'hasPerk': False,
#     'id': '53f2a35b498e7b65981eb526',
#     'location': {'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 769,
#      'formattedAddress': ['Missoula, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.877627,
#        'lng': -113.999697}],
#      'lat': 46.877627,
#      'lng': -113.999697,
#      'state': 'MT'},
#     'name': 'Brewery Park',
#     'referralId': 'v-1558467538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'primary': True,
#       'shortName': 'Music Venue'}],
#     'hasPerk': False,
#     'id': '5718858acd10a651ba07619e',
#     'location': {'cc': 'US',
#      'city': 'Missoula, MT, US',
#      'country': 'United States',
#      'distance': 762,
#      'formattedAddress': ['Missoula, MT, US, WA', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8787176,
#        'lng': -113.996586}],
#      'lat': 46.8787176,
#      'lng': -113.996586,
#      'state': 'WA'},
#     'name': 'Big Sky Brewery',
#     'referralId': 'v-1558467538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'primary': True,
#       'shortName': 'Gastropub'}],
#     'hasPerk': False,
#     'id': '4da4a4ce9aa4721e29553c1a',
#     'location': {'address': '231 W Front St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'at Carousel Dr',
#      'distance': 334,
#      'formattedAddress': ['231 W Front St (at Carousel Dr)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87095405942777,
#        'lng': -113.99738678171228}],
#      'lat': 46.87095405942777,
#      'lng': -113.99738678171228,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Tamarack Brewing Company Alehouse And Grill',
#     'referralId': 'v-1558467538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'primary': True,
#       'shortName': 'Gastropub'}],
#     'hasPerk': False,
#     'id': '4cf6f3a4c020b60c92112375',
#     'location': {'address': '424 N Higgins Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 145,
#      'formattedAddress': ['424 N Higgins Ave',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87346171289112,
#        'lng': -113.99280987296395}],
#      'lat': 46.87346171289112,
#      'lng': -113.99280987296395,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Flathead Lake Brewing Company of Missoula',
#     'referralId': 'v-1558467538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '4b7b6248f964a52019612fe3',
#     'location': {'address': '313 N 1st St W',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'at N Orange St.',
#      'distance': 614,
#      'formattedAddress': ['313 N 1st St W (at N Orange St.)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87766,
#        'lng': -113.9948}],
#      'lat': 46.87766,
#      'lng': -113.9948,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Kettlehouse Brewing Company North',
#     'referralId': 'v-1558467538'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4d5f2258865a224bb5119b85',
#     'location': {'cc': 'US',
#      'country': 'United States',
#      'distance': 7038,
#      'formattedAddress': ['Montana', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.81506826815,
#        'lng': -114.03292877950426}],
#      'lat': 46.81506826815,
#      'lng': -114.03292877950426,
#      'state': 'Montana'},
#     'name': 'Bitterroot Brewery',
#     'referralId': 'v-1558467538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '4be4a02fcf200f47093f123c',
#     'location': {'address': '5417 Trumpeter Way',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Btwn Expressway and W. Harrier',
#      'distance': 8197,
#      'formattedAddress': ['5417 Trumpeter Way (Btwn Expressway and W. Harrier)',
#       'Missoula, MT 59808',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.9220948085964,
#        'lng': -114.07269306463661}],
#      'lat': 46.9220948085964,
#      'lng': -114.07269306463661,
#      'postalCode': '59808',
#      'state': 'MT'},
#     'name': 'Big Sky Brewing Company',
#     'referralId': 'v-1558467538'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f2931735',
#       'name': 'Performing Arts Venue',
#       'pluralName': 'Performing Arts Venues',
#       'primary': True,
#       'shortName': 'Performing Arts'}],
#     'hasPerk': False,
#     'id': '50ecd10e5d24772c235c8d4c',
#     'location': {'cc': 'US',
#      'city': 'Stevensville',
#      'country': 'United States',
#      'distance': 41195,
#      'formattedAddress': ['Stevensville, MT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.508623,
#        'lng': -114.093795}],
#      'lat': 46.508623,
#      'lng': -114.093795,
#      'state': 'MT'},
#     'name': 'Blacksmith Brewery',
#     'referralId': 'v-1558467538'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Dive Bar', 'primary': True, 'i...    False
# 1  [{'shortName': 'Music Venue', 'primary': True,...    False
# 2  [{'shortName': 'Gastropub', 'primary': True, '...    False
# 3  [{'shortName': 'Gastropub', 'primary': True, '...    False
# 4  [{'shortName': 'Brewery', 'primary': True, 'ic...    False
#
#                          id   location.address location.cc     location.city  \
# 0  53f2a35b498e7b65981eb526                NaN          US          Missoula
# 1  5718858acd10a651ba07619e                NaN          US  Missoula, MT, US
# 2  4da4a4ce9aa4721e29553c1a     231 W Front St          US          Missoula
# 3  4cf6f3a4c020b60c92112375  424 N Higgins Ave          US          Missoula
# 4  4b7b6248f964a52019612fe3     313 N 1st St W          US          Missoula
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN                769
# 1    United States                  NaN                762
# 2    United States       at Carousel Dr                334
# 3    United States                  NaN                145
# 4    United States      at N Orange St.                614
#
#                            location.formattedAddress  \
# 0                      [Missoula, MT, United States]
# 1              [Missoula, MT, US, WA, United States]
# 2  [231 W Front St (at Carousel Dr), Missoula, MT...
# 3  [424 N Higgins Ave, Missoula, MT 59802, United...
# 4  [313 N 1st St W (at N Orange St.), Missoula, M...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 46.877627, 'lng': -113.999697, 'label...     46.877627
# 1  [{'lat': 46.8787176, 'lng': -113.996586, 'labe...     46.878718
# 2  [{'lat': 46.87095405942777, 'lng': -113.997386...     46.870954
# 3  [{'lat': 46.87346171289112, 'lng': -113.992809...     46.873462
# 4  [{'lat': 46.87766, 'lng': -113.9948, 'label': ...     46.877660
#
#    location.lng location.postalCode location.state  \
# 0   -113.999697                 NaN             MT
# 1   -113.996586                 NaN             WA
# 2   -113.997387               59802             MT
# 3   -113.992810               59802             MT
# 4   -113.994800               59802             MT
#
#                                           name    referralId
# 0                                 Brewery Park  v-1558467538
# 1                              Big Sky Brewery  v-1558467538
# 2  Tamarack Brewing Company Alehouse And Grill  v-1558467538
# 3    Flathead Lake Brewing Company of Missoula  v-1558467538
# 4            Kettlehouse Brewing Company North  v-1558467538

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                           name             categories  \
# 0                                 Brewery Park               Dive Bar
# 1                              Big Sky Brewery            Music Venue
# 2  Tamarack Brewing Company Alehouse And Grill              Gastropub
# 3    Flathead Lake Brewing Company of Missoula              Gastropub
# 4            Kettlehouse Brewing Company North                Brewery
# 5                           Bitterroot Brewery                   None
# 6                      Big Sky Brewing Company                Brewery
# 7                           Blacksmith Brewery  Performing Arts Venue
#
#               address  cc              city        country  \
# 0                 NaN  US          Missoula  United States
# 1                 NaN  US  Missoula, MT, US  United States
# 2      231 W Front St  US          Missoula  United States
# 3   424 N Higgins Ave  US          Missoula  United States
# 4      313 N 1st St W  US          Missoula  United States
# 5                 NaN  US               NaN  United States
# 6  5417 Trumpeter Way  US          Missoula  United States
# 7                 NaN  US      Stevensville  United States
#
#                       crossStreet  distance  \
# 0                             NaN       769
# 1                             NaN       762
# 2                  at Carousel Dr       334
# 3                             NaN       145
# 4                 at N Orange St.       614
# 5                             NaN      7038
# 6  Btwn Expressway and W. Harrier      8197
# 7                             NaN     41195
#
#                                     formattedAddress  \
# 0                      [Missoula, MT, United States]
# 1              [Missoula, MT, US, WA, United States]
# 2  [231 W Front St (at Carousel Dr), Missoula, MT...
# 3  [424 N Higgins Ave, Missoula, MT 59802, United...
# 4  [313 N 1st St W (at N Orange St.), Missoula, M...
# 5                           [Montana, United States]
# 6  [5417 Trumpeter Way (Btwn Expressway and W. Ha...
# 7                  [Stevensville, MT, United States]
#
#                                       labeledLatLngs        lat         lng  \
# 0  [{'lat': 46.877627, 'lng': -113.999697, 'label...  46.877627 -113.999697
# 1  [{'lat': 46.8787176, 'lng': -113.996586, 'labe...  46.878718 -113.996586
# 2  [{'lat': 46.87095405942777, 'lng': -113.997386...  46.870954 -113.997387
# 3  [{'lat': 46.87346171289112, 'lng': -113.992809...  46.873462 -113.992810
# 4  [{'lat': 46.87766, 'lng': -113.9948, 'label': ...  46.877660 -113.994800
# 5  [{'lat': 46.81506826815, 'lng': -114.032928779...  46.815068 -114.032929
# 6  [{'lat': 46.9220948085964, 'lng': -114.0726930...  46.922095 -114.072693
# 7  [{'lat': 46.508623, 'lng': -114.093795, 'label...  46.508623 -114.093795
#
#   postalCode    state                        id
# 0        NaN       MT  53f2a35b498e7b65981eb526
# 1        NaN       WA  5718858acd10a651ba07619e
# 2      59802       MT  4da4a4ce9aa4721e29553c1a
# 3      59802       MT  4cf6f3a4c020b60c92112375
# 4      59802       MT  4b7b6248f964a52019612fe3
# 5        NaN  Montana  4d5f2258865a224bb5119b85
# 6      59808       MT  4be4a02fcf200f47093f123c
# 7        NaN       MT  50ecd10e5d24772c235c8d4c

# %%
dataframe_filtered.name
# Out:
# 0                                   Brewery Park
# 1                                Big Sky Brewery
# 2    Tamarack Brewing Company Alehouse And Grill
# 3      Flathead Lake Brewing Company of Missoula
# 4              Kettlehouse Brewing Company North
# 5                             Bitterroot Brewery
# 6                        Big Sky Brewing Company
# 7                             Blacksmith Brewery
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# search query by category
search_query = 'liquor stores'
categoryId = '4bf58dd8d48988d186941735' # liquor stores
radius = 50000
print(search_query + ' .... OK!')
# Out:
# liquor stores .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=46.8722217,-113.993395&v=20180604&query=liquor stores&radius=50000&limit=100'

# %%
# get requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce455136a6071493ffccdf9'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4f32965019836c91c7e657e7',
#     'location': {'address': '1200 W Kent Ave',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 2978,
#      'formattedAddress': ['1200 W Kent Ave',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.851586,
#        'lng': -114.018314}],
#      'lat': 46.851586,
#      'lng': -114.018314,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Liquor Stores-Montana Retail Missoula',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4f43831b19834bc91f57446e',
#     'location': {'address': '11300 US Highway 93 S',
#      'cc': 'US',
#      'city': 'Lolo',
#      'country': 'United States',
#      'distance': 13813,
#      'formattedAddress': ['11300 US Highway 93 S',
#       'Lolo, MT 59847',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.763536,
#        'lng': -114.080909}],
#      'lat': 46.763536,
#      'lng': -114.080909,
#      'postalCode': '59847',
#      'state': 'MT'},
#     'name': 'Liquor Stores',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'primary': True,
#       'shortName': 'Casino'}],
#     'hasPerk': False,
#     'id': '4e29e662a809f1b163fef881',
#     'location': {'address': '123 W Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 132,
#      'formattedAddress': ['123 W Broadway St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.872519036272095,
#        'lng': -113.99508691875857}],
#      'lat': 46.872519036272095,
#      'lng': -113.99508691875857,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Savoy Casino & Liquor Store',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4b832d63f964a520e6fb30e3',
#     'location': {'address': '110 W Spruce St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Ryman St',
#      'distance': 247,
#      'formattedAddress': ['110 W Spruce St (Ryman St)',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.8744435999382,
#        'lng': -113.99343521924791}],
#      'lat': 46.8744435999382,
#      'lng': -113.99343521924791,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Grizzly Liquor',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d118941735',
#       'name': 'Dive Bar',
#       'pluralName': 'Dive Bars',
#       'primary': True,
#       'shortName': 'Dive Bar'}],
#     'hasPerk': False,
#     'id': '4ee3afbf775b86c4037b3140',
#     'location': {'address': '900 E Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 951,
#      'formattedAddress': ['900 E Broadway St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.86877,
#        'lng': -113.98196}],
#      'lat': 46.86877,
#      'lng': -113.98196,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': "Diamond Jim's Liquor & Lounge",
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4c0d25f385e19521573beea5',
#     'location': {'address': '1106 W Broadway St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 1008,
#      'formattedAddress': ['1106 W Broadway St',
#       'Missoula, MT 59802',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.87333274996049,
#        'lng': -114.00654764716175}],
#      'lat': 46.87333274996049,
#      'lng': -114.00654764716175,
#      'postalCode': '59802',
#      'state': 'MT'},
#     'name': 'Osprey Nest Liquor Store',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'id': '52e816a6bcbc57f1066b7a54',
#       'name': 'Warehouse Store',
#       'pluralName': 'Warehouse Stores',
#       'primary': True,
#       'shortName': 'Warehouse Store'}],
#     'hasPerk': False,
#     'id': '595fa863f00a706a94f30811',
#     'location': {'address': '2501 Brooks Street',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 3349,
#      'formattedAddress': ['2501 Brooks Street',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.84792,
#        'lng': -114.01935}],
#      'lat': 46.84792,
#      'lng': -114.01935,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'Smart Foodservice Warehouse Stores',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4b721a10f964a520bf6e2de3',
#     'location': {'address': '1300 S Reserve St',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'crossStreet': 'Spurgin Rd W',
#      'distance': 3757,
#      'formattedAddress': ['1300 S Reserve St (Spurgin Rd W)',
#       'Missoula, MT 59801',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.85911795109259,
#        'lng': -114.0388952518928}],
#      'lat': 46.85911795109259,
#      'lng': -114.0388952518928,
#      'postalCode': '59801',
#      'state': 'MT'},
#     'name': 'KrisCo Liquor',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4b5938d2f964a520e88128e3',
#     'location': {'address': '4055 U.S. 93',
#      'cc': 'US',
#      'city': 'Missoula',
#      'country': 'United States',
#      'distance': 6052,
#      'formattedAddress': ['4055 U.S. 93',
#       'Missoula, MT 59804',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.83364613655468,
#        'lng': -114.0494233226762}],
#      'lat': 46.83364613655468,
#      'lng': -114.0494233226762,
#      'postalCode': '59804',
#      'state': 'MT'},
#     'name': 'Silver Slipper',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '5a2649c39de23b0468c59182',
#     'location': {'address': '11300 US Highway 93 S',
#      'cc': 'US',
#      'city': 'Lolo',
#      'country': 'United States',
#      'distance': 13763,
#      'formattedAddress': ['11300 US Highway 93 S',
#       'Lolo, MT 59847',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.76348,
#        'lng': -114.07939}],
#      'lat': 46.76348,
#      'lng': -114.07939,
#      'postalCode': '59847',
#      'state': 'MT'},
#     'name': 'Lolo Liquor and Wine',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4f32b60219836c91c7f22f23',
#     'location': {'address': '301 Main St',
#      'cc': 'US',
#      'city': 'Stevensville',
#      'country': 'United States',
#      'distance': 41042,
#      'formattedAddress': ['301 Main St',
#       'Stevensville, MT 59870',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.509976,
#        'lng': -114.093484}],
#      'lat': 46.509976,
#      'lng': -114.093484,
#      'postalCode': '59870',
#      'state': 'MT'},
#     'name': 'Liquor',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '503fe29fe4b069cafe0e8a8d',
#     'location': {'cc': 'US',
#      'country': 'United States',
#      'distance': 41580,
#      'formattedAddress': ['Montana', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.009098052978516,
#        'lng': -114.50242614746094}],
#      'lat': 47.009098052978516,
#      'lng': -114.50242614746094,
#      'state': 'Montana'},
#     'name': 'State of Montana Liquor Store',
#     'referralId': 'v-1558467859'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'primary': True,
#       'shortName': 'Liquor Store'}],
#     'hasPerk': False,
#     'id': '4d7eabd22ff9b60c5dadb047',
#     'location': {'address': '2381 US Highway 93 N',
#      'cc': 'US',
#      'city': 'Victor',
#      'country': 'United States',
#      'distance': 51858,
#      'formattedAddress': ['2381 US Highway 93 N',
#       'Victor, MT',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 46.41820256,
#        'lng': -114.14541441}],
#      'lat': 46.41820256,
#      'lng': -114.14541441,
#      'state': 'MT'},
#     'name': 'Victor Liquor',
#     'referralId': 'v-1558467859'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Liquor Store', 'primary': True...    False
# 1  [{'shortName': 'Liquor Store', 'primary': True...    False
# 2  [{'shortName': 'Casino', 'primary': True, 'ico...    False
# 3  [{'shortName': 'Liquor Store', 'primary': True...    False
# 4  [{'shortName': 'Dive Bar', 'primary': True, 'i...    False
#
#                          id       location.address location.cc location.city  \
# 0  4f32965019836c91c7e657e7        1200 W Kent Ave          US      Missoula
# 1  4f43831b19834bc91f57446e  11300 US Highway 93 S          US          Lolo
# 2  4e29e662a809f1b163fef881      123 W Broadway St          US      Missoula
# 3  4b832d63f964a520e6fb30e3        110 W Spruce St          US      Missoula
# 4  4ee3afbf775b86c4037b3140      900 E Broadway St          US      Missoula
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN               2978
# 1    United States                  NaN              13813
# 2    United States                  NaN                132
# 3    United States             Ryman St                247
# 4    United States                  NaN                951
#
#                            location.formattedAddress  \
# 0  [1200 W Kent Ave, Missoula, MT 59801, United S...
# 1  [11300 US Highway 93 S, Lolo, MT 59847, United...
# 2  [123 W Broadway St, Missoula, MT 59802, United...
# 3  [110 W Spruce St (Ryman St), Missoula, MT 5980...
# 4  [900 E Broadway St, Missoula, MT 59802, United...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 46.851586, 'lng': -114.018314, 'label...     46.851586
# 1  [{'lat': 46.763536, 'lng': -114.080909, 'label...     46.763536
# 2  [{'lat': 46.872519036272095, 'lng': -113.99508...     46.872519
# 3  [{'lat': 46.8744435999382, 'lng': -113.9934352...     46.874444
# 4  [{'lat': 46.86877, 'lng': -113.98196, 'label':...     46.868770
#
#    location.lng location.postalCode location.state  \
# 0   -114.018314               59801             MT
# 1   -114.080909               59847             MT
# 2   -113.995087               59802             MT
# 3   -113.993435               59802             MT
# 4   -113.981960               59802             MT
#
#                                     name    referralId
# 0  Liquor Stores-Montana Retail Missoula  v-1558467859
# 1                          Liquor Stores  v-1558467859
# 2            Savoy Casino & Liquor Store  v-1558467859
# 3                         Grizzly Liquor  v-1558467859
# 4          Diamond Jim's Liquor & Lounge  v-1558467859

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                      name       categories  \
# 0   Liquor Stores-Montana Retail Missoula     Liquor Store
# 1                           Liquor Stores     Liquor Store
# 2             Savoy Casino & Liquor Store           Casino
# 3                          Grizzly Liquor     Liquor Store
# 4           Diamond Jim's Liquor & Lounge         Dive Bar
# 5                Osprey Nest Liquor Store     Liquor Store
# 6      Smart Foodservice Warehouse Stores  Warehouse Store
# 7                           KrisCo Liquor     Liquor Store
# 8                          Silver Slipper              Bar
# 9                    Lolo Liquor and Wine     Liquor Store
# 10                                 Liquor     Liquor Store
# 11          State of Montana Liquor Store     Liquor Store
# 12                          Victor Liquor     Liquor Store
#
#                   address  cc          city        country   crossStreet  \
# 0         1200 W Kent Ave  US      Missoula  United States           NaN
# 1   11300 US Highway 93 S  US          Lolo  United States           NaN
# 2       123 W Broadway St  US      Missoula  United States           NaN
# 3         110 W Spruce St  US      Missoula  United States      Ryman St
# 4       900 E Broadway St  US      Missoula  United States           NaN
# 5      1106 W Broadway St  US      Missoula  United States           NaN
# 6      2501 Brooks Street  US      Missoula  United States           NaN
# 7       1300 S Reserve St  US      Missoula  United States  Spurgin Rd W
# 8            4055 U.S. 93  US      Missoula  United States           NaN
# 9   11300 US Highway 93 S  US          Lolo  United States           NaN
# 10            301 Main St  US  Stevensville  United States           NaN
# 11                    NaN  US           NaN  United States           NaN
# 12   2381 US Highway 93 N  US        Victor  United States           NaN
#
#     distance                                   formattedAddress  \
# 0       2978  [1200 W Kent Ave, Missoula, MT 59801, United S...
# 1      13813  [11300 US Highway 93 S, Lolo, MT 59847, United...
# 2        132  [123 W Broadway St, Missoula, MT 59802, United...
# 3        247  [110 W Spruce St (Ryman St), Missoula, MT 5980...
# 4        951  [900 E Broadway St, Missoula, MT 59802, United...
# 5       1008  [1106 W Broadway St, Missoula, MT 59802, Unite...
# 6       3349  [2501 Brooks Street, Missoula, MT 59801, Unite...
# 7       3757  [1300 S Reserve St (Spurgin Rd W), Missoula, M...
# 8       6052  [4055 U.S. 93, Missoula, MT 59804, United States]
# 9      13763  [11300 US Highway 93 S, Lolo, MT 59847, United...
# 10     41042  [301 Main St, Stevensville, MT 59870, United S...
# 11     41580                           [Montana, United States]
# 12     51858  [2381 US Highway 93 N, Victor, MT, United States]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'lat': 46.851586, 'lng': -114.018314, 'label...  46.851586 -114.018314
# 1   [{'lat': 46.763536, 'lng': -114.080909, 'label...  46.763536 -114.080909
# 2   [{'lat': 46.872519036272095, 'lng': -113.99508...  46.872519 -113.995087
# 3   [{'lat': 46.8744435999382, 'lng': -113.9934352...  46.874444 -113.993435
# 4   [{'lat': 46.86877, 'lng': -113.98196, 'label':...  46.868770 -113.981960
# 5   [{'lat': 46.87333274996049, 'lng': -114.006547...  46.873333 -114.006548
# 6   [{'lat': 46.84792, 'lng': -114.01935, 'label':...  46.847920 -114.019350
# 7   [{'lat': 46.85911795109259, 'lng': -114.038895...  46.859118 -114.038895
# 8   [{'lat': 46.83364613655468, 'lng': -114.049423...  46.833646 -114.049423
# 9   [{'lat': 46.76348, 'lng': -114.07939, 'label':...  46.763480 -114.079390
# 10  [{'lat': 46.509976, 'lng': -114.093484, 'label...  46.509976 -114.093484
# 11  [{'lat': 47.009098052978516, 'lng': -114.50242...  47.009098 -114.502426
# 12  [{'lat': 46.41820256, 'lng': -114.14541441, 'l...  46.418203 -114.145414
#
#    postalCode    state                        id
# 0       59801       MT  4f32965019836c91c7e657e7
# 1       59847       MT  4f43831b19834bc91f57446e
# 2       59802       MT  4e29e662a809f1b163fef881
# 3       59802       MT  4b832d63f964a520e6fb30e3
# 4       59802       MT  4ee3afbf775b86c4037b3140
# 5       59802       MT  4c0d25f385e19521573beea5
# 6       59801       MT  595fa863f00a706a94f30811
# 7       59801       MT  4b721a10f964a520bf6e2de3
# 8       59804       MT  4b5938d2f964a520e88128e3
# 9       59847       MT  5a2649c39de23b0468c59182
# 10      59870       MT  4f32b60219836c91c7f22f23
# 11        NaN  Montana  503fe29fe4b069cafe0e8a8d
# 12        NaN       MT  4d7eabd22ff9b60c5dadb047

# %%
dataframe_filtered.name
# Out:
# 0     Liquor Stores-Montana Retail Missoula
# 1                             Liquor Stores
# 2               Savoy Casino & Liquor Store
# 3                            Grizzly Liquor
# 4             Diamond Jim's Liquor & Lounge
# 5                  Osprey Nest Liquor Store
# 6        Smart Foodservice Warehouse Stores
# 7                             KrisCo Liquor
# 8                            Silver Slipper
# 9                      Lolo Liquor and Wine
# 10                                   Liquor
# 11            State of Montana Liquor Store
# 12                            Victor Liquor
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# next search for crime datasets in Billings and Missoula
#  url
# https://www.crimemapping.com/map/mt/billings/?fbclid=IwAR2S_lVV-AHqhmEa-w4uY5PkhnZxAutuT2krzbP_u5ch6MGGFcC6oTaBhkA
# Billings crimes - drugs or DUI table with 950 records from Jan 1, 2019 to April 30, 2019
# scrape for data...
import lxml.html as lh

# %%
url='https://www.crimemapping.com/map/mt/billings/?fbclid=IwAR2S_lVV-AHqhmEa-w4uY5PkhnZxAutuT2krzbP_u5ch6MGGFcC6oTaBhkA'

# %%
# create a handle, page, to handle the contents of the website
page = requests.get(url)

# %%
# store the contents of the website under doc
doc = lh.fromstring(page.content)

# %%
# parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
#Check the length of the first 12 rows
[len(T) for T in tr_elements[:12]]
# Out:
# []

# %%
# no output - consider other options...export report, copy table, create csv, drop into session, use insert to code, so easy!

# %%
# insert to code after drop csv
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_5c2a9631aa04424a9ac6625f8f35c9f0 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='9oFFmvaZUPr3N1qU4gDHYft2TEF1tKZN3axmxMT753EE',
    ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_5c2a9631aa04424a9ac6625f8f35c9f0.get_object(Bucket='addictionriskmap-donotdelete-pr-r8csot5d5nitbg',Key='BillingsDrugDUICrimesApril2019.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#           Description                    Location             Date
# 0                 DUI  6TH ST W & YELLOWSTONE AVE  4/30/2019 22:05
# 1               Drunk            1000 BLK MAIN ST  4/30/2019 21:26
# 2               Drunk          3000 BLK 7TH AVE N  4/30/2019 20:21
# 3  Drug Investigation       6TH AVE N & N 23RD ST  4/30/2019 16:56
# 4                 DUI          1000 BLK 1ST AVE N  4/30/2019 14:34

# %%
# next try to convert location to lat/long...example...
# use online converter with Mapquest key: http://more.stevemorse.org/latlonbatch2.html?direction=forward

# %%
# insert to code BillingsLocation.csv
body = client_5c2a9631aa04424a9ac6625f8f35c9f0.get_object(Bucket='addictionriskmap-donotdelete-pr-r8csot5d5nitbg',Key='BillingsLocation.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#           Description                    Location             Date  \
# 0                 DUI  6TH ST W & YELLOWSTONE AVE  4/30/2019 22:05
# 1               Drunk            1000 BLK MAIN ST  4/30/2019 21:26
# 2               Drunk          3000 BLK 7TH AVE N  4/30/2019 20:21
# 3  Drug Investigation       6TH AVE N & N 23RD ST  4/30/2019 16:56
# 4                 DUI          1000 BLK 1ST AVE N  4/30/2019 14:34
#
#                    Location.1                          LocationBillings
# 0  6TH ST W & YELLOWSTONE AVE  6TH ST W & YELLOWSTONE AVE, Billings, MT
# 1                1000 MAIN ST                1000 MAIN ST, Billings, MT
# 2              3000 7TH AVE N              3000 7TH AVE N, Billings, MT
# 3       6TH AVE N & N 23RD ST       6TH AVE N & N 23RD ST, Billings, MT
# 4              1000 1ST AVE N              1000 1ST AVE N, Billings, MT

# %%
# https://www.shanelynn.ie/batch-geocoding-in-python-with-google-geocoding-api/
# try google api for geocoding with python
import logging
import time
logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

# %%
#------------------ CONFIGURATION -------------------------------

# Set your Google API key here. 
# Even if using the free 2500 queries a day, its worth getting an API key since the rate limit is 50 / second.
# With API_KEY = None, you will run into a 2 second delay every 10 requests or so.
# With a "Google Maps Geocoding API" key from https://console.developers.google.com/apis/, 
# the daily limit will be 2500, but at a much faster rate.
# Example: API_KEY = 'AIzaSyC9azed9tLdjpZNjg2_kVePWvMIBq154eA'
API_KEY = None
# Backoff time sets how many minutes to wait between google pings when your API limit is hit
BACKOFF_TIME = 30
# Set your output file name here.
output_filename = 'LocationsOutput.csv'
# Set your input file here
input_filename = df_data_2
# Specify the column name in your input data that contains addresses here
address_column_name = "LocationBillings"
# Return Full Google Results? If True, full JSON results from Google are included in output
RETURN_FULL_RESULTS = False

# %%
#------------------ DATA LOADING --------------------------------

# Read the data to a Pandas Dataframe
data = df_data_2

if address_column_name not in data.columns:
	raise ValueError("Missing Address column in input data")

# Form a list of addresses for geocoding:
# Make a big list of all of the addresses to be processed.
addresses = data[address_column_name].tolist()

# **** DEMO DATA / IRELAND SPECIFIC! ****
# We know that these addresses are in Ireland, and there's a column for county, so add this for accuracy. 
# (remove this line / alter for your own dataset)
# addresses = (data[address_column_name] + ',' + data['County'] + ',Ireland').tolist()

# %%
#------------------	FUNCTION DEFINITIONS ------------------------

def get_google_results(address, api_key=None, return_full_response=False):
    """
    Get geocode results from Google Maps Geocoding API.
    
    Note, that in the case of multiple google geocode reuslts, this function returns details of the FIRST result.
    
    @param address: String address as accurate as possible. For Example "18 Grafton Street, Dublin, Ireland"
    @param api_key: String API key if present from google. 
                    If supplied, requests will use your allowance from the Google API. If not, you
                    will be limited to the free usage of 2500 requests per day.
    @param return_full_response: Boolean to indicate if you'd like to return the full response from google. This
                    is useful if you'd like additional location details for storage or parsing later.
    """
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

# %%
#------------------ PROCESSING LOOP -----------------------------

# Ensure, before we start, that the API key is ok/valid, and internet access is ok
test_result = get_google_results("London, England", API_KEY, RETURN_FULL_RESULTS)
if (test_result['status'] != 'OK') or (test_result['formatted_address'] != 'London, UK'):
    logger.warning("There was an error when testing the Google Geocoder.")
    raise ConnectionError('Problem with test results from Google Geocode - check your API key and internet connection.')

# Create a list to hold results
results = []
# Go through each address in turn
for address in addresses:
    # While the address geocoding is not finished:
    geocoded = False
    while geocoded is not True:
        # Geocode the address with google
        try:
            geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS)
        except Exception as e:
            logger.exception(e)
            logger.error("Major error with {}".format(address))
            logger.error("Skipping!")
            geocoded = True
            
        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            logger.info("Hit Query Limit! Backing off for a bit.")
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            geocoded = False
        else:
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
            logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
            results.append(geocode_result)           
            geocoded = True

    # Print status every 100 addresses
    if len(results) % 100 == 0:
    	logger.info("Completed {} of {} address".format(len(results), len(addresses)))
            
    # Every 500 addresses, save progress to file(in case of a failure so you have something!)
    if len(results) % 500 == 0:
        pd.DataFrame(results).to_csv("{}_bak".format(output_filename))

# All done
logger.info("Finished geocoding all addresses")
# Write the full results to csv using the pandas library.
pd.DataFrame(results).to_csv(output_filename, encoding='utf8')
# Out:
# There was an error when testing the Google Geocoder.
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-48-df74e2de2ee1> in <module>()
#       6 if (test_result['status'] != 'OK') or (test_result['formatted_address'] != 'London, UK'):
#       7     logger.warning("There was an error when testing the Google Geocoder.")
# ----> 8     raise ConnectionError('Problem with test results from Google Geocode - check your API key and internet connection.')
#       9
#      10 # Create a list to hold results
#
# ConnectionError: Problem with test results from Google Geocode - check your API key and internet connection.

# %%
body = client_5c2a9631aa04424a9ac6625f8f35c9f0.get_object(Bucket='addictionriskmap-donotdelete-pr-r8csot5d5nitbg',Key='BillingsLocationDrugOnly.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_4 = pd.read_csv(body)
df_data_4.head()
# Out:
#           Description                   Location             Date  \
# 0  Drug Investigation      6TH AVE N & N 23RD ST  4/30/2019 16:56
# 1  Drug Investigation  1700 BLK HIGH SIERRA BLVD  4/30/2019 14:24
# 2  Drug Investigation         1400 BLK GRAND AVE  4/30/2019 14:21
# 3  Drug Investigation     1500 BLK UNIVERSITY DR  4/30/2019 14:17
# 4  Drug Investigation      CUSTER AVE & 3RD ST W  4/30/2019 11:25
#
#               Location.1                     LocationBillings  \
# 0  6TH AVE N & N 23RD ST  6TH AVE N & N 23RD ST, Billings, MT
# 1  1700 HIGH SIERRA BLVD  1700 HIGH SIERRA BLVD, Billings, MT
# 2         1400 GRAND AVE         1400 GRAND AVE, Billings, MT
# 3     1500 UNIVERSITY DR     1500 UNIVERSITY DR, Billings, MT
# 4  CUSTER AVE & 3RD ST W  CUSTER AVE & 3RD ST W, Billings, MT
#
#            GeoLocatorOutput        Lat        Long
# 0    45.789254, -108.503431  45.789254 -108.503431
# 1    45.8324726, -108.51753  45.832473 -108.517530
# 2  45.7841172, -108.5982038  45.784117 -108.598204
# 3    45.797147, -108.517530  45.797147 -108.517530
# 4    45.775965, -108.522669  45.775965 -108.522669

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add the Coffee Shops as blue circle markers
for lat, lng, label in zip(df_data_4.lat, df_data_4.lng, df_data_4.Description):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-bf4c88b06a8a> in <module>()
#       2
#       3 # add the Coffee Shops as blue circle markers
# ----> 4 for lat, lng, label in zip(df_data_4.lat, df_data_4.lng, df_data_4.Description):
#       5     folium.features.CircleMarker(
#       6         [lat, lng],
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'lat'

# %%
# search for kratum as potential drug that is legal but may become illegal soon...
search_query = 'Kratum'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Kratum .... OK!

# %%
# define the url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0DRUG0FSURF4DQ2KMM3YZYHVTMJ41JSKOTEO2X4B0W3ZMCFA&client_secret=U5NFRY0TAVIJ51HKICV1NFUBGWXSQN0TWKIYNQMGSRTRCAPY&ll=45.784127338925,-108.557717907471&v=20180604&query=Kratum&radius=50000&limit=100'

# %%
# get requests
results = requests.get(url).json()
results
# no results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce5b4f06e69af00251aafa1'},
#  'response': {'venues': []}}
